# %%
# Copyright 2021 Google LLC
# Use of this source code is governed by an MIT-style
# license that can be found in the LICENSE file or at
# https://opensource.org/licenses/MIT.

# Author(s): Kevin P. Murphy (murphyk@gmail.com) and Mahmoud Soliman (mjs@aucegypt.edu)

# %% [markdown]
# <a href="https://opensource.org/licenses/MIT" target="_parent"><img src="https://img.shields.io/github/license/probml/pyprobml"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/probml/pyprobml/blob/master/book1/figures/chapter12_figures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Figure 12.1:<a name='12.1'></a> <a name='probitSigmoidPlot'></a>

# %% [markdown]
#   The logistic (sigmoid) function $\sigma (x)$ in solid red, with the Gaussian cdf function $\Phi (\lambda x)$ in dotted blue superimposed. Here $\lambda =\sqrt  \pi /8 $, which was chosen so that the derivatives of the two curves match at $x=0$. Adapted from Figure 4.9 of <a href='#BishopBook'>[Bis06]</a> .
# Figure(s) generated by [probit_plot.py](https://github.com/probml/pyprobml/blob/master/scripts/probit_plot.py)

# %%
 #@title Setup { display-mode: "form" }
# %%time
# If you run this for the first time it would take ~25/30 seconds
# !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null && git clone https://github.com/probml/colab_powertoys.git &> /dev/null 
# !pip3 install nbimporter -qqq 
# %cd -q /content/colab_powertoys 
from colab_powertoys.probml_toys import probml_toys as pmlt
# %cd -q /pyprobml/scripts

# %%
pmlt.show_and_run("/pyprobml/scripts/probit_plot.py")

# %% [markdown]
# ## Figure 12.2:<a name='12.2'></a> <a name='probitRegDemo'></a>

# %% [markdown]
#   Fitting a probit regression model in 2d using a quasi-Newton method or EM.
# Figure(s) generated by [probitRegDemo.m](https://github.com/probml/pmtk3/blob/master/demos/probitRegDemo.m)

# %%
 #@title Setup { display-mode: "form" }
# %%time
# If you run this for the first time it would take ~25/30 seconds
# !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null && git clone https://github.com/probml/colab_powertoys.git &> /dev/null 
# !pip3 install nbimporter -qqq 
# %cd -q /content/colab_powertoys 
from colab_powertoys.probml_toys import probml_toys as pmlt
# %cd -q /pyprobml/scripts

# %%
pmlt.show_image("/pyprobml/book1/figures/images/probitRegDemoNLL.png")

# %% [markdown]
# ## References:
#  <a name='BishopBook'>[Bis06]</a> C. Bishop "Pattern recognition and machine learning". (2006).
