# %%
# Copyright 2021 Google LLC
# Use of this source code is governed by an MIT-style
# license that can be found in the LICENSE file or at
# https://opensource.org/licenses/MIT.
# Notebook authors: Kevin P. Murphy (murphyk@gmail.com)
# and Mahmoud Soliman (mjs@aucegypt.edu)

# This notebook reproduces figures for chapter 9 from the book
# "Probabilistic Machine Learning: An Introduction"
# by Kevin Murphy (MIT Press, 2021).
# Book pdf is available from http://probml.ai
# Out:
# time: 2.48 ms (started: 2021-05-11 15:46:40 +00:00)

# %% [markdown]
# <a href="https://opensource.org/licenses/MIT" target="_parent"><img src="https://img.shields.io/github/license/probml/pyprobml"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/probml/pyprobml/blob/master/book1/figures/chapter9_linear_discriminant_analysis_figures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Figure 9.1:<a name='9.1'></a> <a name='gda2d'></a>

# %% [markdown]
#   (a) Some 2d data from 3 different classes. (b) Fitting 2d Gaussians to each class.
# Figure(s) generated by [discrim_analysis_dboundaries_plot2.py](https://github.com/probml/pyprobml/blob/master/scripts/discrim_analysis_dboundaries_plot2.py)

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# running setup...
# finished!
# time: 18.6 s (started: 2021-05-11 15:46:40 +00:00)

# %%
google.colab.files.view("./discrim_analysis_dboundaries_plot2.py")
# %run discrim_analysis_dboundaries_plot2.py
# Out:
# /pyprobml/scripts/discrim_analysis_dboundaries_plot2.py:85: UserWarning: The following kwargs were not used by contour: 'lw'
#   [0.5], lw=3, colors='k')
# /pyprobml/scripts/discrim_analysis_dboundaries_plot2.py:85: UserWarning: The following kwargs were not used by contour: 'lw'
#   [0.5], lw=3, colors='k')
# time: 10.4 s (started: 2021-05-11 15:46:58 +00:00)

# %% [markdown]
# ## Figure 9.2:<a name='9.2'></a> <a name='LDA'></a>

# %% [markdown]
#   Gaussian discriminant analysis fit to data in \cref  fig:gda2d . (a) Unconstrained covariances induce quadratic decision boundaries. (b) Tied covariances induce linear decision boundaries.
# Figure(s) generated by [discrim_analysis_dboundaries_plot2.py](https://github.com/probml/pyprobml/blob/master/scripts/discrim_analysis_dboundaries_plot2.py)

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 28.6 ms (started: 2021-05-11 15:47:09 +00:00)

# %%
google.colab.files.view("./discrim_analysis_dboundaries_plot2.py")
# %run discrim_analysis_dboundaries_plot2.py
# Out:
# /pyprobml/scripts/discrim_analysis_dboundaries_plot2.py:85: UserWarning: The following kwargs were not used by contour: 'lw'
#   [0.5], lw=3, colors='k')
# /pyprobml/scripts/discrim_analysis_dboundaries_plot2.py:85: UserWarning: The following kwargs were not used by contour: 'lw'
#   [0.5], lw=3, colors='k')
# time: 9.45 s (started: 2021-05-11 15:47:09 +00:00)

# %% [markdown]
# ## Figure 9.3:<a name='9.3'></a> <a name='ldaGeom'></a>

# %% [markdown]
#   Geometry of LDA in the 2 class case where $\boldsymbol  \Sigma  _1=\boldsymbol  \Sigma  _2=\mathbf  I $.

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 33.1 ms (started: 2021-05-11 15:47:18 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_9.3.png")
# Out:
# <PIL.Image.Image image mode=RGB size=558x480 at 0x7F982196D990>
# time: 255 ms (started: 2021-05-11 15:47:18 +00:00)

# %% [markdown]
# ## Figure 9.4:<a name='9.4'></a> <a name='fisher'></a>

# %% [markdown]
#   Example of Fisher's linear discriminant applied to data in 2d drawn from two classes. Dashed green line = first principal basis vector. Dotted red line = Fisher's linear discriminant vector. Solid black line joins the class-conditional means.
# Figure(s) generated by [fisherLDAdemo.m](https://github.com/probml/pmtk3/blob/master/demos/fisherLDAdemo.m)

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 37.8 ms (started: 2021-05-11 15:47:19 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_9.4.png")
# Out:
# <PIL.Image.Image image mode=RGB size=816x480 at 0x7F9813622590>
# time: 189 ms (started: 2021-05-11 15:47:19 +00:00)

# %% [markdown]
# ## Figure 9.5:<a name='9.5'></a> <a name='fisherProj'></a>

# %% [markdown]
#   Example of Fisher's linear discriminant. (a) Projection of points onto Fisher's vector in \cref  fig:fisher  shows good class separation. (b) Projection of points onto PCA vector in \cref  fig:fisher  shows poor class separation.
# Figure(s) generated by [fisherLDAdemo.m](https://github.com/probml/pmtk3/blob/master/demos/fisherLDAdemo.m)

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 25.8 ms (started: 2021-05-11 15:47:19 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_9.5.png")
# Out:
# <PIL.Image.Image image mode=RGB size=816x480 at 0x7F981916CA50>
# time: 153 ms (started: 2021-05-11 15:47:19 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_9.5.png")
# Out:
# <PIL.Image.Image image mode=RGB size=816x480 at 0x7F98136226D0>
# time: 142 ms (started: 2021-05-11 15:47:19 +00:00)

# %% [markdown]
# ## Figure 9.6:<a name='9.6'></a> <a name='fisherVowel'></a>

# %% [markdown]
#   (a) PCA projection of vowel data to 2d. (b) FLDA projection of vowel data to 2d. We see there is better class separation in the FLDA case. Adapted from Figure 4.11 of <a href='#HastieBook'>[HTF09]</a> .
# Figure(s) generated by [fisherDiscrimVowelDemo.m](https://github.com/probml/pmtk3/blob/master/demos/fisherDiscrimVowelDemo.m)

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 27.5 ms (started: 2021-05-11 15:47:19 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_9.6.png")
# Out:
# <PIL.Image.Image image mode=RGB size=618x480 at 0x7F9816E33C10>
# time: 76.5 ms (started: 2021-05-11 15:47:19 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_9.6.png")
# Out:
# <PIL.Image.Image image mode=RGB size=618x480 at 0x7F9813622610>
# time: 106 ms (started: 2021-05-11 15:47:19 +00:00)

# %% [markdown]
# ## Figure 9.7:<a name='9.7'></a> <a name='nbc_mnist_centroids'></a>

# %% [markdown]
#   Visualization of the Bernoulli class conditional densities for a naive Bayes classifier fit to a binarized version of the MNIST dataset.

# %% [markdown]
# To reproduce this figure, click the open in colab button: <a href="https://colab.research.google.com/github/https://colab.research.google.com/github/probml/pyprobml/blob/master/notebooks/naive_bayes_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 37.7 ms (started: 2021-05-11 15:47:20 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_9.7.png")
# Out:
# <PIL.Image.Image image mode=RGB size=4800x480 at 0x7F98138548D0>
# time: 174 ms (started: 2021-05-11 15:47:20 +00:00)

# %% [markdown]
# ## Figure 9.8:<a name='9.8'></a> <a name='nbc_mnist_preds'></a>

# %% [markdown]
#   Visualization of the predictions made by the model in \cref  fig:nbc_mnist_centroids  when applied to the first 10 binarized MNIST test images. The 9'th example is incorrect.

# %% [markdown]
# To reproduce this figure, click the open in colab button: <a href="https://colab.research.google.com/github/https://colab.research.google.com/github/probml/pyprobml/blob/master/notebooks/naive_bayes_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 46.8 ms (started: 2021-05-11 15:47:20 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_9.8.png")
# Out:
# <PIL.Image.Image image mode=RGB size=4800x480 at 0x7F98136A6850>
# time: 186 ms (started: 2021-05-11 15:47:20 +00:00)

# %% [markdown]
# ## Figure 9.9:<a name='9.9'></a> <a name='genVsDiscrim'></a>

# %% [markdown]
#   The class-conditional densities $p(x|y=c)$ (left) may be more complex than the class posteriors $p(y=c|x)$ (right). Adapted from Figure 1.27 of <a href='#BishopBook'>[Bis06]</a> .
# Figure(s) generated by [generativeVsDiscrim.py](https://github.com/probml/pyprobml/blob/master/scripts/generativeVsDiscrim.py)

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 28 ms (started: 2021-05-11 15:47:20 +00:00)

# %%
google.colab.files.view("./generativeVsDiscrim.py")
# %run generativeVsDiscrim.py
# Out:
# time: 549 ms (started: 2021-05-11 15:47:20 +00:00)

# %% [markdown]
# ## References:
#  <a name='BishopBook'>[Bis06]</a> C. Bishop "Pattern recognition and machine learning". (2006).
#
# <a name='HastieBook'>[HTF09]</a> T. Hastie, R. Tibshirani and J. Friedman. "The Elements of Statistical Learning". (2009).
