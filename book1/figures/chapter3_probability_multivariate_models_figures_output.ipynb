# %%
# Copyright 2021 Google LLC
# Use of this source code is governed by an MIT-style
# license that can be found in the LICENSE file or at
# https://opensource.org/licenses/MIT.
# Notebook authors: Kevin P. Murphy (murphyk@gmail.com)
# and Mahmoud Soliman (mjs@aucegypt.edu)

# This notebook reproduces figures for chapter 3 from the book
# "Probabilistic Machine Learning: An Introduction"
# by Kevin Murphy (MIT Press, 2021).
# Book pdf is available from http://probml.ai
# Out:
# time: 2.55 ms (started: 2021-06-07 13:58:42 +00:00)

# %% [markdown]
# <a href="https://opensource.org/licenses/MIT" target="_parent"><img src="https://img.shields.io/github/license/probml/pyprobml"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/probml/pyprobml/blob/master/book1/figures/chapter3_probability_multivariate_models_figures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Figure 3.1:<a name='3.1'></a> <a name='corrcoefWikipedia'></a>

# %% [markdown]
#   Several sets of $(x, y)$ points, with the correlation coefficient of $x$ and $y$ for each set. Note that the correlation reflects the noisiness and direction of a linear relationship (top row), but not the slope of that relationship (middle), nor many aspects of nonlinear relationships (bottom). (Note: the figure in the center has a slope of 0 but in that case the correlation coefficient is undefined because the variance of $Y$ is zero.) From   https://en.wikipedia.org/wiki/Pearson_correlation_coefficient . Used with kind permission of Wikipedia author Imagecreator.

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# running setup...
# finished!
# time: 19.5 s (started: 2021-06-07 13:58:42 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_3.1.png")
# Out:
# <PIL.Image.Image image mode=RGB size=1142x480 at 0x7F0B968E1150>
# time: 230 ms (started: 2021-06-07 13:59:01 +00:00)

# %% [markdown]
# ## Figure 3.2:<a name='3.2'></a> <a name='spuriousCorrelation'></a>

# %% [markdown]
#   Examples of spurious correlation between causally unrelated time series. (a) Consumption is ice cream (red) and US murder rate (black) over time. From   https://bit.ly/2zfbuvf . Used with kind permission of Karen Cyphers. (b) Divorce rate in Maine strongly correlates with per-capita US consumption of margarine (black). From   http://www.tylervigen.com/spurious-correlations . Used with kind permission of Tyler Vigen.

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 32 ms (started: 2021-06-07 13:59:01 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_3.2_A.jpg")
# Out:
# <PIL.Image.Image image mode=RGB size=822x480 at 0x7F0B86F00AD0>
# time: 97 ms (started: 2021-06-07 13:59:01 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_3.2_B.png")
# Out:
# <PIL.Image.Image image mode=RGB size=1217x480 at 0x7F0B86F68E90>
# time: 271 ms (started: 2021-06-07 13:59:02 +00:00)

# %% [markdown]
# ## Figure 3.3:<a name='3.3'></a> <a name='simpsonsParadoxGraph'></a>

# %% [markdown]
#   Illustration of Simpson's paradox. (a) Overall, $y$ decreases $y$ with $x$. (b) Within each group, $y$ increases with $x$. From   https://en.wikipedia.org/wiki/Simpson's_paradox . Used with kind permission of Wikipedia author Pace\nobreakspace   svwiki

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 25.8 ms (started: 2021-06-07 13:59:02 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_3.3_A.png")
# Out:
# <PIL.Image.Image image mode=RGBA size=672x480 at 0x7F0B86F0B710>
# time: 66.5 ms (started: 2021-06-07 13:59:02 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_3.3_B.png")
# Out:
# <PIL.Image.Image image mode=RGBA size=672x480 at 0x7F0B86F13910>
# time: 92.4 ms (started: 2021-06-07 13:59:02 +00:00)

# %% [markdown]
# ## Figure 3.4:<a name='3.4'></a> <a name='simpsonsCovid'></a>

# %% [markdown]
#   Illustration of Simpson's paradox using COVID-19\xspace , (a) Case fatality rates (CFRs) in Italy and China by age group, and in aggregated form (``Total'', last pair of bars), up to the time of reporting (see legend). (b) Proportion of all confirmed cases included in (a) within each age group by country. From Figure 1 of <a href='#VonKugelgen2020'>[JLB20]</a> . Used with kind permission of Julius von K \"u gelgen.

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 34.1 ms (started: 2021-06-07 13:59:02 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_3.4_A.png")
# Out:
# <PIL.Image.Image image mode=RGB size=729x480 at 0x7F0B86EF8ED0>
# time: 64 ms (started: 2021-06-07 13:59:02 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_3.4_B.png")
# Out:
# <PIL.Image.Image image mode=RGB size=729x480 at 0x7F0BB5AE8DD0>
# time: 58.6 ms (started: 2021-06-07 13:59:02 +00:00)

# %% [markdown]
# ## Figure 3.5:<a name='3.5'></a> <a name='gaussPlot2dSurf'></a>

# %% [markdown]
#   Visualization of a 2d Gaussian density as a surface plot. (a) Distribution using a full covariance matrix can be oriented at any angle. (b) Distribution using a diagonal covariance matrix must be parallel to the axis. (c) Distribution using a spherical covariance matrix must have a symmetric shape.
# Figure(s) generated by [gauss_plot_2d.py](https://github.com/probml/pyprobml/blob/master/scripts/gauss_plot_2d.py)

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 28.3 ms (started: 2021-06-07 13:59:02 +00:00)

# %%
google.colab.files.view("./gauss_plot_2d.py")
# %run gauss_plot_2d.py
# Out:
# time: 20.6 s (started: 2021-06-07 13:59:02 +00:00)

# %% [markdown]
# ## Figure 3.6:<a name='3.6'></a> <a name='gaussPlot2dContour'></a>

# %% [markdown]
#   Visualization of a 2d Gaussian density in terms of level sets of constant probability density. (a) A full covariance matrix has elliptical contours. (b) A diagonal covariance matrix is an  \bf axis aligned  ellipse. (c) A spherical covariance matrix has a circular shape.
# Figure(s) generated by [gauss_plot_2d.py](https://github.com/probml/pyprobml/blob/master/scripts/gauss_plot_2d.py)

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 30.7 ms (started: 2021-06-07 13:59:23 +00:00)

# %%
google.colab.files.view("./gauss_plot_2d.py")
# %run gauss_plot_2d.py
# Out:
# time: 20.1 s (started: 2021-06-07 13:59:23 +00:00)

# %% [markdown]
# ## Figure 3.7:<a name='3.7'></a> <a name='imputeMvn'></a>

# %% [markdown]
#   Illustration of data imputation using an MVN. (a) Visualization of the data matrix. Blank entries are missing (not observed). Blue are positive, green are negative. Area of the square is proportional to the value. (This is known as a  \bf Hinton diagram , named after Geoff Hinton, a famous ML researcher.) (b) True data matrix (hidden). (c) Mean of the posterior predictive distribution, based on partially observed data in that row, using the true model parameters.
# Figure(s) generated by [gauss_imputation_known_params_demo.py](https://github.com/probml/pyprobml/blob/master/scripts/gauss_imputation_known_params_demo.py)

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 35.6 ms (started: 2021-06-07 13:59:43 +00:00)

# %%
google.colab.files.view("./gauss_imputation_known_params_demo.py")
# %run gauss_imputation_known_params_demo.py
# Out:
# saving image to ../figures/gauss_impute_observed.pdf
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /pyprobml/scripts/gauss_imputation_known_params_demo.py in <module>()
#      45
#      46 if __name__ == "__main__":
# ---> 47     main()
#
# /pyprobml/scripts/gauss_imputation_known_params_demo.py in main()
#      31     pml.hinton_diagram(xmiss0, ax=plot_1.gca())
#      32     plot_1.suptitle('Observed')
# ---> 33     pml.savefig("gauss_impute_observed.pdf", dpi=300)
#      34
#      35     plot_2 = plt.figure(2)
#
# /pyprobml/scripts/pyprobml_utils.py in savefig(fname, *args, **kwargs)
#      27
#      28 def savefig(fname, *args, **kwargs):
# ---> 29     save_fig(fname, *args, **kwargs)
#      30
#      31 from matplotlib.patches import Ellipse, transforms
#
# /pyprobml/scripts/pyprobml_utils.py in save_fig(fname, *args, **kwargs)
#      23     print('saving image to {}'.format(fname_full))
#      24     #plt.tight_layout()
# ---> 25     plt.savefig(fname_full,  dpi=300, *args, **kwargs)
#      26
#      27
#
# TypeError: savefig() got multiple values for keyword argument 'dpi'
# time: 408 ms (started: 2021-06-07 13:59:43 +00:00)

# %% [markdown]
# ## Figure 3.8:<a name='3.8'></a> <a name='gauss2dupdate'></a>

# %% [markdown]
#   Illustration of Bayesian inference for a 2d Gaussian random vector $\mathbf  z $. (a) The data is generated from $\mathbf  y _n \sim \mathcal  N (\mathbf  z ,\boldsymbol  \Sigma  _y)$, where $\mathbf  z =[0.5, 0.5]^  \mkern -1.5mu\mathsf  T   $ and $\boldsymbol  \Sigma  _y=0.1 [2, 1; 1, 1])$. We assume the sensor noise covariance $\boldsymbol  \Sigma  _y$ is known but $\mathbf  z $ is unknown. The black cross represents $\mathbf  z $. (b) The prior is $p(\mathbf  z ) = \mathcal  N (\mathbf  z |\boldsymbol  0 ,0.1 \mathbf  I _2)$. (c) We show the posterior after 10 data points have been observed.
# Figure(s) generated by [gaussInferParamsMean2d.m](https://github.com/probml/pmtk3/blob/master/demos/gaussInferParamsMean2d.m)

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 23.9 ms (started: 2021-06-07 13:59:44 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_3.8.png")
# Out:
# <PIL.Image.Image image mode=RGB size=1429x480 at 0x7F0B6E7F15D0>
# time: 82 ms (started: 2021-06-07 13:59:44 +00:00)

# %% [markdown]
# ## Figure 3.9:<a name='3.9'></a> <a name='demoGaussBayes2dUnequal'></a>

# %% [markdown]
#   We observe $\mathbf  y _1=(0,-1)$ (red cross) and $\mathbf  y _2=(1,0)$ (green cross) and estimate $\mathbb  E \left [ \mathbf  z |\mathbf  y _1,\mathbf  y _2 \right ]$ (black cross). (a) Equally reliable sensors, so the posterior mean estimate is in between the two circles. (b) Sensor 2 is more reliable, so the estimate shifts more towards the green circle. (c) Sensor 1 is more reliable in the vertical direction, Sensor 2 is more reliable in the horizontal direction. The estimate is an appropriate combination of the two measurements.
# Figure(s) generated by [sensor_fusion_2d.py](https://github.com/probml/pyprobml/blob/master/scripts/sensor_fusion_2d.py)

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 35.7 ms (started: 2021-06-07 13:59:44 +00:00)

# %%
google.colab.files.view("./sensor_fusion_2d.py")
# %run sensor_fusion_2d.py
# Out:
# time: 974 ms (started: 2021-06-07 13:59:44 +00:00)

# %% [markdown]
# ## Figure 3.10:<a name='3.10'></a> <a name='gmm3'></a>

# %% [markdown]
#   A mixture of 3 Gaussians in 2d. (a) We show the contours of constant probability for each component in the mixture. (b) A surface plot of the overall density. Adapted from Figure 2.23 of <a href='#BishopBook'>[Bis06]</a> .
# Figure(s) generated by [mixGaussPlotDemo.py](https://github.com/probml/pyprobml/blob/master/scripts/mixGaussPlotDemo.py)

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 24.7 ms (started: 2021-06-07 13:59:45 +00:00)

# %%
google.colab.files.view("./mixGaussPlotDemo.py")
# %run mixGaussPlotDemo.py
# Out:
# time: 2.08 s (started: 2021-06-07 13:59:45 +00:00)

# %% [markdown]
# ## Figure 3.11:<a name='3.11'></a> <a name='gmm2d'></a>

# %% [markdown]
#   (a) Some data in 2d. (b) A possible clustering using $K=3$ clusters computed using a GMM.
# Figure(s) generated by [gmm_2d.py](https://github.com/probml/pyprobml/blob/master/scripts/gmm_2d.py)

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 31.8 ms (started: 2021-06-07 13:59:47 +00:00)

# %%
google.colab.files.view("./gmm_2d.py")
# %run gmm_2d.py
# Out:
# integral of pdf 1.0000000000000422
# /pyprobml/scripts/gmm_2d.py:109: RuntimeWarning: divide by zero encountered in double_scalars
#   angle = np.arctan(u[1] / u[0])
# time: 12.3 s (started: 2021-06-07 13:59:47 +00:00)

# %% [markdown]
# ## Figure 3.12:<a name='3.12'></a> <a name='mixBernoulliMnist'></a>

# %% [markdown]
#   We fit a mixture of 20 Bernoullis to the binarized MNIST digit data. We visualize the estimated cluster means $ \boldsymbol  \mu   _k$. The numbers on top of each image represent the estimated mixing weights $ \pi  _k$. No labels were used when training the model.
# Figure(s) generated by [mixBerMnistEM.py](https://github.com/probml/pyprobml/blob/master/scripts/mixBerMnistEM.py)

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 29.3 ms (started: 2021-06-07 13:59:59 +00:00)

# %%
google.colab.files.view("./mixBerMnistEM.py")
# %run mixBerMnistEM.py
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# iteration 0:
#    [0.05219522 0.06448333 0.03340751 0.05573492 0.05958519 0.04960204
#  0.04382505 0.05883487 0.03604797 0.04737552 0.04993534 0.05565193
#  0.03583911 0.04033586 0.04633295 0.05333046 0.06199275 0.05318366
#  0.03723786 0.06506844]:
#    -4.72965e+05
# iteration 1:
#    [0.05126593 0.06389205 0.03280406 0.05530994 0.05908693 0.0487221
#  0.04302358 0.05835097 0.03539434 0.0465067  0.04904911 0.05522852
#  0.03518934 0.03960063 0.04548392 0.05237963 0.06144885 0.05223573
#  0.03656153 0.06446612]:
#    -2.39489e+05
# iteration 2:
#    [0.05111776 0.06447127 0.03282244 0.05884437 0.06115477 0.04854497
#  0.04320409 0.06068387 0.03545146 0.04674366 0.04887471 0.05879756
#  0.03524549 0.03972641 0.04570404 0.0522437  0.06274387 0.05209603
#  0.03663845 0.06489108]:
#    -2.29982e+05
# iteration 3:
#    [0.04203166 0.04278563 0.03114286 0.10614968 0.0404508  0.04021897
#  0.05381986 0.0430703  0.0361903  0.06261481 0.04036458 0.11184861
#  0.0359508  0.04565861 0.05996575 0.04303094 0.03893841 0.04279068
#  0.03878893 0.04418782]:
#    -2.14159e+05
# iteration 4:
#    [0.02513371 0.05712955 0.01465954 0.05298362 0.04030394 0.07999538
#  0.04048413 0.10045968 0.01453031 0.11178549 0.05604789 0.09139953
#  0.01503812 0.02081908 0.08008859 0.02430699 0.02107678 0.0237376
#  0.01553053 0.11448953]:
#    -1.94176e+05
# time: 58.9 s (started: 2021-06-07 13:59:59 +00:00)

# %% [markdown]
# ## Figure 3.13:<a name='3.13'></a> <a name='sprinkler'></a>

# %% [markdown]
#   Water sprinkler PGM with corresponding binary CPTs. T and F stand for true and false.

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 42.8 ms (started: 2021-06-07 14:00:58 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_3.13.png")
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F0B2A021290>
# time: 112 ms (started: 2021-06-07 14:00:58 +00:00)

# %% [markdown]
# ## Figure 3.14:<a name='3.14'></a> <a name='ARDGM'></a>

# %% [markdown]
#   Illustration of first and second order autoregressive (Markov) models.

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 46.7 ms (started: 2021-06-07 14:00:58 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_3.14_A.png")
# Out:
# <PIL.Image.Image image mode=RGB size=2520x480 at 0x7F0B29F71E50>
# time: 111 ms (started: 2021-06-07 14:00:58 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_3.14_B.png")
# Out:
# <PIL.Image.Image image mode=RGB size=1737x480 at 0x7F0B29F0F650>
# time: 93.7 ms (started: 2021-06-07 14:00:59 +00:00)

# %% [markdown]
# ## Figure 3.15:<a name='3.15'></a> <a name='platesIID'></a>

# %% [markdown]
#   Left: data points $\mathbf  y _n$ are conditionally independent given $\boldsymbol  \theta  $. Right: Same model, using plate notation. This represents the same model as the one on the left, except the repeated $\mathbf  y _n$ nodes are inside a box, known as a plate; the number in the lower right hand corner, $N$, specifies the number of repetitions of the $\mathbf  y _n$ node.

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 70.7 ms (started: 2021-06-07 14:00:59 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_3.15.png")
# Out:
# <PIL.Image.Image image mode=RGB size=821x480 at 0x7F0B29F19050>
# time: 68.9 ms (started: 2021-06-07 14:00:59 +00:00)

# %% [markdown]
# ## Figure 3.16:<a name='3.16'></a> <a name='gmmDgm'></a>

# %% [markdown]
#   A Gaussian mixture model represented as a graphical model.

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 62.7 ms (started: 2021-06-07 14:00:59 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_3.16.png")
# Out:
# <PIL.Image.Image image mode=RGB size=185x480 at 0x7F0B29F19C90>
# time: 56.3 ms (started: 2021-06-07 14:00:59 +00:00)

# %% [markdown]
# ## References:
#  <a name='BishopBook'>[Bis06]</a> C. Bishop "Pattern recognition and machine learning". (2006).
#
# <a name='VonKugelgen2020'>[JLB20]</a> v. Julius, G. Luigi and S. Bernhard. "Simpson's paradox in Covid-19 case fatality rates: amediation analysis of age-related causal effects". abs/2005.07180 (2020). arXiv: 2005.07180
