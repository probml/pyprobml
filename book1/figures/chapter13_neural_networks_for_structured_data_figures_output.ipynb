# %%
# Copyright 2021 Google LLC
# Use of this source code is governed by an MIT-style
# license that can be found in the LICENSE file or at
# https://opensource.org/licenses/MIT.
# Notebook authors: Kevin P. Murphy (murphyk@gmail.com)
# and Mahmoud Soliman (mjs@aucegypt.edu)

# This notebook reproduces figures for chapter 13 from the book
# "Probabilistic Machine Learning: An Introduction"
# by Kevin Murphy (MIT Press, 2021).
# Book pdf is available from http://probml.ai
# Out:
# time: 2.5 ms (started: 2021-05-11 14:35:15 +00:00)

# %% [markdown]
# <a href="https://opensource.org/licenses/MIT" target="_parent"><img src="https://img.shields.io/github/license/probml/pyprobml"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/probml/pyprobml/blob/master/book1/figures/chapter13_neural_networks_for_structured_data_figures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Figure 13.1:<a name='13.1'></a> <a name='xor'></a>

# %% [markdown]
#   (a) Illustration of the fact that the XOR function is not linearly separable, but can be separated by the two layer model using Heaviside activation functions. Adapted from Figure 10.6 of <a href='#Geron2019'>[Aur19]</a> .
# Figure(s) generated by [xor_heaviside.py](https://github.com/probml/pyprobml/blob/master/scripts/xor_heaviside.py)

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# running setup...
# finished!
# time: 18.2 s (started: 2021-05-11 14:35:15 +00:00)

# %%
google.colab.files.view("./xor_heaviside.py")
# %run xor_heaviside.py
# Out:
# saving image to ../figures/xor-heaviside.pdf
# saving image to ../figures/xor-sigmoid.pdf
# time: 767 ms (started: 2021-05-11 14:35:33 +00:00)

# %% [markdown]
# ## Figure 13.2:<a name='13.2'></a> <a name='activationFns2'></a>

# %% [markdown]
#   (a) Illustration of how the sigmoid function is linear for inputs near 0, but saturates for large positive and negative inputs. Adapted from 11.1 of <a href='#Geron2019'>[Aur19]</a> . (b) Plots of some popular non-saturating activation functions.
# Figure(s) generated by [activation_fun_plot.py](https://github.com/probml/pyprobml/blob/master/scripts/activation_fun_plot.py)

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 23.1 ms (started: 2021-05-11 14:35:34 +00:00)

# %%
google.colab.files.view("./activation_fun_plot.py")
# %run activation_fun_plot.py
# Out:
# plot some activation functions
# time: 1.05 s (started: 2021-05-11 14:35:34 +00:00)

# %% [markdown]
# ## Figure 13.3:<a name='13.3'></a> <a name='mlp-playground'></a>

# %% [markdown]
#   An MLP with 2 hidden layers applied to a set of 2d points from 2 classes, shown in the top left corner. The visualizations associated with each hidden unit show the decision boundary at that part of the network. The final output is shown on the right. The input is $\mathbf  x \in \mathbb  R ^2$, the first layer activations are $\mathbf  z _1 \in \mathbb  R ^4$, the second layer activations are $\mathbf  z _2 \in \mathbb  R ^2$, and the final logit is $a_3 \in \mathbb  R $, which is converted to a probability using the sigmoid function. This is a screenshot from the interactive demo at   http://playground.tensorflow.org .

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 34 ms (started: 2021-05-11 14:35:35 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_13.3.png")
# Out:
# <PIL.Image.Image image mode=RGBA size=906x480 at 0x7F68BC307750>
# time: 191 ms (started: 2021-05-11 14:35:35 +00:00)

# %% [markdown]
# ## Figure 13.4:<a name='13.4'></a> <a name='mlpMnistStructure'></a>

# %% [markdown]
#   Structure of the MLP used for MNIST classification. Note that $100,480=(784+1) \times 128$, and $16,512 = (128+1) \times 128$.

# %% [markdown]
# To reproduce this figure, click the open in colab button: <a href="https://colab.research.google.com/github/https://colab.research.google.com/github/probml/pyprobml/blob/master/notebooks/mlp_mnist_tf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 31.5 ms (started: 2021-05-11 14:35:35 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_13.4.png")
# Out:
# <PIL.Image.Image image mode=RGBA size=1080x480 at 0x7F68BAA45950>
# time: 85 ms (started: 2021-05-11 14:35:35 +00:00)

# %% [markdown]
# ## Figure 13.5:<a name='13.5'></a> <a name='mlpMnist'></a>

# %% [markdown]
#   Results of applying an MLP (with 2 hidden layers with 128 units and 1 output layer with 10 units) to some MNIST images (cherry picked to include some errors). Red is incorrect, blue is correct. (a) After 1 epoch of training. (b) After 2 epochs.

# %% [markdown]
# To reproduce this figure, click the open in colab button: <a href="https://colab.research.google.com/github/https://colab.research.google.com/github/probml/pyprobml/blob/master/notebooks/mlp_mnist_tf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 29.5 ms (started: 2021-05-11 14:35:35 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_13.5_A.png")
# Out:
# <PIL.Image.Image image mode=RGBA size=597x480 at 0x7F68BAA48A10>
# time: 57.5 ms (started: 2021-05-11 14:35:35 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_13.5_B.png")
# Out:
# <PIL.Image.Image image mode=RGBA size=597x480 at 0x7F68DAA98F10>
# time: 73.2 ms (started: 2021-05-11 14:35:35 +00:00)

# %% [markdown]
# ## Figure 13.6:<a name='13.6'></a> <a name='mlpImdbStructure'></a>

# %% [markdown]
#   Structure of the MLP used for IMDB review classification. We use a vocabulary size of $V=1000$, an embedding size of $E=16$, and a hidden layer of size $16$. The embedding matrix $\mathbf  W _1$ has size $10,000 \times 16$, the hidden layer (labeled ``dense'') has a weight matrix $\mathbf  W _2$ of size $16 \times 16$ and bias $\mathbf  b _2$ of size 16 (note that $16 \times 16 + 16 = 272$), and the final layer (labeled ``dense\_1'') has a weight vector $\mathbf  w _3$ of size $16$ and a bias $b_3$ of size 1. The global average pooling layer has no free parameters.

# %% [markdown]
# To reproduce this figure, click the open in colab button: <a href="https://colab.research.google.com/github/https://colab.research.google.com/github/probml/pyprobml/blob/master/notebooks/mlp_imdb_tf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 31.9 ms (started: 2021-05-11 14:35:36 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_13.6.png")
# Out:
# <PIL.Image.Image image mode=RGBA size=999x480 at 0x7F68BAA45690>
# time: 71.5 ms (started: 2021-05-11 14:35:36 +00:00)

# %% [markdown]
# ## Figure 13.7:<a name='13.7'></a> <a name='twoHeaded'></a>

# %% [markdown]
#   Illustration of an MLP with a shared ``backbone'' and two output ``heads'', one for predicting the mean and one for predicting the variance. From   https://brendanhasz.github.io/2019/07/23/bayesian-density-net.html . Used with kind permission of Brendan Hasz.

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 40.1 ms (started: 2021-05-11 14:35:36 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_13.7.png")
# Out:
# <PIL.Image.Image image mode=RGB size=1129x480 at 0x7F68BAA529D0>
# time: 92.5 ms (started: 2021-05-11 14:35:36 +00:00)

# %% [markdown]
# ## Figure 13.8:<a name='13.8'></a> <a name='twoHeadedSineWaves'></a>

# %% [markdown]
#   Illustration of predictions from an MLP fit using MLE to a 1d regression dataset with growing noise. (a) Output variance is input-dependent, as in \cref  fig:twoHeaded . (b) Mean is computed using same model as in (a), but output variance is treated as a fixed parameter $\sigma ^2$, which is estimated by MLE after training, as in \cref  sec:linregSigmaMLE .

# %% [markdown]
# To reproduce this figure, click the open in colab button: <a href="https://colab.research.google.com/github/https://colab.research.google.com/github/probml/pyprobml/blob/master/notebooks/mlp_1d_regression_hetero_tfp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 37.2 ms (started: 2021-05-11 14:35:36 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_13.8_A.png")
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F68BAA64090>
# time: 58 ms (started: 2021-05-11 14:35:36 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_13.8_B.png")
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F68BAA64A90>
# time: 67.3 ms (started: 2021-05-11 14:35:36 +00:00)

# %% [markdown]
# ## Figure 13.9:<a name='13.9'></a> <a name='reluPolytope2d'></a>

# %% [markdown]
#   A decomposition of $\mathbb  R ^2$ into a finite set of linear decision regions produced by an MLP with \ensuremath  \mathrm  ReLU  \xspace activations with (a) one hidden layer of 25 hidden units and (b) two hidden layers. From Figure 1 of <a href='#Hein2019'>[MMJ19]</a> . Used with kind permission of Maksym Andriuschenko.

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 31.8 ms (started: 2021-05-11 14:35:36 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_13.9_A.png")
# Out:
# <PIL.Image.Image image mode=RGBA size=730x480 at 0x7F68BAA52850>
# time: 125 ms (started: 2021-05-11 14:35:36 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_13.9_B.png")
# Out:
# <PIL.Image.Image image mode=RGBA size=724x480 at 0x7F68BAA64E10>
# time: 113 ms (started: 2021-05-11 14:35:36 +00:00)

# %% [markdown]
# ## Figure 13.10:<a name='13.10'></a> <a name='axons'></a>

# %% [markdown]
#   Illustration of two neurons connected together in a ``circuit''. The output axon of the left neuron makes a synaptic connection with the dendrites of the cell on the right Electrical charges, in the form of ion flows, allow the cells to communicate. From   https://en.wikipedia.org/wiki/Neuron . Used with kind permission of Wikipedia author BruceBlaus.

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 25.1 ms (started: 2021-05-11 14:35:36 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_13.10.png")
# Out:
# <PIL.Image.Image image mode=RGB size=744x480 at 0x7F68BC33D6D0>
# time: 160 ms (started: 2021-05-11 14:35:36 +00:00)

# %% [markdown]
# ## Figure 13.11:<a name='13.11'></a> <a name='DNN-size-vs-time'></a>

# %% [markdown]
#   Plot of neural network sizes over time. Models 1, 2, 3 and 4 correspond to the perceptron <a href='#Rosenblatt58'>[Ros58]</a> , the adaptive linear unit <a href='#Widrow1960'>[BH60]</a>  the neocognitron <a href='#Fukushima1980'>[K80]</a> , and the first MLP trained by backprop <a href='#Rumelhart86'>[RHW86]</a> . From Figure 1.11 of <a href='#GoodfellowBook'>[GBC16]</a> . Used with kind permission of Ian Goodfellow.

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 29.3 ms (started: 2021-05-11 14:35:37 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_13.11.png")
# Out:
# <PIL.Image.Image image mode=RGB size=958x480 at 0x7F68BAA48F50>
# time: 96.3 ms (started: 2021-05-11 14:35:37 +00:00)

# %% [markdown]
# ## Figure 13.12:<a name='13.12'></a> <a name='feedforward-graph'></a>

# %% [markdown]
#   A simple linear-chain feedforward model with 4 layers. Here $\mathbf  x $ is the input and $\mathbf  o $ is the output. From <a href='#Blondel2020'>[Mat20]</a> .

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 46.4 ms (started: 2021-05-11 14:35:37 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_13.12.png")
# Out:
# <PIL.Image.Image image mode=RGB size=2325x480 at 0x7F68BAA70890>
# time: 81.9 ms (started: 2021-05-11 14:35:37 +00:00)

# %% [markdown]
# ## Figure 13.13:<a name='13.13'></a> <a name='computation-graph'></a>

# %% [markdown]
#   An example of a computation graph with 2 (scalar) inputs and 1 (scalar) output. From <a href='#Blondel2020'>[Mat20]</a> .

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 33.3 ms (started: 2021-05-11 14:35:37 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_13.13.png")
# Out:
# <PIL.Image.Image image mode=RGB size=1641x480 at 0x7F68BAA70910>
# time: 78 ms (started: 2021-05-11 14:35:37 +00:00)

# %% [markdown]
# ## Figure 13.14:<a name='13.14'></a> <a name='backwardsDiff'></a>

# %% [markdown]
#   Notation for automatic differentiation at node $j$ in a computation graph. From <a href='#Blondel2020'>[Mat20]</a> .

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 22.3 ms (started: 2021-05-11 14:35:37 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_13.14.png")
# Out:
# <PIL.Image.Image image mode=RGB size=1281x480 at 0x7F68BAA70350>
# time: 65.8 ms (started: 2021-05-11 14:35:37 +00:00)

# %% [markdown]
# ## Figure 13.15:<a name='13.15'></a> <a name='compGraphD2l'></a>

# %% [markdown]
#   Computation graph for an MLP with input $\mathbf  x $, hidden layer $\mathbf  h $, output $\mathbf  o $, loss function $L=\ell (\mathbf  o ,y)$, an $\ell _2$ regularizer $s$ on the weights, and total loss $J=L+s$. From Figure 4.7.1 of <a href='#dive'>[Zha+20]</a> . Used with kind permission of Aston Zhang.

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 31.7 ms (started: 2021-05-11 14:35:37 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_13.15.png")
# Out:
# <PIL.Image.Image image mode=RGB size=1480x480 at 0x7F68BAA48E90>
# time: 80.4 ms (started: 2021-05-11 14:35:37 +00:00)

# %% [markdown]
# ## Figure 13.16:<a name='13.16'></a> <a name='func-ad-triangle'></a>

# %% [markdown]
#   A circuit for a function $f$ over three primitives, and its decomposition into two circuits without fan-out. Input nodes are drawn in green.\relax

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 42 ms (started: 2021-05-11 14:35:37 +00:00)

# %% [markdown]
# ## Figure 13.17:<a name='13.17'></a> <a name='activationWithGrad'></a>

# %% [markdown]
#   (a) Some popular activation functions. (b) Plot of their gradients.

# %% [markdown]
# To reproduce this figure, click the open in colab button: <a href="https://colab.research.google.com/github/https://colab.research.google.com/github/probml/pyprobml/blob/master/notebooks/activation_fun_deriv_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 25.1 ms (started: 2021-05-11 14:35:37 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_13.17_A.png")
# Out:
# <PIL.Image.Image image mode=RGB size=960x480 at 0x7F68BAA45D50>
# time: 64 ms (started: 2021-05-11 14:35:37 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_13.17_B.png")
# Out:
# <PIL.Image.Image image mode=RGB size=960x480 at 0x7F68BAA644D0>
# time: 67 ms (started: 2021-05-11 14:35:37 +00:00)

# %% [markdown]
# ## Figure 13.18:<a name='13.18'></a> <a name='residualVanishing'></a>

# %% [markdown]
#   (a) Illustration of a residual block. (b) Illustration of why adding residual connections can help when training a very deep model. Adapted from Figure 14.16 of <a href='#Geron2019'>[Aur19]</a> .

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 28.5 ms (started: 2021-05-11 14:35:37 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_13.18_A.png")
# Out:
# <PIL.Image.Image image mode=RGB size=1199x480 at 0x7F68BAA6EB10>
# time: 56 ms (started: 2021-05-11 14:35:37 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_13.18_B.png")
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F68BAA6B210>
# time: 98.8 ms (started: 2021-05-11 14:35:38 +00:00)

# %% [markdown]
# ## Figure 13.19:<a name='13.19'></a> <a name='mlpHyper'></a>

# %% [markdown]
#   The effects of changing the hyperparameters on an MLP with one hidden layer. (a) Random functions sampled from a Gaussian prior with hyperparameters $\alpha _ 1 =5$, $\beta _1=1$, $\alpha _2=1$, $\beta _2=1$. (b) Increasing $\alpha _ 1 $ by factor of 5. (c) Increasing $\beta _ 1 $ by factor of 5. (d) Inreasing $\alpha _ 2 $ by factor of 5.
# Figure(s) generated by [mlpPriorsDemo2.py](https://github.com/probml/pyprobml/blob/master/scripts/mlpPriorsDemo2.py)

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 29.5 ms (started: 2021-05-11 14:35:38 +00:00)

# %%
google.colab.files.view("./mlpPriorsDemo2.py")
# %run mlpPriorsDemo2.py
# Out:
# saving image to ../figures/mlpPriors-0.pdf
# saving image to ../figures/mlpPriors-1.pdf
# saving image to ../figures/mlpPriors-2.pdf
# saving image to ../figures/mlpPriors-3.pdf
# time: 1.12 s (started: 2021-05-11 14:35:38 +00:00)

# %% [markdown]
# ## Figure 13.20:<a name='13.20'></a> <a name='multiGPU'></a>

# %% [markdown]
#   Calculation of minibatch stochastic gradient using data parallelism and two GPUs. From Figure 12.5.2 of <a href='#dive'>[Zha+20]</a> . Used with kind permission of Aston Zhang.

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 31.2 ms (started: 2021-05-11 14:35:39 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_13.20.png")
# Out:
# <PIL.Image.Image image mode=RGB size=1066x480 at 0x7F68C4561150>
# time: 93.3 ms (started: 2021-05-11 14:35:39 +00:00)

# %% [markdown]
# ## Figure 13.21:<a name='13.21'></a> <a name='sparseNnet'></a>

# %% [markdown]
#   (a) A deep but sparse neural network. The connections are pruned using $\ell _1$ regularization. At each level, nodes numbered 0 are clamped to 1, so their outgoing weights correspond to the offset/bias terms. (b) Predictions made by the model on the training set.
# Figure(s) generated by [sparseNnetDemo.m](https://github.com/probml/pmtk3/blob/master/demos/sparseNnetDemo.m)

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 29.7 ms (started: 2021-05-11 14:35:39 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_13.21.png")
# Out:
# <PIL.Image.Image image mode=RGB size=599x480 at 0x7F68C4593510>
# time: 76.4 ms (started: 2021-05-11 14:35:39 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_13.21.png")
# Out:
# <PIL.Image.Image image mode=RGB size=599x480 at 0x7F68C454A790>
# time: 69.8 ms (started: 2021-05-11 14:35:39 +00:00)

# %% [markdown]
# ## Figure 13.22:<a name='13.22'></a> <a name='dropout'></a>

# %% [markdown]
#   Illustration of dropout. (a) A standard neural net with 2 hidden layers. (b) An example of a thinned net produced by applying dropout with $p_0=0.5$. Units that have been dropped out are marked with an x. From Figure 1 of <a href='#Srivastava2014'>[Nit+14]</a> . Used with kind permission of Geoff Hinton.

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 28.2 ms (started: 2021-05-11 14:35:39 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_13.22_A.png")
# Out:
# <PIL.Image.Image image mode=RGB size=432x480 at 0x7F68C45267D0>
# time: 107 ms (started: 2021-05-11 14:35:39 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_13.22_B.png")
# Out:
# <PIL.Image.Image image mode=RGB size=432x480 at 0x7F68C454A410>
# time: 88.7 ms (started: 2021-05-11 14:35:39 +00:00)

# %% [markdown]
# ## Figure 13.23:<a name='13.23'></a> <a name='flatMinima'></a>

# %% [markdown]
#   Flat vs sharp minima. From Figures 1 and 2 of <a href='#Hochreiter1997'>[SJ97]</a> . Used with kind permission of Jürgen Schmidhuber.

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 35.2 ms (started: 2021-05-11 14:35:39 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_13.23.png")
# Out:
# <PIL.Image.Image image mode=RGB size=621x480 at 0x7F68C454A710>
# time: 96.5 ms (started: 2021-05-11 14:35:39 +00:00)

# %% [markdown]
# ## Figure 13.24:<a name='13.24'></a> <a name='sgd-minima-unstable'></a>

# %% [markdown]
#   Each curve shows how the loss varies across parameter values for a given minibatch. (a) A stable local minimum. (b) An unstable local minimum. From   https://www.inference.vc/notes-on-the-origin-of-implicit-regularization-in-stochastic-gradient-descent/ . Used with kind permission of Ferenc Huszar

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 29.9 ms (started: 2021-05-11 14:35:40 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_13.24_A.png")
# Out:
# <PIL.Image.Image image mode=RGB size=339x480 at 0x7F68C44ABAD0>
# time: 96.2 ms (started: 2021-05-11 14:35:40 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_13.24_B.png")
# Out:
# <PIL.Image.Image image mode=RGB size=339x480 at 0x7F68C4526350>
# time: 93.1 ms (started: 2021-05-11 14:35:40 +00:00)

# %% [markdown]
# ## Figure 13.25:<a name='13.25'></a> <a name='xorRBF'></a>

# %% [markdown]
#   (a) xor truth table. (b) Fitting a linear logistic regression classifier using degree 10 polynomial expansion. (c) Same model, but using an RBF kernel with centroids specified by the 4 black crosses.
# Figure(s) generated by [logregXorDemo.py](https://github.com/probml/pyprobml/blob/master/scripts/logregXorDemo.py)

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 24.8 ms (started: 2021-05-11 14:35:40 +00:00)

# %%
google.colab.files.view("./logregXorDemo.py")
# %run logregXorDemo.py
# Out:
# time: 2.33 s (started: 2021-05-11 14:35:40 +00:00)

# %% [markdown]
# ## Figure 13.26:<a name='13.26'></a> <a name='rbfDemo'></a>

# %% [markdown]
#   Linear regression using 10 equally spaced RBF basis functions in 1d. Left column: fitted function. Middle column: basis functions evaluated on a grid. Right column: design matrix. Top to bottom we show different bandwidths for the kernel function: $\sigma =0.5, 10, 50$.
# Figure(s) generated by [linregRbfDemo.py](https://github.com/probml/pyprobml/blob/master/scripts/linregRbfDemo.py)

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 26.7 ms (started: 2021-05-11 14:35:42 +00:00)

# %%
google.colab.files.view("./linregRbfDemo.py")
# %run linregRbfDemo.py
# Out:
# saving image to ../figures/../figures/rbfDemoALL.pdf
# time: 3.51 s (started: 2021-05-11 14:35:42 +00:00)

# %% [markdown]
# ## Figure 13.27:<a name='13.27'></a> <a name='mixexp'></a>

# %% [markdown]
#   (a) Some data from a one-to-many function. (b) The responsibilities of each expert for the input domain. (c) Prediction of each expert. (d) Overeall prediction. Mean is red cross, mode is black square. Adapted from Figures 5.20 and 5.21 of <a href='#BishopBook'>[Bis06]</a> .
# Figure(s) generated by [mixexpDemoOneToMany.m](https://github.com/probml/pmtk3/blob/master/demos/mixexpDemoOneToMany.m)

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 47.6 ms (started: 2021-05-11 14:35:46 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_13.27.png")
# Out:
# <PIL.Image.Image image mode=RGB size=581x480 at 0x7F68B1A89210>
# time: 64.6 ms (started: 2021-05-11 14:35:46 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_13.27.png")
# Out:
# <PIL.Image.Image image mode=RGB size=581x480 at 0x7F68B19FE4D0>
# time: 65.1 ms (started: 2021-05-11 14:35:46 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_13.27.png")
# Out:
# <PIL.Image.Image image mode=RGB size=581x480 at 0x7F68B19FE710>
# time: 73.7 ms (started: 2021-05-11 14:35:46 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_13.27.png")
# Out:
# <PIL.Image.Image image mode=RGB size=581x480 at 0x7F68B1990D10>
# time: 79.7 ms (started: 2021-05-11 14:35:46 +00:00)

# %% [markdown]
# ## Figure 13.28:<a name='13.28'></a> <a name='deepMOE'></a>

# %% [markdown]
#   Deep MOE with $m$ experts, represented as a neural network. From Figure 1 of <a href='#Chazan2017'>[SJS17]</a> . Used with kind permission of Jacob Goldberger.

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 33.3 ms (started: 2021-05-11 14:35:46 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_13.28.png")
# Out:
# <PIL.Image.Image image mode=RGBA size=734x480 at 0x7F68B19A9CD0>
# time: 68.6 ms (started: 2021-05-11 14:35:46 +00:00)

# %% [markdown]
# ## Figure 13.29:<a name='13.29'></a> <a name='HMENN'></a>

# %% [markdown]
#   A 2-level hierarchical mixture of experts as a neural network. The top gating network chooses between the left and right expert, shown by the large boxes; the left and right experts themselves choose between their left and right sub-experts.

# %%
#@title Click me to run setup { display-mode: "form" }
try:
  if PYPROBML_SETUP_ALREADY_RUN:
    print('skipping setup')
except:
  PYPROBML_SETUP_ALREADY_RUN = True
  print('running setup...')
  # !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null 
  # %cd -q /pyprobml/scripts
  import pyprobml_utils as pml
  import colab_utils
  import os
  os.environ["PYPROBML"] = ".." # one above current scripts directory
  import google.colab 
  from google.colab.patches import cv2_imshow
  # %reload_ext autoreload 
  # %autoreload 2
  def show_image(img_path,size=None,ratio=None):
      img = colab_utils.image_resize(img_path, size)
      cv2_imshow(img)
  print('finished!')
# Out:
# skipping setup
# time: 34.6 ms (started: 2021-05-11 14:35:46 +00:00)

# %%
show_image("/pyprobml/book1/figures/images/Figure_13.29.png")
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F68B19A84D0>
# time: 88.7 ms (started: 2021-05-11 14:35:46 +00:00)

# %% [markdown]
# ## References:
#  <a name='Geron2019'>[Aur19]</a> G. Aur'elien "Hands-On Machine Learning with Scikit-Learn and TensorFlow: Concepts, Tools, and Techniques for BuildingIntelligent Systems (2nd edition)". (2019).
#
# <a name='Widrow1960'>[BH60]</a> W. Bernard and H. HoffMarcianE. "Adaptive Switching Circuits". (1960).
#
# <a name='BishopBook'>[Bis06]</a> C. Bishop "Pattern recognition and machine learning". (2006).
#
# <a name='GoodfellowBook'>[GBC16]</a> I. Goodfellow, Y. Bengio and A. Courville. "Deep Learning". (2016).
#
# <a name='Fukushima1980'>[K80]</a> F. K "Neocognitron: a self organizing neural network model for amechanism of pattern recognition unaffected by shift in position". In: Biol. Cybern. (1980).
#
# <a name='Hein2019'>[MMJ19]</a> H. Matthias, A. Maksym and B. Julian. "Why ReLU networks yield high-confidence predictions far awayfrom the training data and how to mitigate the problem". (2019).
#
# <a name='Blondel2020'>[Mat20]</a> B. Mathieu "Automatic differentiation". (2020).
#
# <a name='Srivastava2014'>[Nit+14]</a> S. Nitish, H. GeoffRey, K. Alex, S. Ilya and S. Ruslan. "Dropout: A Simple Way to Prevent Neural Networks from Over tting". In: jmlr (2014).
#
# <a name='Rumelhart86'>[RHW86]</a> D. Rumelhart, G. Hinton and R. Williams. "Learning internal representations by error propagation". (1986).
#
# <a name='Rosenblatt58'>[Ros58]</a> F. Rosenblatt "The Perceptron: A Probabilistic Model for Information Storage and Organization in the Brain". In: Psychological Review (1958).
#
# <a name='Hochreiter1997'>[SJ97]</a> H. S and S. J. "Flat minima". In: Neural Comput. (1997).
#
# <a name='Chazan2017'>[SJS17]</a> C. ShlomoE, G. Jacob and G. Sharon. "Speech Enhancement using a Deep Mixture of Experts". abs/1703.09302 (2017). arXiv: 1703.09302
#
# <a name='dive'>[Zha+20]</a> A. Zhang, Z. Lipton, M. Li and A. Smola. "Dive into deep learning". (2020).
