# %% [markdown]
#  (a) A single decision tree. (b-c) Bagging ensemble of 10 and 50 trees. (d) Random forest of 50 trees. Adapted from Figure 7.5 of \citep{Geron2019}. Generated by [bagging_trees.ipynb](https://github.com/probml/pyprobml/blob/master/notebooks/book1/18/bagging_trees.ipynb) and [rf_demo_2d.ipynb](https://github.com/probml/pyprobml/blob/master/notebooks/book1/18/rf_demo_2d.ipynb).
