# %% [markdown]
# (a) Illustration of local and global minimum in 1d. Generated by [extrema_fig_1d.ipynb](https://colab.research.google.com/github/probml/pyprobml/blob/master/notebooks/book1/08/extrema_fig_1d.ipynb) . (b) Illustration of a saddle point in 2d. Generated by [saddle.ipynb](https://colab.research.google.com/github/probml/pyprobml/blob/master/notebooks/book1/08/saddle.ipynb) .
