# %% [markdown]
# (a) Illustration of the Neyman-Pearson hypothesis testing paradigm. Generated by [neymanPearson2.ipynb](https://colab.research.google.com/github/probml/pyprobml/blob/master/notebooks/book1/05/neymanPearson2.ipynb) . (b) Two hypothetical two-sided power curves. B dominates A. Adapted from Figure 6.3.5 of \citep{Larsen86}. Generated by [twoPowerCurves.ipynb](https://colab.research.google.com/github/probml/pyprobml/blob/master/notebooks/book1/05/twoPowerCurves.ipynb) .
