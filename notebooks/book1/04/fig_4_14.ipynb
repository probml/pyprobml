# %% [markdown]
#  (a) The Dirichlet distribution when $K=3$ defines a distribution over the simplex, which can be represented by the triangular surface. Points on this surface satisfy $0 \leq \theta _k \leq 1$ and $\DOTSB \sum@ \slimits@ _{k=1}^3 \theta _k = 1$. Generated by [dirichlet_3d_triangle_plot.ipynb](https://github.com/probml/pyprobml/blob/master/notebooks/book1/04/dirichlet_3d_triangle_plot.ipynb). (b) Plot of the Dirichlet density for $\oset{\smallsmil
