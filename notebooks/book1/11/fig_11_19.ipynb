# %% [markdown]
# (a) Illustration of robust linear regression. Generated by [linregRobustDemoCombined.ipynb](https://colab.research.google.com/github/probml/pyprobml/blob/master/notebooks/book1/11/linregRobustDemoCombined.ipynb) . (b) Illustration of $\ell _2$, $\ell _1$, and Huber loss functions with $\delta =1.5$. Generated by [huberLossPlot.ipynb](https://colab.research.google.com/github/probml/pyprobml/blob/master/notebooks/book1/11/huberLossPlot.ipynb) .
