# %% [markdown]
# (a) The Dirichlet distribution when $K=3$ defines a distribution over the simplex, which can be represented by the triangular surface. Points on this surface satisfy $0 \leq \theta _c \leq 1$ and $ \sum@ @ _{c=1}^3 \theta _c = 1$. Generated by [dirichlet_3d_triangle_plot.ipynb](https://colab.research.google.com/github/probml/pyprobml/blob/master/notebooks/book2/02/dirichlet_3d_triangle_plot.ipynb). (b) Plot of the Dirichlet density for $\boldsymbol{\alpha }=(20,20,20)$. (c) Plot of the Dirichlet density for $\boldsymbol{\alpha }=(3,3,20)$. (d) Plot of the Dirichlet density for $\boldsymbol{\alpha }=(0.1, 0.1, 0.1)$. Generated by [dirichlet_3d_spiky_plot.ipynb](https://colab.research.google.com/github/probml/pyprobml/blob/master/notebooks/book2/02/dirichlet_3d_spiky_plot.ipynb).
