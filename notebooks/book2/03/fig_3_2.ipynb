# %% [markdown]
# Two distributions in which the mode (highest point) is untypical of the distribution; the mean (vertical red line) is a better summary. (a) A bimodal distribution. Generated by [bimodal_dist_plot.ipynb](https://colab.research.google.com/github/probml/pyprobml/blob/master/notebooks/book2/03/bimodal_dist_plot.ipynb). (b) A skewed $\mathrm{Ga}(1,1)$ distribution. Generated by [gamma_dist_plot.ipynb](https://colab.research.google.com/github/probml/pyprobml/blob/master/notebooks/book2/03/gamma_dist_plot.ipynb).
