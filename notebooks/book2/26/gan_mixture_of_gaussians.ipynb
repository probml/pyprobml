# %% [markdown]
# <a href="https://colab.research.google.com/github/probml/probml-notebooks/blob/main/notebooks/gan_mixture_of_gaussians.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook implements a Generative Adversarial Network to fit a synthetic dataset generated from a mixture of Gaussians in 2D.
#
# The code was adapted from the ODEGAN code here: https://github.com/deepmind/deepmind-research/blob/master/ode_gan/odegan_mog16.ipynb. The original notebook was created by **Chongli Qin‎**.
#
# Some modifications made by **Mihaela Rosca** [here](https://github.com/probml/probml-notebooks/blob/main/notebooks/gan_mog_mode_hopping.ipynb) were also incorporated.

# %% [markdown]
# # Imports

# %%
# %pip install -qq git+https://github.com/google/flax.git
# Out:
# Collecting git+https://github.com/google/flax.git
#   Cloning https://github.com/google/flax.git to /tmp/pip-req-build-vbnrs1r9
#   Running command git clone -q https://github.com/google/flax.git /tmp/pip-req-build-vbnrs1r9
# Requirement already satisfied (use --upgrade to upgrade): flax==0.5.2 from git+https://github.com/google/flax.git in /home/dhruvpatel/.local/lib/python3.8/site-packages
# Requirement already satisfied: PyYAML>=5.4.1 in /home/dhruvpatel/.local/lib/python3.8/site-packages (from flax==0.5.2) (6.0)
# Requirement already satisfied: jax>=0.3.2 in /home/dhruvpatel/.local/lib/python3.8/site-packages (from flax==0.5.2) (0.3.14)
# Requirement already satisfied: matplotlib in /home/dhruvpatel/.local/lib/python3.8/site-packages (from flax==0.5.2) (3.5.2)
# Requirement already satisfied: msgpack in /home/dhruvpatel/.local/lib/python3.8/site-packages (from flax==0.5.2) (1.0.4)
# Requirement already satisfied: numpy>=1.12 in /home/dhruvpatel/.local/lib/python3.8/site-packages (from flax==0.5.2) (1.23.0)
# Requirement already satisfied: optax in /home/dhruvpatel/.local/lib/python3.8/site-packages (from flax==0.5.2) (0.1.2)
# Requirement already satisfied: rich~=11.1 in /home/dhruvpatel/.local/lib/python3.8/site-packages (from flax==0.5.2) (11.2.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in /home/dhruvpatel/.local/lib/python3.8/site-packages (from flax==0.5.2) (4.2.0)
# Requirement already satisfied: absl-py in /home/dhruvpatel/.local/lib/python3.8/site-packages (from jax>=0.3.2->flax==0.5.2) (1.1.0)
# Requirement already satisfied: scipy>=1.5 in /home/dhruvpatel/.local/lib/python3.8/site-packages (from jax>=0.3.2->flax==0.5.2) (1.8.1)
# Requirement already satisfied: opt-einsum in /home/dhruvpatel/.local/lib/python3.8/site-packages (from jax>=0.3.2->flax==0.5.2) (3.3.0)
# Requirement already satisfied: etils[epath] in /home/dhruvpatel/.local/lib/python3.8/site-packages (from jax>=0.3.2->flax==0.5.2) (0.6.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/dhruvpatel/.local/lib/python3.8/site-packages (from matplotlib->flax==0.5.2) (9.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/dhruvpatel/.local/lib/python3.8/site-packages (from matplotlib->flax==0.5.2) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/dhruvpatel/.local/lib/python3.8/site-packages (from matplotlib->flax==0.5.2) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/dhruvpatel/.local/lib/python3.8/site-packages (from matplotlib->flax==0.5.2) (1.4.3)
# Requirement already satisfied: packaging>=20.0 in /home/dhruvpatel/.local/lib/python3.8/site-packages (from matplotlib->flax==0.5.2) (21.3)
# Requirement already satisfied: cycler>=0.10 in /home/dhruvpatel/.local/lib/python3.8/site-packages (from matplotlib->flax==0.5.2) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/dhruvpatel/.local/lib/python3.8/site-packages (from matplotlib->flax==0.5.2) (4.33.3)
# Requirement already satisfied: chex>=0.0.4 in /home/dhruvpatel/.local/lib/python3.8/site-packages (from optax->flax==0.5.2) (0.1.3)
# Requirement already satisfied: jaxlib>=0.1.37 in /home/dhruvpatel/.local/lib/python3.8/site-packages (from optax->flax==0.5.2) (0.3.10)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /home/dhruvpatel/.local/lib/python3.8/site-packages (from rich~=11.1->flax==0.5.2) (2.12.0)
# Requirement already satisfied: colorama<0.5.0,>=0.4.0 in /usr/lib/python3/dist-packages (from rich~=11.1->flax==0.5.2) (0.4.3)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /home/dhruvpatel/.local/lib/python3.8/site-packages (from rich~=11.1->flax==0.5.2) (0.9.1)
# Requirement already satisfied: importlib_resources; extra == "epath" in /home/dhruvpatel/.local/lib/python3.8/site-packages (from etils[epath]->jax>=0.3.2->flax==0.5.2) (5.8.0)
# Requirement already satisfied: zipp; extra == "epath" in /usr/lib/python3/dist-packages (from etils[epath]->jax>=0.3.2->flax==0.5.2) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib->flax==0.5.2) (1.14.0)
# Requirement already satisfied: dm-tree>=0.1.5 in /home/dhruvpatel/.local/lib/python3.8/site-packages (from chex>=0.0.4->optax->flax==0.5.2) (0.1.7)
# Requirement already satisfied: toolz>=0.9.0 in /home/dhruvpatel/.local/lib/python3.8/site-packages (from chex>=0.0.4->optax->flax==0.5.2) (0.11.2)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /home/dhruvpatel/.local/lib/python3.8/site-packages (from jaxlib>=0.1.37->optax->flax==0.5.2) (2.0)
# Building wheels for collected packages: flax
#   Building wheel for flax (setup.py) ... done
#   Created wheel for flax: filename=flax-0.5.2-py3-none-any.whl size=198021 sha256=a35e138463e092a55066bd0034fb0cff43506fa627bf3ad0e2bba2668707a696
#   Stored in directory: /tmp/pip-ephem-wheel-cache-22ytboxz/wheels/5d/cd/13/31d6d37c2228329484735564bfa16a48768d2232924588f91b
# Successfully built flax
# Note: you may need to restart the kernel to use updated packages.

# %%
from typing import Sequence
import matplotlib.pyplot as plt

# %matplotlib inline

# %pip install -qq jax==0.3.14
import jax
import jax.numpy as jnp

import flax.linen as nn
from flax.training import train_state

import optax

import functools
import scipy as sp
import math

try:
    import seaborn as sns
except ModuleNotFoundError:
    # %pip install -qq seaborn
    import seaborn as sns

try:
    import probml_utils as pml
    from probml_utils import savefig, latexify
except ModuleNotFoundError:
    # %pip install -qq git+https://github.com/probml/probml-utils.git
    import probml_utils as pml
    from probml_utils import savefig, latexify

rng = jax.random.PRNGKey(0)
# Out:
# Requirement already satisfied: jax==0.3.14 in /home/dhruvpatel/.local/lib/python3.8/site-packages (0.3.14)
# Requirement already satisfied: opt-einsum in /home/dhruvpatel/.local/lib/python3.8/site-packages (from jax==0.3.14) (3.3.0)
# Requirement already satisfied: scipy>=1.5 in /home/dhruvpatel/.local/lib/python3.8/site-packages (from jax==0.3.14) (1.8.1)
# Requirement already satisfied: absl-py in /home/dhruvpatel/.local/lib/python3.8/site-packages (from jax==0.3.14) (1.1.0)
# Requirement already satisfied: numpy>=1.19 in /home/dhruvpatel/.local/lib/python3.8/site-packages (from jax==0.3.14) (1.23.0)
# Requirement already satisfied: typing-extensions in /home/dhruvpatel/.local/lib/python3.8/site-packages (from jax==0.3.14) (4.2.0)
# Requirement already satisfied: etils[epath] in /home/dhruvpatel/.local/lib/python3.8/site-packages (from jax==0.3.14) (0.6.0)
# Requirement already satisfied: importlib_resources; extra == "epath" in /home/dhruvpatel/.local/lib/python3.8/site-packages (from etils[epath]->jax==0.3.14) (5.8.0)
# Requirement already satisfied: zipp; extra == "epath" in /usr/lib/python3/dist-packages (from etils[epath]->jax==0.3.14) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
latexify(width_scale_factor=3, fig_height=1.5)
# Out:
# /home/dhruvpatel/.local/lib/python3.8/site-packages/probml_utils/plotting.py:26: UserWarning: LATEXIFY environment variable not set, not latexifying
#   warnings.warn("LATEXIFY environment variable not set, not latexifying")

# %% [markdown]
# # Data Generation
#
# Data is generated from a 2D mixture of Gaussians.

# %%
@functools.partial(jax.jit, static_argnums=(1,))
def real_data(rng, batch_size):
    mog_mean = jnp.array(
        [
            [1.50, 1.50],
            [1.50, 0.50],
            [1.50, -0.50],
            [1.50, -1.50],
            [0.50, 1.50],
            [0.50, 0.50],
            [0.50, -0.50],
            [0.50, -1.50],
            [-1.50, 1.50],
            [-1.50, 0.50],
            [-1.50, -0.50],
            [-1.50, -1.50],
            [-0.50, 1.50],
            [-0.50, 0.50],
            [-0.50, -0.50],
            [-0.50, -1.50],
        ]
    )
    temp = jnp.tile(mog_mean, (batch_size // 16 + 1, 1))
    mus = temp[0:batch_size, :]
    return mus + 0.02 * jax.random.normal(rng, shape=(batch_size, 2))

# %% [markdown]
# # Plotting

# %%
def plot_on_ax(ax, values, contours=None, bbox=None, xlabel="", ylabel="", title="", cmap="Blues"):
    kernel = sp.stats.gaussian_kde(values.T)

    ax.axis(bbox)
    ax.set_aspect(abs(bbox[1] - bbox[0]) / abs(bbox[3] - bbox[2]))
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_xticks([])
    ax.set_yticks([])

    xx, yy = jnp.mgrid[bbox[0] : bbox[1] : 300j, bbox[2] : bbox[3] : 300j]
    positions = jnp.vstack([xx.ravel(), yy.ravel()])

    f = jnp.reshape(kernel(positions).T, xx.shape)
    cfset = ax.contourf(xx, yy, f, cmap=cmap)
    if contours is not None:
        x = jnp.arange(-2.0, 2.0, 0.1)
        y = jnp.arange(-2.0, 2.0, 0.1)
        cx, cy = jnp.meshgrid(x, y)
        new_set = ax.contour(
            cx, cy, contours.squeeze().reshape(cx.shape), levels=20, colors="k", linewidths=0.8, alpha=0.5
        )
    ax.set_title(title)

# %% [markdown]
# # Models and Training

# %% [markdown]
# A multilayer perceptron with the ReLU activation function.

# %%
class MLP(nn.Module):
    features: Sequence[int]

    @nn.compact
    def __call__(self, x):
        for feat in self.features[:-1]:
            x = jax.nn.relu(nn.Dense(features=feat)(x))
        x = nn.Dense(features=self.features[-1])(x)
        return x

# %% [markdown]
# The loss function for the discriminator is:
#
# $$L_D(\phi, \theta) = \mathbb{E}_{p^*(x)} g(D_\phi(x)) + \mathbb{E}_{q(z)}h(D_\phi(G_\theta(z)))$$
#
# where $g(t) = -\log t$, $h(t) = -\log(1 - t)$ as in the original GAN.

# %%
@jax.jit
def discriminator_step(disc_state, gen_state, latents, real_examples):
    def loss_fn(disc_params):
        fake_examples = gen_state.apply_fn(gen_state.params, latents)
        real_logits = disc_state.apply_fn(disc_params, real_examples)
        fake_logits = disc_state.apply_fn(disc_params, fake_examples)
        disc_real = -jax.nn.log_sigmoid(real_logits)
        # log(1 - sigmoid(x)) = log_sigmoid(-x)
        disc_fake = -jax.nn.log_sigmoid(-fake_logits)
        return jnp.mean(disc_real + disc_fake)

    disc_loss, disc_grad = jax.value_and_grad(loss_fn)(disc_state.params)
    disc_state = disc_state.apply_gradients(grads=disc_grad)
    return disc_state, disc_loss

# %% [markdown]
# The loss function for the generator is:
#
# $$L_G(\phi, \theta) = \mathbb{E}_{q(z)} l(D_\phi(G_\theta(z))$$
#
# where $l(t) = -\log t$ for the non-saturating generator loss.

# %%
@jax.jit
def generator_step(disc_state, gen_state, latents):
    def loss_fn(gen_params):
        fake_examples = gen_state.apply_fn(gen_params, latents)
        fake_logits = disc_state.apply_fn(disc_state.params, fake_examples)
        disc_fake = -jax.nn.log_sigmoid(fake_logits)
        return jnp.mean(disc_fake)

    gen_loss, gen_grad = jax.value_and_grad(loss_fn)(gen_state.params)
    gen_state = gen_state.apply_gradients(grads=gen_grad)
    return gen_state, gen_loss

# %% [markdown]
# Perform a training step by first updating the discriminator parameters $\phi$ using the gradient $\nabla_\phi L_D (\phi, \theta)$ and then updating the generator parameters $\theta$ using the gradient $\nabla_\theta L_G (\phi, \theta)$.

# %%
@jax.jit
def train_step(disc_state, gen_state, latents, real_examples):
    disc_state, disc_loss = discriminator_step(disc_state, gen_state, latents, real_examples)
    gen_state, gen_loss = generator_step(disc_state, gen_state, latents)
    return disc_state, gen_state, disc_loss, gen_loss

# %%
batch_size = 512
latent_size = 32

discriminator = MLP(features=[25, 25, 1])
generator = MLP(features=[25, 25, 2])

# %%
# Initialize parameters for the discriminator and the generator
latents = jax.random.normal(rng, shape=(batch_size, latent_size))
real_examples = real_data(rng, batch_size)
disc_params = discriminator.init(rng, real_examples)
gen_params = generator.init(rng, latents)

# %%
# Plot real examples
bbox = [-2, 2, -2, 2]
plot_on_ax(plt.gca(), real_examples, bbox=bbox)
plt.tight_layout()
sns.despine()
pml.savefig("gan_gmm_data.pdf")
plt.show()
# Out:
# /home/dhruvpatel/.local/lib/python3.8/site-packages/probml_utils/plotting.py:80: UserWarning: set FIG_DIR environment variable to save figures
#   warnings.warn("set FIG_DIR environment variable to save figures")

# %%
# Create train states for the discriminator and the generator
lr = 0.05
disc_state = train_state.TrainState.create(
    apply_fn=discriminator.apply, params=disc_params, tx=optax.sgd(learning_rate=lr)
)
gen_state = train_state.TrainState.create(apply_fn=generator.apply, params=gen_params, tx=optax.sgd(learning_rate=lr))

# %%
# x and y grid for plotting discriminator contours
x = jnp.arange(-2.0, 2.0, 0.1)
y = jnp.arange(-2.0, 2.0, 0.1)
X, Y = jnp.meshgrid(x, y)
pairs = jnp.stack((X, Y), axis=-1)
pairs = jnp.reshape(pairs, (-1, 2))

# Latents for testing generator
test_latents = jax.random.normal(rng, shape=(batch_size * 10, latent_size))

# %%
num_iters = 20001
n_save = 2000
draw_contours = False
history = []

for i in range(num_iters):
    rng_iter = jax.random.fold_in(rng, i)
    data_rng, latent_rng = jax.random.split(rng_iter)
    # Sample minibatch of examples
    real_examples = real_data(data_rng, batch_size)
    # Sample minibatch of latents
    latents = jax.random.normal(latent_rng, shape=(batch_size, latent_size))
    # Update both the generator
    disc_state, gen_state, disc_loss, gen_loss = train_step(disc_state, gen_state, latents, real_examples)
    if i % n_save == 0:
        print(f"i = {i}, Discriminator Loss = {disc_loss}, " + f"Generator Loss = {gen_loss}")
        # Generate examples using the test latents
        fake_examples = gen_state.apply_fn(gen_state.params, test_latents)
        if draw_contours:
            real_logits = disc_state.apply_fn(disc_state.params, pairs)
            disc_contour = -real_logits + jax.nn.log_sigmoid(real_logits)
        else:
            disc_contour = None
        history.append((i, fake_examples, disc_contour, disc_loss, gen_loss))
# Out:
# i = 0, Discriminator Loss = 1.3994444608688354, Generator Loss = 0.7146230340003967
# i = 2000, Discriminator Loss = 1.252339243888855, Generator Loss = 0.7533749341964722
# i = 4000, Discriminator Loss = 1.1361539363861084, Generator Loss = 0.739945650100708
# i = 6000, Discriminator Loss = 0.9970182776451111, Generator Loss = 1.6042615175247192
# i = 8000, Discriminator Loss = 0.8922513723373413, Generator Loss = 1.8515212535858154
# i = 10000, Discriminator Loss = 0.7909914255142212, Generator Loss = 1.2700555324554443
# i = 12000, Discriminator Loss = 0.45676666498184204, Generator Loss = 3.2579092979431152
# i = 14000, Discriminator Loss = 0.3048436641693115, Generator Loss = 3.015509605407715
# i = 16000, Discriminator Loss = 0.7251914143562317, Generator Loss = 6.251989364624023
# i = 18000, Discriminator Loss = 0.41163283586502075, Generator Loss = 3.460146188735962
# i = 20000, Discriminator Loss = 0.42174386978149414, Generator Loss = 2.3319690227508545

# %% [markdown]
# # Plot Results
#
# Plot the data and the examples generated by the generator.

# %%
# Plot generated examples from history
for i, hist in enumerate(history):
    iter, fake_examples, contours, disc_loss, gen_loss = hist
    plot_on_ax(
        plt.gca(),
        fake_examples,
        contours=contours,
        bbox=bbox,
        title=f"Disc Loss: {disc_loss:.3f} \n Gen Loss: {gen_loss:.3f}",
    )

    if (iter == 2000) or (iter == 4000) or (iter == 8000) or (iter == 12000) or (iter == 14000):
        plt.tight_layout()
        sns.despine()
        pml.savefig(f"gan_gmm_iter_{iter}.pdf")
        plt.show()
    else:
        plt.tight_layout()
        # plt.savefig(f"gan_gmm_iter_{iter}.pdf")
        plt.show()

# %%
cols = 3
rows = math.ceil((len(history) + 1) / cols)
bbox = [-2, 2, -2, 2]

fig, axs = plt.subplots(rows, cols, figsize=(cols * 3, rows * 3), dpi=200)
axs = axs.flatten()

# Plot real examples
plot_on_ax(axs[0], real_examples, bbox=bbox, title="Data")

# Plot generated examples from history
for i, hist in enumerate(history):
    iter, fake_examples, contours, disc_loss, gen_loss = hist
    plot_on_ax(
        axs[i + 1],
        fake_examples,
        contours=contours,
        bbox=bbox,
        xlabel=f"Disc Loss: {disc_loss:.3f} | Gen Loss: {gen_loss:.3f}",
        title=f"Samples at Iteration {iter}",
    )

# Remove extra plots from the figure
for i in range(len(history) + 1, len(axs)):
    axs[i].remove()
plt.tight_layout()
plt.show()
