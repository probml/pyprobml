# %% [markdown]
# Illustration of state estimation for a switching linear model. (a) Black dots are observations, hollow circles are the true location, colors represent the discrete state. (b) Estimate from RBPF. Generated by [rbpf_maneuver.ipynb](https://colab.research.google.com/github/probml/pyprobml/blob/master/notebooks/book2/12/rbpf_maneuver.ipynb). (c) Estimate from bootstrap filter. Generated by [bootstrap_filter_maneuver.ipynb](https://colab.research.google.com/github/probml/pyprobml/blob/master/notebooks/book2/12/bootstrap_filter_maneuver.ipynb).
