# %% [markdown]
# Illustration of filtering applied to a 2d nonlinear dynamical system. (a) True underlying state and observed data. (b) Extended Kalman filter estimate Generated by [ekf_vs_ukf.ipynb](https://colab.research.google.com/github/probml/pyprobml/blob/master/notebooks/book2/28/ekf_vs_ukf.ipynb). (c) Particle filter estimate using 2000 samples. Generated by [bootstrap_filter.ipynb](https://colab.research.google.com/github/probml/pyprobml/blob/master/notebooks/book2/28/bootstrap_filter.ipynb).
