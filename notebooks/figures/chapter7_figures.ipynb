# %%
# Copyright 2021 Google LLC
# Use of this source code is governed by an MIT-style
# license that can be found in the LICENSE file or at
# https://opensource.org/licenses/MIT.

# Author(s): Kevin P. Murphy (murphyk@gmail.com) and Mahmoud Soliman (mjs@aucegypt.edu)

# %% [markdown]
# <a href="https://opensource.org/licenses/MIT" target="_parent"><img src="https://img.shields.io/github/license/probml/pyprobml"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/probml/pyprobml/blob/master/notebooks/figures//chapter7_figures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Figure 7.1:<a name='7.1'></a> <a name='betaCI'></a>

# %% [markdown]
#   (a) Central interval and (b) HPD region for a Beta(3,9) posterior. The CI is (0.06, 0.52) and the HPD is (0.04, 0.48). Adapted from Figure 3.6 of <a href='#Hoff09'>[Hof09]</a> .
# Figure(s) generated by [betaHPD.m](https://github.com/probml/pmtk3/blob/master/demos/betaHPD.m)

# %%
#@title Setup
# %%time
# If you run this for the first time it would take ~25/30 seconds
# !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null && git clone https://github.com/Sekhen/colab_powertoys.git &> /dev/null 
# !pip3 install nbimporter -qqq 
# %cd -q /content/colab_powertoys 
from colab_powertoys.probml_toys import probml_toys as pmlt
# %cd -q /content/

# %%
pmlt.show_image("/content/pyprobml/notebooks/figures/images/betaCI.png")

# %%
pmlt.show_image("/content/pyprobml/notebooks/figures/images/betaHPD.png")

# %% [markdown]
# ## Figure 7.2:<a name='7.2'></a> <a name='CIvsHPD'></a>

# %% [markdown]
#   (a) Central interval and (b) HPD region for a hypothetical multimodal posterior. Adapted from Figure 2.2 of <a href='#Gelman04'>[Gel+04]</a> .
# Figure(s) generated by [postDensityIntervals.m](https://github.com/probml/pmtk3/blob/master/demos/postDensityIntervals.m)

# %%
#@title Setup
# %%time
# If you run this for the first time it would take ~25/30 seconds
# !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null && git clone https://github.com/Sekhen/colab_powertoys.git &> /dev/null 
# !pip3 install nbimporter -qqq 
# %cd -q /content/colab_powertoys 
from colab_powertoys.probml_toys import probml_toys as pmlt
# %cd -q /content/

# %%
pmlt.show_image("/content/pyprobml/notebooks/figures/images/centralInterval.png")

# %%
pmlt.show_image("/content/pyprobml/notebooks/figures/images/HPD.png")

# %% [markdown]
# ## Figure 7.3:<a name='7.3'></a> <a name='changeOfVars'></a>

# %% [markdown]
#   Computing the distribution of $z=y^2$, where $p(y)$ is uniform (left). The analytic result is shown in the middle, and the Monte Carlo approximation is shown on the right.
# Figure(s) generated by [change_of_vars_demo1d.py](https://github.com/probml/pyprobml/blob/master/scripts/change_of_vars_demo1d.py)

# %%
#@title Setup
# %%time
# If you run this for the first time it would take ~25/30 seconds
# !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null && git clone https://github.com/Sekhen/colab_powertoys.git &> /dev/null 
# !pip3 install nbimporter -qqq 
# %cd -q /content/colab_powertoys 
from colab_powertoys.probml_toys import probml_toys as pmlt
# %cd -q /content/

# %%
pmlt.show_and_run("/content/pyprobml/scripts/change_of_vars_demo1d.py")

# %% [markdown]
# ## Figure 7.4:<a name='7.4'></a> <a name='kdeGauss2d'></a>

# %% [markdown]
#   Kernel density estimate derived from a Monte Carlo approximation to $p(\mu ,\sigma ^2| \mathcal  D  )$ where $ \mathcal  D  = \  y_n \sim \mathcal  N (\mu =2,\sigma =1): n=1:1000 \ $ and we use a diffuse prior. The red star is the MLE.
# Figure(s) generated by [gauss2d_pymc3.py](https://github.com/probml/pyprobml/blob/master/scripts/gauss2d_pymc3.py)

# %%
#@title Setup
# %%time
# If you run this for the first time it would take ~25/30 seconds
# !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null && git clone https://github.com/Sekhen/colab_powertoys.git &> /dev/null 
# !pip3 install nbimporter -qqq 
# %cd -q /content/colab_powertoys 
from colab_powertoys.probml_toys import probml_toys as pmlt
# %cd -q /content/

# %%
pmlt.show_and_run("/content/pyprobml/scripts/gauss2d_pymc3.py")

# %% [markdown]
# ## Figure 7.5:<a name='7.5'></a> <a name='betaPost1'></a>

# %% [markdown]
#   Updating a Beta prior with a Bernoulli likelihood with sufficient statistics $N_1=4,N_0=1$. (a) Beta(2,2) prior. (b) Uniform Beta(1,1) prior.
# Figure(s) generated by [beta_binom_post_plot.py](https://github.com/probml/pyprobml/blob/master/scripts/beta_binom_post_plot.py)

# %%
#@title Setup
# %%time
# If you run this for the first time it would take ~25/30 seconds
# !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null && git clone https://github.com/Sekhen/colab_powertoys.git &> /dev/null 
# !pip3 install nbimporter -qqq 
# %cd -q /content/colab_powertoys 
from colab_powertoys.probml_toys import probml_toys as pmlt
# %cd -q /content/

# %%
pmlt.show_and_run("/content/pyprobml/scripts/beta_binom_post_plot.py")

# %% [markdown]
# ## Figure 7.6:<a name='7.6'></a> <a name='sequentialCoinToss'></a>

# %% [markdown]
#   Illustration of sequential Bayesian updating for the beta-Bernoulli model. Each colored box represents the predicted distribution $p(x_t|\mathbf  h _t)$, where $\mathbf  h _t=(N_ 1,t ,N_ 0,t )$ is the sufficient statistic derived from history of observations up until time $t$, namely the total number of heads and tails. The probability of heads (blue bar) is given by $p(x_t=1|\mathbf  h _t) = (N_ t,1  + 1)/(t+2)$, assuming we start with a uniform $\mathrm  Beta (\theta |1,1)$ prior. From Figure 3 of <a href='#Ortega2019'>[Ped+19]</a> . Used with kind permission of Pedro Ortega.

# %%
#@title Setup
# %%time
# If you run this for the first time it would take ~25/30 seconds
# !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null && git clone https://github.com/Sekhen/colab_powertoys.git &> /dev/null 
# !pip3 install nbimporter -qqq 
# %cd -q /content/colab_powertoys 
from colab_powertoys.probml_toys import probml_toys as pmlt
# %cd -q /content/

# %%
pmlt.show_image("/content/pyprobml/notebooks/figures/images/coin-prediction.png")

# %% [markdown]
# ## Figure 7.7:<a name='7.7'></a> <a name='BBpostpred'></a>

# %% [markdown]
#   (a) Posterior predictive distributions for 10 future trials after seeing $N_1=4$ heads and $N_0=1$ tails. (b) Plug-in approximation based on the same data. In both cases, we use a uniform prior.
# Figure(s) generated by [beta_binom_post_pred_plot.py](https://github.com/probml/pyprobml/blob/master/scripts/beta_binom_post_pred_plot.py)

# %%
#@title Setup
# %%time
# If you run this for the first time it would take ~25/30 seconds
# !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null && git clone https://github.com/Sekhen/colab_powertoys.git &> /dev/null 
# !pip3 install nbimporter -qqq 
# %cd -q /content/colab_powertoys 
from colab_powertoys.probml_toys import probml_toys as pmlt
# %cd -q /content/

# %%
pmlt.show_and_run("/content/pyprobml/scripts/beta_binom_post_pred_plot.py")

# %% [markdown]
# ## Figure 7.8:<a name='7.8'></a> <a name='mixBeta'></a>

# %% [markdown]
#   A mixture of two Beta distributions.
# Figure(s) generated by [mixBetaDemo.m](https://github.com/probml/pmtk3/blob/master/demos/mixBetaDemo.m)

# %%
#@title Setup
# %%time
# If you run this for the first time it would take ~25/30 seconds
# !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null && git clone https://github.com/Sekhen/colab_powertoys.git &> /dev/null 
# !pip3 install nbimporter -qqq 
# %cd -q /content/colab_powertoys 
from colab_powertoys.probml_toys import probml_toys as pmlt
# %cd -q /content/

# %%
pmlt.show_image("/content/pyprobml/notebooks/figures/images/mixBetaDemo.png")

# %% [markdown]
# ## Figure 7.9:<a name='7.9'></a> <a name='dirichlet'></a>

# %% [markdown]
#   (a) The Dirichlet distribution when $K=3$ defines a distribution over the simplex, which can be represented by the triangular surface. Points on this surface satisfy $0 \leq \theta _k \leq 1$ and $\DOTSB \sum@ \slimits@ _ k=1 ^3 \theta _k = 1$.
# Figure(s) generated by [dirichlet_3d_triangle_plot.py](https://github.com/probml/pyprobml/blob/master/scripts/dirichlet_3d_triangle_plot.py) [dirichlet_3d_spiky_plot.py](https://github.com/probml/pyprobml/blob/master/scripts/dirichlet_3d_spiky_plot.py)

# %%
#@title Setup
# %%time
# If you run this for the first time it would take ~25/30 seconds
# !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null && git clone https://github.com/Sekhen/colab_powertoys.git &> /dev/null 
# !pip3 install nbimporter -qqq 
# %cd -q /content/colab_powertoys 
from colab_powertoys.probml_toys import probml_toys as pmlt
# %cd -q /content/

# %%
pmlt.show_and_run("/content/pyprobml/scripts/dirichlet_3d_triangle_plot.py")

# %%
pmlt.show_and_run("/content/pyprobml/scripts/dirichlet_3d_spiky_plot.py")

# %% [markdown]
# ## Figure 7.10:<a name='7.10'></a> <a name='dirichletSamples'></a>

# %% [markdown]
#   Samples from a 5-dimensional symmetric Dirichlet distribution for different parameter values. (a) $\oset  \smallsmile   \boldsymbol  \alpha    = (0.1,\ldots ,0.1)$. This results in very sparse distributions, with many 0s. (b) $\oset  \smallsmile   \boldsymbol  \alpha    = (1,\ldots ,1)$. This results in more uniform (and dense) distributions.
# Figure(s) generated by [dirichlet_samples_plot.py](https://github.com/probml/pyprobml/blob/master/scripts/dirichlet_samples_plot.py)

# %%
#@title Setup
# %%time
# If you run this for the first time it would take ~25/30 seconds
# !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null && git clone https://github.com/Sekhen/colab_powertoys.git &> /dev/null 
# !pip3 install nbimporter -qqq 
# %cd -q /content/colab_powertoys 
from colab_powertoys.probml_toys import probml_toys as pmlt
# %cd -q /content/

# %%
pmlt.show_and_run("/content/pyprobml/scripts/dirichlet_samples_plot.py")

# %% [markdown]
# ## Figure 7.11:<a name='7.11'></a> <a name='gaussInferParamsMean1d'></a>

# %% [markdown]
#   Inferring the mean of a univariate Gaussian with known $\sigma ^2$. (a) Using strong prior, $p(\mu ) = \mathcal  N (\mu |0,1)$. (b) Using weak prior, $p(\mu ) = \mathcal  N (\mu |0,5)$.
# Figure(s) generated by [gaussInferParamsMean1d.m](https://github.com/probml/pmtk3/blob/master/demos/gaussInferParamsMean1d.m)

# %%
#@title Setup
# %%time
# If you run this for the first time it would take ~25/30 seconds
# !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null && git clone https://github.com/Sekhen/colab_powertoys.git &> /dev/null 
# !pip3 install nbimporter -qqq 
# %cd -q /content/colab_powertoys 
from colab_powertoys.probml_toys import probml_toys as pmlt
# %cd -q /content/

# %%
pmlt.show_image("/content/pyprobml/notebooks/figures/images/gaussInferParamsMean1d.png")

# %% [markdown]
# ## Figure 7.12:<a name='7.12'></a> <a name='sigmaPost'></a>

# %% [markdown]
#   Sequential updating of the posterior for $\sigma ^2$ starting from an uninformative prior. The data was generated from a Gaussian with known mean $\mu =5$ and unknown variance $\sigma ^2=10$.
# Figure(s) generated by [gauss_seq_update_sigma_1d.py](https://github.com/probml/pyprobml/blob/master/scripts/gauss_seq_update_sigma_1d.py)

# %%
#@title Setup
# %%time
# If you run this for the first time it would take ~25/30 seconds
# !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null && git clone https://github.com/Sekhen/colab_powertoys.git &> /dev/null 
# !pip3 install nbimporter -qqq 
# %cd -q /content/colab_powertoys 
from colab_powertoys.probml_toys import probml_toys as pmlt
# %cd -q /content/

# %%
pmlt.show_and_run("/content/pyprobml/scripts/gauss_seq_update_sigma_1d.py")

# %% [markdown]
# ## Figure 7.13:<a name='7.13'></a> <a name='NIX'></a>

# %% [markdown]
#   The $NI\chi ^2(\mu ,\sigma ^2|m,\kappa ,\nu ,\sigma ^2)$ distribution. $m$ is the prior mean and $k$ is how strongly we believe this; $\sigma ^2$ is the prior variance and $\nu $ is how strongly we believe this. (a) $m=0,\kappa =1,\nu =1,\sigma ^2=1$. Notice that the contour plot (underneath the surface) is shaped like a ``squashed egg''. (b) We increase the strength of our belief in the mean by setting $\kappa =5$, so the distribution for $\mu $ around $m=0$ becomes narrower.
# Figure(s) generated by [nix_plots.py](https://github.com/probml/pyprobml/blob/master/scripts/nix_plots.py)

# %%
#@title Setup
# %%time
# If you run this for the first time it would take ~25/30 seconds
# !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null && git clone https://github.com/Sekhen/colab_powertoys.git &> /dev/null 
# !pip3 install nbimporter -qqq 
# %cd -q /content/colab_powertoys 
from colab_powertoys.probml_toys import probml_toys as pmlt
# %cd -q /content/

# %%
pmlt.show_and_run("/content/pyprobml/scripts/nix_plots.py")

# %% [markdown]
# ## Figure 7.14:<a name='7.14'></a> <a name='gauss2dupdate2'></a>

# %% [markdown]
#   Illustration of Bayesian inference for the mean of a 2d Gaussian. (a) The data is generated from $\mathbf  y _n \sim \mathcal  N (\boldsymbol  \mu  ,\boldsymbol  \Sigma  )$, where $\boldsymbol  \mu  =[0.5, 0.5]^ \top  $ and $\boldsymbol  \Sigma  =0.1 [2, 1; 1, 1])$. (b) The prior is $p(\boldsymbol  \mu  ) = \mathcal  N (\boldsymbol  \mu  |\boldsymbol  0 ,0.1 \mathbf  I _2)$. (c) We show the posterior after 10 data points have been observed.
# Figure(s) generated by [gaussInferParamsMean2d.m](https://github.com/probml/pmtk3/blob/master/demos/gaussInferParamsMean2d.m)

# %%
#@title Setup
# %%time
# If you run this for the first time it would take ~25/30 seconds
# !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null && git clone https://github.com/Sekhen/colab_powertoys.git &> /dev/null 
# !pip3 install nbimporter -qqq 
# %cd -q /content/colab_powertoys 
from colab_powertoys.probml_toys import probml_toys as pmlt
# %cd -q /content/

# %%
pmlt.show_image("/content/pyprobml/notebooks/figures/images/gauss2dUpdatePostSubplot.png")

# %% [markdown]
# ## Figure 7.15:<a name='7.15'></a> <a name='gaussParams'></a>

# %% [markdown]
#   Graphical models representing different kinds of assumptions about the parameter priors. (a) A semi-conjugate prior for a Gaussian. (b) A conjugate prior for a Gaussian.

# %%
#@title Setup
# %%time
# If you run this for the first time it would take ~25/30 seconds
# !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null && git clone https://github.com/Sekhen/colab_powertoys.git &> /dev/null 
# !pip3 install nbimporter -qqq 
# %cd -q /content/colab_powertoys 
from colab_powertoys.probml_toys import probml_toys as pmlt
# %cd -q /content/

# %%
pmlt.show_image("/content/pyprobml/notebooks/figures/images/gaussParamsSemiConj.png")

# %%
pmlt.show_image("/content/pyprobml/notebooks/figures/images/gaussParamsConj.png")

# %% [markdown]
# ## Figure 7.16:<a name='7.16'></a> <a name='hbayesCancerRateDgm'></a>

# %% [markdown]
#   PGM for a hierarchical binomial model. (a) ``Unrolled'' model. (b) Same model, using plate notation.

# %%
#@title Setup
# %%time
# If you run this for the first time it would take ~25/30 seconds
# !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null && git clone https://github.com/Sekhen/colab_powertoys.git &> /dev/null 
# !pip3 install nbimporter -qqq 
# %cd -q /content/colab_powertoys 
from colab_powertoys.probml_toys import probml_toys as pmlt
# %cd -q /content/

# %%
pmlt.show_image("/content/pyprobml/notebooks/figures/images/hbayesCancerRateNoPlates.png")

# %%
pmlt.show_image("/content/pyprobml/notebooks/figures/images/hbayesCancerRateDGM.png")

# %% [markdown]
# ## Figure 7.17:<a name='7.17'></a> <a name='hbayesBinom'></a>

# %% [markdown]
#   Data and inferences for the hierarchical binomial model fit using HMC.

# %% [markdown]
# To reproduce this figure, click the open in colab button: <a href="https://colab.research.google.com/github/probml/pyprobml/blob/master/book1/bayes_stats/hbayes_binom_rats_pymc3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Setup
# %%time
# If you run this for the first time it would take ~25/30 seconds
# !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null && git clone https://github.com/Sekhen/colab_powertoys.git &> /dev/null 
# !pip3 install nbimporter -qqq 
# %cd -q /content/colab_powertoys 
from colab_powertoys.probml_toys import probml_toys as pmlt
# %cd -q /content/

# %%
pmlt.show_image("/content/pyprobml/notebooks/figures/images/hbayes_binom_rats_barplot.png")

# %%
pmlt.show_image("/content/pyprobml/notebooks/figures/images/hbayes_binom_rats_forest94.png")

# %% [markdown]
# ## Figure 7.18:<a name='7.18'></a> <a name='hbayesMeansNonCentered'></a>

# %% [markdown]
#   A hierarchical Gaussian Bayesian model. (a) Centered parameterization. (b) Non-centered parameterization.

# %%
#@title Setup
# %%time
# If you run this for the first time it would take ~25/30 seconds
# !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null && git clone https://github.com/Sekhen/colab_powertoys.git &> /dev/null 
# !pip3 install nbimporter -qqq 
# %cd -q /content/colab_powertoys 
from colab_powertoys.probml_toys import probml_toys as pmlt
# %cd -q /content/

# %%
pmlt.show_image("/content/pyprobml/notebooks/figures/images/hbayesMeansDGM.png")

# %%
pmlt.show_image("/content/pyprobml/notebooks/figures/images/hbayesMeansNonCentered.png")

# %% [markdown]
# ## Figure 7.19:<a name='7.19'></a> <a name='schoolsPost'></a>

# %% [markdown]
#   8-schools dataset. (a) Raw data. Each row plots $y_j \pm \sigma _j$. Vertical line is the pooled estimate. (b) Posterior 95\% credible intervals for $\theta _j$. Vertical line is posterior mean $\mathbb  E \left [ \mu | \mathcal  D   \right ]$.
# Figure(s) generated by [schools8_pymc3.py](https://github.com/probml/pyprobml/blob/master/scripts/schools8_pymc3.py)

# %%
#@title Setup
# %%time
# If you run this for the first time it would take ~25/30 seconds
# !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null && git clone https://github.com/Sekhen/colab_powertoys.git &> /dev/null 
# !pip3 install nbimporter -qqq 
# %cd -q /content/colab_powertoys 
from colab_powertoys.probml_toys import probml_toys as pmlt
# %cd -q /content/

# %%
pmlt.show_and_run("/content/pyprobml/scripts/schools8_pymc3.py")

# %% [markdown]
# ## Figure 7.20:<a name='7.20'></a> <a name='schoolsTau'></a>

# %% [markdown]
#   Marginal posterior density $p(\tau | \mathcal  D  )$ for the 8-schools dataset.
# Figure(s) generated by [schools8_pymc3.py](https://github.com/probml/pyprobml/blob/master/scripts/schools8_pymc3.py)

# %%
#@title Setup
# %%time
# If you run this for the first time it would take ~25/30 seconds
# !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null && git clone https://github.com/Sekhen/colab_powertoys.git &> /dev/null 
# !pip3 install nbimporter -qqq 
# %cd -q /content/colab_powertoys 
from colab_powertoys.probml_toys import probml_toys as pmlt
# %cd -q /content/

# %%
pmlt.show_and_run("/content/pyprobml/scripts/schools8_pymc3.py")

# %% [markdown]
# ## Figure 7.21:<a name='7.21'></a> <a name='ebBinom'></a>

# %% [markdown]
#   Data and inferences for the hierarchical binomial model fit using empirical Bayes.
# Figure(s) generated by [ebBinom.m](https://github.com/probml/pmtk3/blob/master/demos/ebBinom.m)

# %%
#@title Setup
# %%time
# If you run this for the first time it would take ~25/30 seconds
# !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null && git clone https://github.com/Sekhen/colab_powertoys.git &> /dev/null 
# !pip3 install nbimporter -qqq 
# %cd -q /content/colab_powertoys 
from colab_powertoys.probml_toys import probml_toys as pmlt
# %cd -q /content/

# %%
pmlt.show_image("/content/pyprobml/notebooks/figures/images/ebBinomBars.png")

# %%
pmlt.show_image("/content/pyprobml/notebooks/figures/images/ebBinomCI.png")

# %% [markdown]
# ## Figure 7.22:<a name='7.22'></a> <a name='linregEbModelSelVsN5'></a>

# %% [markdown]
#   Ilustration of Bayesian model selection for polynomial regression. (a-c) We fit polynomials of degrees 1, 2 and 3 fit to $N=5$ data points. The solid green curve is the true function, the dashed red curve is the prediction (dotted blue lines represent $\pm \sigma $ around the mean). (d) We plot the posterior over models, $p(m| \mathcal  D  )$, assuming a uniform prior $p(m) \propto 1$. Adapted from a figure by Zoubin Ghahramani.
# Figure(s) generated by [linreg_eb_modelsel_vs_n.py](https://github.com/probml/pyprobml/blob/master/scripts/linreg_eb_modelsel_vs_n.py)

# %%
#@title Setup
# %%time
# If you run this for the first time it would take ~25/30 seconds
# !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null && git clone https://github.com/Sekhen/colab_powertoys.git &> /dev/null 
# !pip3 install nbimporter -qqq 
# %cd -q /content/colab_powertoys 
from colab_powertoys.probml_toys import probml_toys as pmlt
# %cd -q /content/

# %%
pmlt.show_and_run("/content/pyprobml/scripts/linreg_eb_modelsel_vs_n.py")

# %% [markdown]
# ## Figure 7.23:<a name='7.23'></a> <a name='linregEbModelSelVsN30'></a>

# %% [markdown]
#   Same as \cref  fig:linregEbModelSelVsN5  except now $N=30$.
# Figure(s) generated by [linreg_eb_modelsel_vs_n.py](https://github.com/probml/pyprobml/blob/master/scripts/linreg_eb_modelsel_vs_n.py)

# %%
#@title Setup
# %%time
# If you run this for the first time it would take ~25/30 seconds
# !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null && git clone https://github.com/Sekhen/colab_powertoys.git &> /dev/null 
# !pip3 install nbimporter -qqq 
# %cd -q /content/colab_powertoys 
from colab_powertoys.probml_toys import probml_toys as pmlt
# %cd -q /content/

# %%
pmlt.show_and_run("/content/pyprobml/scripts/linreg_eb_modelsel_vs_n.py")

# %% [markdown]
# ## Figure 7.24:<a name='7.24'></a> <a name='occam'></a>

# %% [markdown]
#   A schematic illustration of the Bayesian Occam's razor. The broad (green) curve corresponds to a complex model, the narrow (blue) curve to a simple model, and the middle (red) curve is just right. Adapted from Figure 3.13 of <a href='#BishopBook'>[Bis06]</a> . See also \citep [Figure 2] Murray05  for a similar plot produced on real data.

# %%
#@title Setup
# %%time
# If you run this for the first time it would take ~25/30 seconds
# !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null && git clone https://github.com/Sekhen/colab_powertoys.git &> /dev/null 
# !pip3 install nbimporter -qqq 
# %cd -q /content/colab_powertoys 
from colab_powertoys.probml_toys import probml_toys as pmlt
# %cd -q /content/

# %%
pmlt.show_image("/content/pyprobml/notebooks/figures/images/BayesOccamsRazor.png")

# %% [markdown]
# ## Figure 7.25:<a name='7.25'></a> <a name='joshCoins4BIC'></a>

# %% [markdown]
#   (a) Log marginal likelihood vs number of heads for the coin tossing example. (b) BIC approximation. (The vertical scale is arbitrary, since we are holding $N$ fixed.)
# Figure(s) generated by [coins_model_sel_demo.py](https://github.com/probml/pyprobml/blob/master/scripts/coins_model_sel_demo.py)

# %%
#@title Setup
# %%time
# If you run this for the first time it would take ~25/30 seconds
# !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null && git clone https://github.com/Sekhen/colab_powertoys.git &> /dev/null 
# !pip3 install nbimporter -qqq 
# %cd -q /content/colab_powertoys 
from colab_powertoys.probml_toys import probml_toys as pmlt
# %cd -q /content/

# %%
pmlt.show_and_run("/content/pyprobml/scripts/coins_model_sel_demo.py")

# %% [markdown]
# ## Figure 7.26:<a name='7.26'></a> <a name='amazonSellers'></a>

# %% [markdown]
#   Monte Carlo approximation to $p(\delta | \mathcal  D  )$. We use kernel density estimation (\cref  sec:KDE ) to get a smooth plot. The vertical lines represent a ROPE of $[-0.1, 0.1]$.
# Figure(s) generated by [amazonSellerDemo.m](https://github.com/probml/pmtk3/blob/master/demos/amazonSellerDemo.m)

# %%
#@title Setup
# %%time
# If you run this for the first time it would take ~25/30 seconds
# !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null && git clone https://github.com/Sekhen/colab_powertoys.git &> /dev/null 
# !pip3 install nbimporter -qqq 
# %cd -q /content/colab_powertoys 
from colab_powertoys.probml_toys import probml_toys as pmlt
# %cd -q /content/

# %%
pmlt.show_image("/content/pyprobml/notebooks/figures/images/amazonSellersDeltaROPE.png")

# %% [markdown]
# ## Figure 7.27:<a name='7.27'></a> <a name='newcomb'></a>

# %% [markdown]
#   (a) Histogram of Newcomb's data. (b) Histograms of data sampled from Gaussian model. (c) Histogram of test statistic on data sampled from the model, which represents $p(\tau (\cc@accent  "707E   \mathcal  D   ^s)| \mathcal  D  )$, where $\tau ( \mathcal  D  )=\qopname m min \ y \in  \mathcal  D  \ $. The vertical line is the test statistic on the true data, $\tau ( \mathcal  D  )$. (d) Same as (c) except $\tau ( \mathcal  D  ) = \mathbb  V \  y \in  \mathcal  D  \ $.
# Figure(s) generated by [newcombPlugin.m](https://github.com/probml/pmtk3/blob/master/demos/newcombPlugin.m)

# %%
#@title Setup
# %%time
# If you run this for the first time it would take ~25/30 seconds
# !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null && git clone https://github.com/Sekhen/colab_powertoys.git &> /dev/null 
# !pip3 install nbimporter -qqq 
# %cd -q /content/colab_powertoys 
from colab_powertoys.probml_toys import probml_toys as pmlt
# %cd -q /content/

# %%
pmlt.show_image("/content/pyprobml/notebooks/figures/images/newcombTruth2.png")

# %%
pmlt.show_image("/content/pyprobml/notebooks/figures/images/newcombSynth2.png")

# %%
pmlt.show_image("/content/pyprobml/notebooks/figures/images/newcombTestStat2.png")

# %%
pmlt.show_image("/content/pyprobml/notebooks/figures/images/newcombHistoVar.png")

# %% [markdown]
# ## Figure 7.28:<a name='7.28'></a> <a name='bbPost'></a>

# %% [markdown]
#   Approximating the posterior of a beta-Bernoulli model. (a) Grid approximation using 20 grid points. (b) Laplace approximation.
# Figure(s) generated by [beta_binom_approx_post_pymc3.py](https://github.com/probml/pyprobml/blob/master/scripts/beta_binom_approx_post_pymc3.py)

# %%
#@title Setup
# %%time
# If you run this for the first time it would take ~25/30 seconds
# !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null && git clone https://github.com/Sekhen/colab_powertoys.git &> /dev/null 
# !pip3 install nbimporter -qqq 
# %cd -q /content/colab_powertoys 
from colab_powertoys.probml_toys import probml_toys as pmlt
# %cd -q /content/

# %%
pmlt.show_and_run("/content/pyprobml/scripts/beta_binom_approx_post_pymc3.py")

# %% [markdown]
# ## Figure 7.29:<a name='7.29'></a> <a name='bbMF'></a>

# %% [markdown]
#   Approximating the posterior of a beta-Bernoulli model using Gaussian approximation to the logits, $q(\alpha ) = \mathcal  N (\mu ,\sigma )$, where $\alpha =\mathrm  logit (\theta )$. (a) Estimate of variational mean over time. (b) Estimate of variational standard deviation over time. (c) ELBO over time. (d) Kernel density estimate of the original parameter $\theta \in [0,1]$ derived from samples from the variational posterior.
# Figure(s) generated by [beta_binom_approx_post_pymc3.py](https://github.com/probml/pyprobml/blob/master/scripts/beta_binom_approx_post_pymc3.py)

# %%
#@title Setup
# %%time
# If you run this for the first time it would take ~25/30 seconds
# !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null && git clone https://github.com/Sekhen/colab_powertoys.git &> /dev/null 
# !pip3 install nbimporter -qqq 
# %cd -q /content/colab_powertoys 
from colab_powertoys.probml_toys import probml_toys as pmlt
# %cd -q /content/

# %%
pmlt.show_and_run("/content/pyprobml/scripts/beta_binom_approx_post_pymc3.py")

# %% [markdown]
# ## Figure 7.30:<a name='7.30'></a> <a name='bbHMC'></a>

# %% [markdown]
#   Approximating the posterior of a beta-Bernoulli model using MCMC. (a) Kernel density estimate derived from samples from 4 independent chains. (b) Trace plot of the chains as they generate posterior samples.
# Figure(s) generated by [beta_binom_approx_post_pymc3.py](https://github.com/probml/pyprobml/blob/master/scripts/beta_binom_approx_post_pymc3.py)

# %%
#@title Setup
# %%time
# If you run this for the first time it would take ~25/30 seconds
# !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null && git clone https://github.com/Sekhen/colab_powertoys.git &> /dev/null 
# !pip3 install nbimporter -qqq 
# %cd -q /content/colab_powertoys 
from colab_powertoys.probml_toys import probml_toys as pmlt
# %cd -q /content/

# %%
pmlt.show_and_run("/content/pyprobml/scripts/beta_binom_approx_post_pymc3.py")

# %% [markdown]
# ## Figure 7.31:<a name='7.31'></a> <a name='ADF'></a>

# %% [markdown]
#   Illustration of the predict-update-project cycle of assumed density filtering.

# %%
#@title Setup
# %%time
# If you run this for the first time it would take ~25/30 seconds
# !git clone https://github.com/probml/pyprobml /pyprobml &> /dev/null && git clone https://github.com/Sekhen/colab_powertoys.git &> /dev/null 
# !pip3 install nbimporter -qqq 
# %cd -q /content/colab_powertoys 
from colab_powertoys.probml_toys import probml_toys as pmlt
# %cd -q /content/

# %%
pmlt.show_image("/content/pyprobml/notebooks/figures/images/ADFPUP.png")

# %% [markdown]
# ## References:
#  <a name='BishopBook'>[Bis06]</a> C. Bishop "Pattern recognition and machine learning". (2006).
#
# <a name='Gelman04'>[Gel+04]</a> A. Gelman, J. Carlin, H. Stern and D. Rubin. "Bayesian data analysis". (2004).
#
# <a name='Hoff09'>[Hof09]</a> P. Hoff "A First Course in Bayesian Statistical Methods". (2009).
#
# <a name='Ortega2019'>[Ped+19]</a> O. PedroA, W. JaneX, R. Mark, G. Tim, K. Zeb, P. Razvan, H. Nicolas, V. Joel, P. Alex, S. Pablo, J. SiddhantM, M. T. Kevin, A. Mohammad, O. Ian, R. Neil, G. Andr'as, C. ChiappaSilvia, O. Simon, T. YeeWhye, v. Hado, d. Nando and B. M. Shane. "Meta-learning of Sequential Strategies". abs/1905.03030 (2019). arXiv: 1905.03030
