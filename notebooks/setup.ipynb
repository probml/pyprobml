# %% [markdown]
# <a href="https://colab.research.google.com/github/probml/pyprobml/blob/master/notebooks/setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Get notebook setup
import tensorflow as tf

# %%
tf.__version__
# Out:
# '1.14.0-rc1'

# %%
pip uninstall tensorflow
# Out:
# Uninstalling tensorflow-1.14.0rc1:
#   Would remove:
#     /usr/local/bin/freeze_graph
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.6/dist-packages/tensorflow-1.14.0rc1.dist-info/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/*
# Proceed (y/n)? y
#   Successfully uninstalled tensorflow-1.14.0rc1

# %%
pip uninstall tensorflow-gpu
# Out:
# WARNING: Skipping tensorflow-gpu as it is not installed.

# %%
pip install tensorflow-gpu==2.0.0-beta1
# Out:
# ...
#      |████████████████████████████████| 348.9MB 38kB/s
# ...
#      |████████████████████████████████| 501kB 51.4MB/s
# ...
#      |████████████████████████████████| 3.1MB 32.1MB/s
# ...

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.0.0-beta1'

# %%
import torch
torch.__version__
# Out:
# '1.1.0'

# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
xs = np.arange(10); ys = xs**2; print(ys)
# Out:
# [ 0  1  4  9 16 25 36 49 64 81]

# %%
plt.plot(xs,ys)
