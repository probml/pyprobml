# %% [markdown]
# # Unsupervised Learning of Syntactic Structure with Invertible Neural Projections,

# %% [markdown]
# This code is based on https://github.com/jxhe/struct-learning-with-flow . We need to change the Markov Model class and some functions in a way that it can run on Google Colab and it stores the word embeddings that are attained by the model which is proposed by [Unsupervised Learning of Syntactic Structure with Invertible Neural Projections](http://arxiv.org/abs/1808.09111http://arxiv.org/abs/1808.09111)

# %% [markdown]
# ## Setup

# %%
# Running this cell is neccesary due to the fact that
# installing faiss 1.6.5 via pip is not working for torchcuda
# However, it will restart the kernel.
# After that, you should continue with the next cell and reload the page.

# !pip install -q condacolab
import condacolab

condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/latest/download/Mambaforge-colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:29
# 🔁 Restarting kernel...

# %%
import condacolab

condacolab.check()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# It will override the conda pinned versions to install required version of cuda
# !echo python 3.7.*   > /usr/local/conda-meta/pinned
# !echo python_abi 3.7.* *cp37*  >> /usr/local/conda-meta/pinned
# !conda install faiss=1.6.5 cudatoolkit=10.1 -c pytorch # For CUDA10
# !pip install -q tsnecuda==3.0.0+cu101 -f https://tsnecuda.isx.ai/tsnecuda_stable.html
# !git clone https://github.com/jxhe/struct-learning-with-flow.git

# Rename original repo
# !mv /content/struct-learning-with-flow /content/struct_learning_with_flow
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - cudatoolkit=10.1
#     - faiss=1.6.5
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2021.5.30  |       ha878542_0         136 KB  conda-forge
#     certifi-2021.5.30          |   py37h89c1867_0         141 KB  conda-forge
#     conda-4.10.3               |   py37h89c1867_0         3.1 MB  conda-forge
#     cudatoolkit-10.1.243       |       h036e899_8       427.5 MB  conda-forge
#     faiss-1.6.5                |py37hc041386_0_cuda         917 KB  conda-forge
#     libblas-3.9.0              |11_linux64_openblas          12 KB  conda-forge
#     libcblas-3.9.0             |11_linux64_openblas          11 KB  conda-forge
#     libfaiss-1.6.5             |  h3168606_0_cuda        37.8 MB  conda-forge
#     libgfortran-ng-11.1.0      |       h69a702a_8          19 KB  conda-forge
#     libgfortran5-11.1.0        |       h6c583b3_8         1.7 MB  conda-forge
#     liblapack-3.9.0            |11_linux64_openblas          11 KB  conda-forge
#     libopenblas-0.3.17         |pthreads_h8fe5266_1         9.2 MB  conda-forge
#     numpy-1.21.1               |   py37h038b26d_0         6.1 MB  conda-forge
#     openssl-1.1.1k             |       h7f98852_0         2.1 MB  conda-forge
#     python_abi-3.7             |          2_cp37m           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       488.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   cudatoolkit        conda-forge/linux-64::cudatoolkit-10.1.243-h036e899_8
#   faiss              conda-forge/linux-64::faiss-1.6.5-py37hc041386_0_cuda
#   libblas            conda-forge/linux-64::libblas-3.9.0-11_linux64_openblas
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-11_linux64_openblas
#   libfaiss           conda-forge/linux-64::libfaiss-1.6.5-h3168606_0_cuda
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-11.1.0-h69a702a_8
#   libgfortran5       conda-forge/linux-64::libgfortran5-11.1.0-h6c583b3_8
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-11_linux64_openblas
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.17-pthreads_h8fe5266_1
#   numpy              conda-forge/linux-64::numpy-1.21.1-py37h038b26d_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2020.12.5-ha878542_0 --> 2021.5.30-ha878542_0
#   certifi                          2020.12.5-py37h89c1867_1 --> 2021.5.30-py37h89c1867_0
#   conda                                4.9.2-py37h89c1867_0 --> 4.10.3-py37h89c1867_0
#   openssl                                 1.1.1j-h7f98852_0 --> 1.1.1k-h7f98852_0
#   python_abi                                    3.7-1_cp37m --> 3.7-2_cp37m
#
#
#
# Downloading and Extracting Packages
# libgfortran-ng-11.1. | 19 KB     | : 100% 1.0/1 [00:00<00:00, 14.27it/s]
# ca-certificates-2021 | 136 KB    | : 100% 1.0/1 [00:00<00:00, 19.21it/s]
# libfaiss-1.6.5       | 37.8 MB   | : 100% 1.0/1 [00:05<00:00,  5.89s/it]
# python_abi-3.7       | 4 KB      | : 100% 1.0/1 [00:00<00:00, 32.79it/s]
# numpy-1.21.1         | 6.1 MB    | : 100% 1.0/1 [00:01<00:00,  1.29s/it]
# libblas-3.9.0        | 12 KB     | : 100% 1.0/1 [00:00<00:00, 30.30it/s]
# faiss-1.6.5          | 917 KB    | : 100% 1.0/1 [00:00<00:00,  5.02it/s]
# libgfortran5-11.1.0  | 1.7 MB    | : 100% 1.0/1 [00:00<00:00,  3.25it/s]
# libcblas-3.9.0       | 11 KB     | : 100% 1.0/1 [00:00<00:00, 33.16it/s]
# cudatoolkit-10.1.243 | 427.5 MB  | : 100% 1.0/1 [00:53<00:00, 53.73s/it]
# openssl-1.1.1k       | 2.1 MB    | : 100% 1.0/1 [00:00<00:00,  2.88it/s]
# certifi-2021.5.30    | 141 KB    | : 100% 1.0/1 [00:00<00:00, 20.90it/s]
# conda-4.10.3         | 3.1 MB    | : 100% 1.0/1 [00:00<00:00,  1.79it/s]
# liblapack-3.9.0      | 11 KB     | : 100% 1.0/1 [00:00<00:00, 27.47it/s]
# libopenblas-0.3.17   | 9.2 MB    | : 100% 1.0/1 [00:01<00:00,  1.49s/it]
# done
# done
# - By downloading and using the CUDA Toolkit conda packages, you accept the terms and conditions of the CUDA End User License Agreement (EULA): https://docs.nvidia.com/cuda/eula/index.html
#
# done
#      |████████████████████████████████| 54.4 MB 8.4 kB/s
# Cloning into 'struct-learning-with-flow'...
# remote: Enumerating objects: 118, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 118 (delta 0), reused 0 (delta 0), pack-reused 115
# Receiving objects: 100% (118/118), 97.16 KiB | 641.00 KiB/s, done.
# Resolving deltas: 100% (46/46), done.

# %%
# %cd /content/struct_learning_with_flow
# !python prepare_data.py
# Out:
# /content/struct_learning_with_flow

# %%
import sys
import time
import os
from __future__ import print_function
from collections import defaultdict
from collections import Counter
from functools import partial
import pickle
import math
from math import log
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import pandas as pd

import argparse
from argparse import Namespace

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import Parameter
from torch.nn.utils.rnn import pad_packed_sequence, pack_padded_sequence
import tsnecuda as TSNE

from sklearn.metrics.cluster import v_measure_score

from struct_learning_with_flow.modules.utils import (
    read_conll,
    to_input_tensor,
    data_iter,
    generate_seed,
    sents_to_vec,
    log_sum_exp,
)
from struct_learning_with_flow.modules.projection import *
from struct_learning_with_flow.modules.markov_flow_model import MarkovFlow as mf

# %%
def write_conll(fname, sentences, pred_tags, null_total, embeddings):
    # Embeddings have 123 elements in it, therefore each sentence has its embedding
    embed_dict = {}
    with open(fname, "w") as fout:
        for (pred, null_sent, sent, embed) in zip(pred_tags, null_total, sentences, embeddings):
            word_list = sent["word"]
            embed = list(embed)
            head_list = sent["head"]
            length = len(sent) + len(null_sent)

            assert length == len(head_list)

            pred_tag_list = [str(k.item()) for k in pred]
            for null in null_sent:
                embed.insert(null, np.zeros(embed[0].shape))
                pred_tag_list.insert(null, "-NONE-")
                word_list.insert(null, "-NONE-")

            for i in range(length):
                fout.write("{}\t{}\t{}\t{}\n".format(i + 1, word_list[i], pred_tag_list[i], head_list[i][1]))
                if not word_list[i] in embed_dict and i not in null_sent:
                    embed_dict[word_list[i]] = embed[i]
            fout.write("\n")

    with open("/content/word_embeddings.pkl", "wb") as fout:
        pickle.dump(embed_dict, fout)

# %%
class MarkovFlow(mf):
    def __init__(self, args, num_dims):
        super(MarkovFlow, self).__init__(args, num_dims)

    def test(self, test_data, test_tags, sentences=None, tagging=False, path=None, null_index=None):
        """Evaluate tagging performance with
        many-to-1 metric and VM score

        Args:
            test_data: nested list of sentences
            test_tags: nested list of gold tags
            tagging: output the predicted tags if True
            path: The output tag file path
            null_index: the null element location in Penn
                        Treebank, only used for writing unsupervised
                        tags for downstream parsing task

        Returns:
            Tuple1: (M1, VM score)

        """

        pad = np.zeros(self.num_dims)

        total = 0.0
        correct = 0.0
        cnt_stats = {}
        match_dict = {}

        index_all = []
        eval_tags = []

        gold_vm = []
        model_vm = []
        embeddings_ = []

        for sents, tags in data_iter(
            list(zip(test_data, test_tags)), batch_size=self.args.batch_size, is_test=True, shuffle=False
        ):
            total += sum(len(sent) for sent in sents)
            sents_var, masks = to_input_tensor(sents, pad, device=self.device)
            sents_var, _ = self.transform(sents_var)
            embeddings_.extend(np.swapaxes(sents_var.cpu().numpy(), 0, 1))

            # index: (batch_size, seq_length)
            index = self._viterbi(sents_var, masks)

            index_all += list(index)
            eval_tags += tags

            # count
            for (seq_gold_tags, seq_model_tags) in zip(tags, index):
                for (gold_tag, model_tag) in zip(seq_gold_tags, seq_model_tags):
                    model_tag = model_tag.item()
                    gold_vm += [gold_tag]
                    model_vm += [model_tag]
                    if model_tag not in cnt_stats:
                        cnt_stats[model_tag] = Counter()
                    cnt_stats[model_tag][gold_tag] += 1
        # match
        for tag in cnt_stats:
            match_dict[tag] = cnt_stats[tag].most_common(1)[0][0]

        # eval many2one
        for (seq_gold_tags, seq_model_tags) in zip(eval_tags, index_all):
            for (gold_tag, model_tag) in zip(seq_gold_tags, seq_model_tags):
                model_tag = model_tag.item()
                if match_dict[model_tag] == gold_tag:
                    correct += 1

        if tagging:
            write_conll(path, sentences, index_all, null_index, embeddings_)

        return correct / total, v_measure_score(gold_vm, model_vm)

# %%
def init_config(
    train_file,
    word_vec,
    model="gaussian",
    test_file="",
    batch_size=32,
    epochs=50,
    lr=0.001,
    num_state=45,
    couple_layers=4,
    cell_layers=1,
    hidden_units=50,
    load_nice="",
    load_gaussian="",
    valid_nepoch=1,
    tag_from="",
    seed=5783287,
    set_seed=False,
    jobid=0,
    taskid=0,
):

    kwargs = {
        "model": model,
        "train_file": train_file,
        "word_vec": word_vec,
        "couple_layers": couple_layers,
        "test_file": test_file,
        "batch_size": batch_size,
        "epochs": epochs,
        "lr": lr,
        "num_state": num_state,
        "couple_layers": couple_layers,
        "cell_layers": cell_layers,
        "hidden_units": hidden_units,
        "load_nice": load_nice,
        "load_gaussian": load_gaussian,
        "valid_nepoch": valid_nepoch,
        "tag_from": tag_from,
        "seed": seed,
        "set_seed": set_seed,
        "jobid": jobid,
        "taskid": taskid,
    }

    args = Namespace(**kwargs)
    args.cuda = torch.cuda.is_available()

    save_dir = "dump_models/markov"

    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    id_ = "pos_%s_%dlayers_%d_%d" % (args.model, args.couple_layers, args.jobid, args.taskid)
    save_path = os.path.join(save_dir, id_ + ".pt")
    args.save_path = save_path
    print("model save path: ", save_path)

    if args.tag_from != "":
        if args.model == "nice":
            args.load_nice = args.tag_from
        else:
            args.load_gaussian = args.tag_from
        args.tag_path = "pos_%s_%slayers_tagging%d_%d.txt" % (args.model, args.couple_layers, args.jobid, args.taskid)

    if args.set_seed:
        torch.manual_seed(args.seed)
        if args.cuda:
            torch.cuda.manual_seed(args.seed)
        np.random.seed(args.seed * 13 / 7)

    print(args)

    return args

# %%
def main(args):

    word_vec = pickle.load(open(args.word_vec, "rb"))
    print("complete loading word vectors")

    train_text, null_index = read_conll(args.train_file)
    if args.test_file != "":
        test_text, null_index = read_conll(args.test_file)
    else:
        test_text = train_text

    train_data = sents_to_vec(word_vec, train_text)
    test_data = sents_to_vec(word_vec, test_text)

    test_tags = [sent["tag"] for sent in test_text]

    num_dims = len(train_data[0][0])
    print("complete reading data")

    print("#training sentences: %d" % len(train_data))
    print("#testing sentences: %d" % len(test_data))

    log_niter = (len(train_data) // args.batch_size) // 10

    pad = np.zeros(num_dims)
    device = torch.device("cuda" if args.cuda else "cpu")
    args.device = device
    init_seed = to_input_tensor(generate_seed(train_data, args.batch_size), pad, device=device)

    model = MarkovFlow(args, num_dims).to(device)

    model.init_params(init_seed)

    if args.tag_from != "":
        model.eval()
        with torch.no_grad():
            accuracy, vm = model.test(
                test_data, test_tags, sentences=test_text, tagging=True, path=args.tag_path, null_index=null_index
            )
        print(
            "\n***** M1 %f, VM %f, max_var %.4f, min_var %.4f*****\n"
            % (accuracy, vm, model.var.data.max(), model.var.data.min())
        )
        return

    optimizer = torch.optim.Adam(model.parameters(), lr=args.lr)

    begin_time = time.time()
    print("begin training")

    train_iter = report_obj = report_jc = report_ll = report_num_words = 0

    # print the accuracy under init params
    model.eval()
    with torch.no_grad():
        accuracy, vm = model.test(test_data, test_tags)
    print(
        "\n*****starting M1 %f, VM %f, max_var %.4f, min_var %.4f*****\n"
        % (accuracy, vm, model.var.data.max(), model.var.data.min())
    )

    model.train()
    for epoch in range(args.epochs):
        # model.print_params()
        report_obj = report_jc = report_ll = report_num_words = 0
        for sents in data_iter(train_data, batch_size=args.batch_size, shuffle=True):
            train_iter += 1
            batch_size = len(sents)
            num_words = sum(len(sent) for sent in sents)
            sents_var, masks = to_input_tensor(sents, pad, device=args.device)
            optimizer.zero_grad()
            likelihood, jacobian_loss = model(sents_var, masks)
            neg_likelihood_loss = -likelihood

            avg_ll_loss = (neg_likelihood_loss + jacobian_loss) / batch_size

            avg_ll_loss.backward()

            optimizer.step()

            log_likelihood_val = -neg_likelihood_loss.item()
            jacobian_val = -jacobian_loss.item()
            obj_val = log_likelihood_val + jacobian_val

            report_ll += log_likelihood_val
            report_jc += jacobian_val
            report_obj = obj_val
            report_num_words += num_words

            if train_iter % log_niter == 0:
                print(
                    "epoch %d, iter %d, log_likelihood %.2f, jacobian %.2f, obj %.2f, max_var %.4f "
                    "min_var %.4f time elapsed %.2f sec"
                    % (
                        epoch,
                        train_iter,
                        report_ll / report_num_words,
                        report_jc / report_num_words,
                        report_obj / report_num_words,
                        model.var.max(),
                        model.var.min(),
                        time.time() - begin_time,
                    )
                )

        print(
            "\nepoch %d, log_likelihood %.2f, jacobian %.2f, obj %.2f\n"
            % (epoch, report_ll / report_num_words, report_jc / report_num_words, report_obj / report_num_words)
        )

        if epoch % args.valid_nepoch == 0:
            model.eval()
            with torch.no_grad():
                accuracy, vm = model.test(test_data, test_tags)
            print("\n*****epoch %d, iter %d, M1 %f, VM %f*****\n" % (epoch, train_iter, accuracy, vm))
            model.train()

        torch.save(model.state_dict(), args.save_path)

    model.eval()
    with torch.no_grad():
        accuracy, vm = model.test(test_data, test_tags)
    print("\n complete training, accuracy %f, vm %f\n" % (accuracy, vm))

# %% [markdown]
# # Training a Gaussian HMM

# %% [markdown]
# Running two cells below equivalent to
#
# ```
# python markov_flow_train.py --model gaussian --train_file /path/to/train --word_vec /path/to/word_vec_file
# ```

# %%
train_file = "/content/struct_learning_with_flow/sample_data/ptb_tag_train_sub.txt"
word_vec = "/content/struct_learning_with_flow/sample_data/wsj_word_vec.pkl"
couple_layers = 4

# %%
args = init_config(train_file, word_vec, couple_layers=couple_layers, lr=5e-3)
main(args)
# Out:
# model save path:  dump_models/markov/pos_gaussian_4layers_0_0.pt
# Namespace(batch_size=32, cell_layers=1, couple_layers=4, cuda=True, epochs=50, hidden_units=50, jobid=0, load_gaussian='', load_nice='', lr=0.005, model='gaussian', num_state=45, save_path='dump_models/markov/pos_gaussian_4layers_0_0.pt', seed=5783287, set_seed=False, tag_from='', taskid=0, test_file='', train_file='/content/struct_learning_with_flow/sample_data/ptb_tag_train_sub.txt', valid_nepoch=1, word_vec='/content/struct_learning_with_flow/sample_data/wsj_word_vec.pkl')
# complete loading word vectors
# complete reading data
# #training sentences: 3914
# #testing sentences: 3914
# begin training
#
# *****starting M1 0.432900, VM 0.366470, max_var 0.0106, min_var 0.0046*****
#
# epoch 0, iter 12, log_likelihood 116.42, jacobian 0.00, obj 10.27, max_var 0.0106 min_var 0.0046 time elapsed 7.42 sec
# epoch 0, iter 24, log_likelihood 121.82, jacobian 0.00, obj 4.77, max_var 0.0106 min_var 0.0046 time elapsed 8.11 sec
# epoch 0, iter 36, log_likelihood 124.57, jacobian 0.00, obj 3.53, max_var 0.0106 min_var 0.0046 time elapsed 8.75 sec
# epoch 0, iter 48, log_likelihood 126.14, jacobian 0.00, obj 2.21, max_var 0.0106 min_var 0.0046 time elapsed 9.43 sec
# epoch 0, iter 60, log_likelihood 127.31, jacobian 0.00, obj 2.39, max_var 0.0106 min_var 0.0046 time elapsed 10.30 sec
# epoch 0, iter 72, log_likelihood 128.13, jacobian 0.00, obj 1.84, max_var 0.0106 min_var 0.0046 time elapsed 10.95 sec
# epoch 0, iter 84, log_likelihood 128.73, jacobian 0.00, obj 1.51, max_var 0.0106 min_var 0.0046 time elapsed 11.55 sec
# epoch 0, iter 96, log_likelihood 129.15, jacobian 0.00, obj 1.36, max_var 0.0106 min_var 0.0046 time elapsed 12.16 sec
# epoch 0, iter 108, log_likelihood 129.52, jacobian 0.00, obj 1.30, max_var 0.0106 min_var 0.0046 time elapsed 12.76 sec
# epoch 0, iter 120, log_likelihood 129.79, jacobian 0.00, obj 1.07, max_var 0.0106 min_var 0.0046 time elapsed 13.43 sec
#
# epoch 0, log_likelihood 129.84, jacobian 0.00, obj 0.28
#
#
# *****epoch 0, iter 123, M1 0.733111, VM 0.671021*****
#
# epoch 1, iter 132, log_likelihood 132.69, jacobian 0.00, obj 13.12, max_var 0.0106 min_var 0.0046 time elapsed 20.52 sec
# epoch 1, iter 144, log_likelihood 132.52, jacobian 0.00, obj 5.78, max_var 0.0106 min_var 0.0046 time elapsed 21.21 sec
# epoch 1, iter 156, log_likelihood 132.46, jacobian 0.00, obj 4.18, max_var 0.0106 min_var 0.0046 time elapsed 21.83 sec
# epoch 1, iter 168, log_likelihood 132.47, jacobian 0.00, obj 3.01, max_var 0.0106 min_var 0.0046 time elapsed 22.65 sec
# epoch 1, iter 180, log_likelihood 132.50, jacobian 0.00, obj 2.16, max_var 0.0106 min_var 0.0046 time elapsed 23.28 sec
# epoch 1, iter 192, log_likelihood 132.51, jacobian 0.00, obj 1.61, max_var 0.0106 min_var 0.0046 time elapsed 23.82 sec
# epoch 1, iter 204, log_likelihood 132.49, jacobian 0.00, obj 1.76, max_var 0.0106 min_var 0.0046 time elapsed 24.41 sec
# epoch 1, iter 216, log_likelihood 132.48, jacobian 0.00, obj 1.44, max_var 0.0106 min_var 0.0046 time elapsed 25.07 sec
# epoch 1, iter 228, log_likelihood 132.53, jacobian 0.00, obj 1.09, max_var 0.0106 min_var 0.0046 time elapsed 25.67 sec
# epoch 1, iter 240, log_likelihood 132.56, jacobian 0.00, obj 1.15, max_var 0.0106 min_var 0.0046 time elapsed 26.24 sec
#
# epoch 1, log_likelihood 132.57, jacobian 0.00, obj 0.33
#
#
# *****epoch 1, iter 246, M1 0.739074, VM 0.675350*****
#
# epoch 2, iter 252, log_likelihood 132.66, jacobian 0.00, obj 21.94, max_var 0.0106 min_var 0.0046 time elapsed 33.18 sec
# epoch 2, iter 264, log_likelihood 132.59, jacobian 0.00, obj 7.22, max_var 0.0106 min_var 0.0046 time elapsed 33.83 sec
# epoch 2, iter 276, log_likelihood 132.45, jacobian 0.00, obj 4.86, max_var 0.0106 min_var 0.0046 time elapsed 34.67 sec
# epoch 2, iter 288, log_likelihood 132.58, jacobian 0.00, obj 3.13, max_var 0.0106 min_var 0.0046 time elapsed 35.28 sec
# epoch 2, iter 300, log_likelihood 132.61, jacobian 0.00, obj 2.59, max_var 0.0106 min_var 0.0046 time elapsed 35.91 sec
# epoch 2, iter 312, log_likelihood 132.63, jacobian 0.00, obj 1.89, max_var 0.0106 min_var 0.0046 time elapsed 36.51 sec
# epoch 2, iter 324, log_likelihood 132.67, jacobian 0.00, obj 1.39, max_var 0.0106 min_var 0.0046 time elapsed 37.06 sec
# epoch 2, iter 336, log_likelihood 132.74, jacobian 0.00, obj 1.49, max_var 0.0106 min_var 0.0046 time elapsed 37.63 sec
# epoch 2, iter 348, log_likelihood 132.73, jacobian 0.00, obj 1.31, max_var 0.0106 min_var 0.0046 time elapsed 38.21 sec
# epoch 2, iter 360, log_likelihood 132.78, jacobian 0.00, obj 1.29, max_var 0.0106 min_var 0.0046 time elapsed 38.81 sec
#
# epoch 2, log_likelihood 132.77, jacobian 0.00, obj 0.30
#
#
# *****epoch 2, iter 369, M1 0.742188, VM 0.677654*****
#
# epoch 3, iter 372, log_likelihood 133.00, jacobian 0.00, obj 44.02, max_var 0.0106 min_var 0.0046 time elapsed 45.77 sec
# epoch 3, iter 384, log_likelihood 133.03, jacobian 0.00, obj 8.35, max_var 0.0106 min_var 0.0046 time elapsed 46.36 sec
# epoch 3, iter 396, log_likelihood 132.88, jacobian 0.00, obj 5.04, max_var 0.0106 min_var 0.0046 time elapsed 46.99 sec
# epoch 3, iter 408, log_likelihood 132.88, jacobian 0.00, obj 3.64, max_var 0.0106 min_var 0.0046 time elapsed 47.60 sec
# epoch 3, iter 420, log_likelihood 132.85, jacobian 0.00, obj 2.80, max_var 0.0106 min_var 0.0046 time elapsed 48.19 sec
# epoch 3, iter 432, log_likelihood 132.87, jacobian 0.00, obj 1.91, max_var 0.0106 min_var 0.0046 time elapsed 48.80 sec
# epoch 3, iter 444, log_likelihood 132.85, jacobian 0.00, obj 1.75, max_var 0.0106 min_var 0.0046 time elapsed 49.45 sec
# epoch 3, iter 456, log_likelihood 132.85, jacobian 0.00, obj 1.54, max_var 0.0106 min_var 0.0046 time elapsed 50.01 sec
# epoch 3, iter 468, log_likelihood 132.84, jacobian 0.00, obj 1.11, max_var 0.0106 min_var 0.0046 time elapsed 50.82 sec
# epoch 3, iter 480, log_likelihood 132.86, jacobian 0.00, obj 1.33, max_var 0.0106 min_var 0.0046 time elapsed 51.50 sec
# epoch 3, iter 492, log_likelihood 132.88, jacobian 0.00, obj 0.37, max_var 0.0106 min_var 0.0046 time elapsed 52.12 sec
#
# epoch 3, log_likelihood 132.88, jacobian 0.00, obj 0.37
#
#
# *****epoch 3, iter 492, M1 0.742645, VM 0.679905*****
#
# epoch 4, iter 504, log_likelihood 133.16, jacobian 0.00, obj 10.79, max_var 0.0106 min_var 0.0046 time elapsed 59.20 sec
# epoch 4, iter 516, log_likelihood 133.14, jacobian 0.00, obj 5.84, max_var 0.0106 min_var 0.0046 time elapsed 59.82 sec
# epoch 4, iter 528, log_likelihood 133.18, jacobian 0.00, obj 4.14, max_var 0.0106 min_var 0.0046 time elapsed 60.53 sec
# epoch 4, iter 540, log_likelihood 133.05, jacobian 0.00, obj 2.98, max_var 0.0106 min_var 0.0046 time elapsed 61.17 sec
# epoch 4, iter 552, log_likelihood 132.98, jacobian 0.00, obj 2.51, max_var 0.0106 min_var 0.0046 time elapsed 61.85 sec
# epoch 4, iter 564, log_likelihood 133.01, jacobian 0.00, obj 1.66, max_var 0.0106 min_var 0.0046 time elapsed 62.48 sec
# epoch 4, iter 576, log_likelihood 132.98, jacobian 0.00, obj 1.54, max_var 0.0106 min_var 0.0046 time elapsed 63.16 sec
# epoch 4, iter 588, log_likelihood 132.96, jacobian 0.00, obj 1.39, max_var 0.0106 min_var 0.0046 time elapsed 63.84 sec
# epoch 4, iter 600, log_likelihood 132.93, jacobian 0.00, obj 1.15, max_var 0.0106 min_var 0.0046 time elapsed 64.56 sec
# epoch 4, iter 612, log_likelihood 132.92, jacobian 0.00, obj 0.96, max_var 0.0106 min_var 0.0046 time elapsed 65.17 sec
#
# epoch 4, log_likelihood 132.93, jacobian 0.00, obj 0.30
#
#
# *****epoch 4, iter 615, M1 0.744505, VM 0.680951*****
#
# epoch 5, iter 624, log_likelihood 133.47, jacobian 0.00, obj 12.89, max_var 0.0106 min_var 0.0046 time elapsed 72.61 sec
# epoch 5, iter 636, log_likelihood 133.18, jacobian 0.00, obj 6.32, max_var 0.0106 min_var 0.0046 time elapsed 73.24 sec
# epoch 5, iter 648, log_likelihood 132.99, jacobian 0.00, obj 3.63, max_var 0.0106 min_var 0.0046 time elapsed 74.17 sec
# epoch 5, iter 660, log_likelihood 133.07, jacobian 0.00, obj 2.96, max_var 0.0106 min_var 0.0046 time elapsed 74.80 sec
# epoch 5, iter 672, log_likelihood 133.00, jacobian 0.00, obj 2.40, max_var 0.0106 min_var 0.0046 time elapsed 75.45 sec
# epoch 5, iter 684, log_likelihood 133.00, jacobian 0.00, obj 1.98, max_var 0.0106 min_var 0.0046 time elapsed 76.04 sec
# epoch 5, iter 696, log_likelihood 133.05, jacobian 0.00, obj 1.66, max_var 0.0106 min_var 0.0046 time elapsed 76.69 sec
# epoch 5, iter 708, log_likelihood 133.01, jacobian 0.00, obj 1.26, max_var 0.0106 min_var 0.0046 time elapsed 77.36 sec
# epoch 5, iter 720, log_likelihood 132.99, jacobian 0.00, obj 1.32, max_var 0.0106 min_var 0.0046 time elapsed 78.09 sec
# epoch 5, iter 732, log_likelihood 132.97, jacobian 0.00, obj 1.15, max_var 0.0106 min_var 0.0046 time elapsed 78.72 sec
#
# epoch 5, log_likelihood 132.96, jacobian 0.00, obj 0.40
#
#
# *****epoch 5, iter 738, M1 0.741550, VM 0.678878*****
#
# epoch 6, iter 744, log_likelihood 133.15, jacobian 0.00, obj 24.64, max_var 0.0106 min_var 0.0046 time elapsed 85.94 sec
# epoch 6, iter 756, log_likelihood 133.02, jacobian 0.00, obj 7.74, max_var 0.0106 min_var 0.0046 time elapsed 86.55 sec
# epoch 6, iter 768, log_likelihood 133.00, jacobian 0.00, obj 4.38, max_var 0.0106 min_var 0.0046 time elapsed 87.19 sec
# epoch 6, iter 780, log_likelihood 132.95, jacobian 0.00, obj 3.34, max_var 0.0106 min_var 0.0046 time elapsed 87.84 sec
# epoch 6, iter 792, log_likelihood 132.98, jacobian 0.00, obj 2.17, max_var 0.0106 min_var 0.0046 time elapsed 88.42 sec
# epoch 6, iter 804, log_likelihood 132.99, jacobian 0.00, obj 2.15, max_var 0.0106 min_var 0.0046 time elapsed 88.99 sec
# epoch 6, iter 816, log_likelihood 132.97, jacobian 0.00, obj 1.92, max_var 0.0106 min_var 0.0046 time elapsed 89.57 sec
# epoch 6, iter 828, log_likelihood 132.93, jacobian 0.00, obj 1.42, max_var 0.0106 min_var 0.0046 time elapsed 90.37 sec
# epoch 6, iter 840, log_likelihood 132.95, jacobian 0.00, obj 1.29, max_var 0.0106 min_var 0.0046 time elapsed 91.11 sec
# epoch 6, iter 852, log_likelihood 132.97, jacobian 0.00, obj 1.17, max_var 0.0106 min_var 0.0046 time elapsed 91.77 sec
#
# epoch 6, log_likelihood 132.97, jacobian 0.00, obj 0.41
#
#
# *****epoch 6, iter 861, M1 0.750670, VM 0.683409*****
#
# epoch 7, iter 864, log_likelihood 132.11, jacobian 0.00, obj 48.37, max_var 0.0106 min_var 0.0046 time elapsed 99.15 sec
# epoch 7, iter 876, log_likelihood 132.90, jacobian 0.00, obj 10.34, max_var 0.0106 min_var 0.0046 time elapsed 99.93 sec
# epoch 7, iter 888, log_likelihood 133.05, jacobian 0.00, obj 5.12, max_var 0.0106 min_var 0.0046 time elapsed 100.62 sec
# epoch 7, iter 900, log_likelihood 133.01, jacobian 0.00, obj 3.36, max_var 0.0106 min_var 0.0046 time elapsed 101.48 sec
# epoch 7, iter 912, log_likelihood 133.03, jacobian 0.00, obj 2.89, max_var 0.0106 min_var 0.0046 time elapsed 102.12 sec
# epoch 7, iter 924, log_likelihood 132.99, jacobian 0.00, obj 1.90, max_var 0.0106 min_var 0.0046 time elapsed 102.71 sec
# epoch 7, iter 936, log_likelihood 133.00, jacobian 0.00, obj 1.76, max_var 0.0106 min_var 0.0046 time elapsed 103.35 sec
# epoch 7, iter 948, log_likelihood 132.99, jacobian 0.00, obj 1.56, max_var 0.0106 min_var 0.0046 time elapsed 104.00 sec
# epoch 7, iter 960, log_likelihood 132.99, jacobian 0.00, obj 1.23, max_var 0.0106 min_var 0.0046 time elapsed 104.65 sec
# epoch 7, iter 972, log_likelihood 132.99, jacobian 0.00, obj 1.43, max_var 0.0106 min_var 0.0046 time elapsed 105.23 sec
# epoch 7, iter 984, log_likelihood 132.99, jacobian 0.00, obj 0.38, max_var 0.0106 min_var 0.0046 time elapsed 105.85 sec
#
# epoch 7, log_likelihood 132.99, jacobian 0.00, obj 0.38
#
#
# *****epoch 7, iter 984, M1 0.745238, VM 0.680454*****
#
# epoch 8, iter 996, log_likelihood 133.06, jacobian 0.00, obj 11.22, max_var 0.0106 min_var 0.0046 time elapsed 113.23 sec
# epoch 8, iter 1008, log_likelihood 132.90, jacobian 0.00, obj 6.04, max_var 0.0106 min_var 0.0046 time elapsed 113.84 sec
# epoch 8, iter 1020, log_likelihood 132.91, jacobian 0.00, obj 4.23, max_var 0.0106 min_var 0.0046 time elapsed 114.49 sec
# epoch 8, iter 1032, log_likelihood 132.89, jacobian 0.00, obj 2.58, max_var 0.0106 min_var 0.0046 time elapsed 115.33 sec
# epoch 8, iter 1044, log_likelihood 132.91, jacobian 0.00, obj 2.30, max_var 0.0106 min_var 0.0046 time elapsed 115.94 sec
# epoch 8, iter 1056, log_likelihood 132.97, jacobian 0.00, obj 1.81, max_var 0.0106 min_var 0.0046 time elapsed 116.55 sec
# epoch 8, iter 1068, log_likelihood 132.99, jacobian 0.00, obj 1.56, max_var 0.0106 min_var 0.0046 time elapsed 117.22 sec
# epoch 8, iter 1080, log_likelihood 133.01, jacobian 0.00, obj 1.34, max_var 0.0106 min_var 0.0046 time elapsed 117.81 sec
# epoch 8, iter 1092, log_likelihood 133.00, jacobian 0.00, obj 1.14, max_var 0.0106 min_var 0.0046 time elapsed 118.37 sec
# epoch 8, iter 1104, log_likelihood 132.98, jacobian 0.00, obj 1.14, max_var 0.0106 min_var 0.0046 time elapsed 118.99 sec
#
# epoch 8, log_likelihood 132.98, jacobian 0.00, obj 0.27
#
#
# *****epoch 8, iter 1107, M1 0.747789, VM 0.682783*****
#
# epoch 9, iter 1116, log_likelihood 133.36, jacobian 0.00, obj 14.93, max_var 0.0106 min_var 0.0046 time elapsed 125.96 sec
# epoch 9, iter 1128, log_likelihood 133.05, jacobian 0.00, obj 6.23, max_var 0.0106 min_var 0.0046 time elapsed 126.55 sec
# epoch 9, iter 1140, log_likelihood 132.94, jacobian 0.00, obj 4.02, max_var 0.0106 min_var 0.0046 time elapsed 127.11 sec
# epoch 9, iter 1152, log_likelihood 133.03, jacobian 0.00, obj 2.80, max_var 0.0106 min_var 0.0046 time elapsed 127.77 sec
# epoch 9, iter 1164, log_likelihood 133.03, jacobian 0.00, obj 2.41, max_var 0.0106 min_var 0.0046 time elapsed 128.39 sec
# epoch 9, iter 1176, log_likelihood 132.96, jacobian 0.00, obj 2.02, max_var 0.0106 min_var 0.0046 time elapsed 128.98 sec
# epoch 9, iter 1188, log_likelihood 132.99, jacobian 0.00, obj 1.72, max_var 0.0106 min_var 0.0046 time elapsed 129.64 sec
# epoch 9, iter 1200, log_likelihood 132.95, jacobian 0.00, obj 1.32, max_var 0.0106 min_var 0.0046 time elapsed 130.31 sec
# epoch 9, iter 1212, log_likelihood 132.96, jacobian 0.00, obj 1.22, max_var 0.0106 min_var 0.0046 time elapsed 130.92 sec
# epoch 9, iter 1224, log_likelihood 132.99, jacobian 0.00, obj 1.03, max_var 0.0106 min_var 0.0046 time elapsed 131.54 sec
#
# epoch 9, log_likelihood 132.99, jacobian 0.00, obj 0.33
#
#
# *****epoch 9, iter 1230, M1 0.747566, VM 0.682126*****
#
# epoch 10, iter 1236, log_likelihood 133.24, jacobian 0.00, obj 22.14, max_var 0.0106 min_var 0.0046 time elapsed 138.60 sec
# epoch 10, iter 1248, log_likelihood 133.06, jacobian 0.00, obj 7.88, max_var 0.0106 min_var 0.0046 time elapsed 139.20 sec
# epoch 10, iter 1260, log_likelihood 133.15, jacobian 0.00, obj 4.27, max_var 0.0106 min_var 0.0046 time elapsed 139.77 sec
# epoch 10, iter 1272, log_likelihood 133.08, jacobian 0.00, obj 3.31, max_var 0.0106 min_var 0.0046 time elapsed 140.57 sec
# epoch 10, iter 1284, log_likelihood 132.99, jacobian 0.00, obj 2.17, max_var 0.0106 min_var 0.0046 time elapsed 141.21 sec
# epoch 10, iter 1296, log_likelihood 132.97, jacobian 0.00, obj 1.88, max_var 0.0106 min_var 0.0046 time elapsed 141.81 sec
# epoch 10, iter 1308, log_likelihood 132.96, jacobian 0.00, obj 1.69, max_var 0.0106 min_var 0.0046 time elapsed 142.38 sec
# epoch 10, iter 1320, log_likelihood 133.00, jacobian 0.00, obj 1.65, max_var 0.0106 min_var 0.0046 time elapsed 143.00 sec
# epoch 10, iter 1332, log_likelihood 132.98, jacobian 0.00, obj 1.44, max_var 0.0106 min_var 0.0046 time elapsed 143.70 sec
# epoch 10, iter 1344, log_likelihood 133.00, jacobian 0.00, obj 1.49, max_var 0.0106 min_var 0.0046 time elapsed 144.32 sec
#
# epoch 10, log_likelihood 132.99, jacobian 0.00, obj 0.27
#
#
# *****epoch 10, iter 1353, M1 0.752742, VM 0.685982*****
#
# epoch 11, iter 1356, log_likelihood 132.59, jacobian 0.00, obj 46.13, max_var 0.0106 min_var 0.0046 time elapsed 151.19 sec
# epoch 11, iter 1368, log_likelihood 132.96, jacobian 0.00, obj 8.67, max_var 0.0106 min_var 0.0046 time elapsed 151.82 sec
# epoch 11, iter 1380, log_likelihood 132.99, jacobian 0.00, obj 5.54, max_var 0.0106 min_var 0.0046 time elapsed 152.43 sec
# epoch 11, iter 1392, log_likelihood 132.90, jacobian 0.00, obj 3.51, max_var 0.0106 min_var 0.0046 time elapsed 153.00 sec
# epoch 11, iter 1404, log_likelihood 132.92, jacobian 0.00, obj 2.41, max_var 0.0106 min_var 0.0046 time elapsed 153.58 sec
# epoch 11, iter 1416, log_likelihood 132.94, jacobian 0.00, obj 2.08, max_var 0.0106 min_var 0.0046 time elapsed 154.18 sec
# epoch 11, iter 1428, log_likelihood 132.97, jacobian 0.00, obj 1.65, max_var 0.0106 min_var 0.0046 time elapsed 154.77 sec
# epoch 11, iter 1440, log_likelihood 133.01, jacobian 0.00, obj 1.74, max_var 0.0106 min_var 0.0046 time elapsed 155.44 sec
# epoch 11, iter 1452, log_likelihood 132.98, jacobian 0.00, obj 1.41, max_var 0.0106 min_var 0.0046 time elapsed 156.19 sec
# epoch 11, iter 1464, log_likelihood 132.99, jacobian 0.00, obj 1.12, max_var 0.0106 min_var 0.0046 time elapsed 156.81 sec
# epoch 11, iter 1476, log_likelihood 132.99, jacobian 0.00, obj 0.30, max_var 0.0106 min_var 0.0046 time elapsed 157.49 sec
#
# epoch 11, log_likelihood 132.99, jacobian 0.00, obj 0.30
#
#
# *****epoch 11, iter 1476, M1 0.747577, VM 0.681792*****
#
# epoch 12, iter 1488, log_likelihood 133.17, jacobian 0.00, obj 11.43, max_var 0.0106 min_var 0.0046 time elapsed 164.88 sec
# epoch 12, iter 1500, log_likelihood 133.20, jacobian 0.00, obj 5.77, max_var 0.0106 min_var 0.0046 time elapsed 165.46 sec
# epoch 12, iter 1512, log_likelihood 133.04, jacobian 0.00, obj 3.08, max_var 0.0106 min_var 0.0046 time elapsed 166.13 sec
# epoch 12, iter 1524, log_likelihood 132.98, jacobian 0.00, obj 2.79, max_var 0.0106 min_var 0.0046 time elapsed 166.83 sec
# epoch 12, iter 1536, log_likelihood 133.01, jacobian 0.00, obj 2.38, max_var 0.0106 min_var 0.0046 time elapsed 167.44 sec
# epoch 12, iter 1548, log_likelihood 132.94, jacobian 0.00, obj 1.86, max_var 0.0106 min_var 0.0046 time elapsed 168.27 sec
# epoch 12, iter 1560, log_likelihood 132.97, jacobian 0.00, obj 1.51, max_var 0.0106 min_var 0.0046 time elapsed 168.89 sec
# epoch 12, iter 1572, log_likelihood 133.00, jacobian 0.00, obj 1.27, max_var 0.0106 min_var 0.0046 time elapsed 169.57 sec
# epoch 12, iter 1584, log_likelihood 133.01, jacobian 0.00, obj 1.33, max_var 0.0106 min_var 0.0046 time elapsed 170.22 sec
# epoch 12, iter 1596, log_likelihood 132.99, jacobian 0.00, obj 1.32, max_var 0.0106 min_var 0.0046 time elapsed 170.91 sec
#
# epoch 12, log_likelihood 133.00, jacobian 0.00, obj 0.34
#
#
# *****epoch 12, iter 1599, M1 0.746875, VM 0.683270*****
#
# epoch 13, iter 1608, log_likelihood 133.05, jacobian 0.00, obj 14.48, max_var 0.0106 min_var 0.0046 time elapsed 178.29 sec
# epoch 13, iter 1620, log_likelihood 133.03, jacobian 0.00, obj 5.42, max_var 0.0106 min_var 0.0046 time elapsed 178.92 sec
# epoch 13, iter 1632, log_likelihood 132.94, jacobian 0.00, obj 3.86, max_var 0.0106 min_var 0.0046 time elapsed 179.71 sec
# epoch 13, iter 1644, log_likelihood 132.87, jacobian 0.00, obj 3.12, max_var 0.0106 min_var 0.0046 time elapsed 180.34 sec
# epoch 13, iter 1656, log_likelihood 132.88, jacobian 0.00, obj 2.27, max_var 0.0106 min_var 0.0046 time elapsed 180.96 sec
# epoch 13, iter 1668, log_likelihood 132.92, jacobian 0.00, obj 1.78, max_var 0.0106 min_var 0.0046 time elapsed 181.74 sec
# epoch 13, iter 1680, log_likelihood 132.93, jacobian 0.00, obj 2.01, max_var 0.0106 min_var 0.0046 time elapsed 182.42 sec
# epoch 13, iter 1692, log_likelihood 132.94, jacobian 0.00, obj 1.37, max_var 0.0106 min_var 0.0046 time elapsed 182.99 sec
# epoch 13, iter 1704, log_likelihood 133.00, jacobian 0.00, obj 1.23, max_var 0.0106 min_var 0.0046 time elapsed 183.58 sec
# epoch 13, iter 1716, log_likelihood 133.02, jacobian 0.00, obj 1.18, max_var 0.0106 min_var 0.0046 time elapsed 184.16 sec
#
# epoch 13, log_likelihood 133.01, jacobian 0.00, obj 0.46
#
#
# *****epoch 13, iter 1722, M1 0.747725, VM 0.682818*****
#
# epoch 14, iter 1728, log_likelihood 133.14, jacobian 0.00, obj 22.77, max_var 0.0106 min_var 0.0046 time elapsed 191.02 sec
# epoch 14, iter 1740, log_likelihood 133.08, jacobian 0.00, obj 7.27, max_var 0.0106 min_var 0.0046 time elapsed 191.65 sec
# epoch 14, iter 1752, log_likelihood 133.04, jacobian 0.00, obj 4.62, max_var 0.0106 min_var 0.0046 time elapsed 192.30 sec
# epoch 14, iter 1764, log_likelihood 133.02, jacobian 0.00, obj 3.40, max_var 0.0106 min_var 0.0046 time elapsed 192.96 sec
# epoch 14, iter 1776, log_likelihood 132.95, jacobian 0.00, obj 2.49, max_var 0.0106 min_var 0.0046 time elapsed 193.54 sec
# epoch 14, iter 1788, log_likelihood 132.96, jacobian 0.00, obj 1.92, max_var 0.0106 min_var 0.0046 time elapsed 194.30 sec
# epoch 14, iter 1800, log_likelihood 133.00, jacobian 0.00, obj 1.81, max_var 0.0106 min_var 0.0046 time elapsed 194.93 sec
# epoch 14, iter 1812, log_likelihood 133.02, jacobian 0.00, obj 1.37, max_var 0.0106 min_var 0.0046 time elapsed 195.57 sec
# epoch 14, iter 1824, log_likelihood 132.99, jacobian 0.00, obj 1.34, max_var 0.0106 min_var 0.0046 time elapsed 196.22 sec
# epoch 14, iter 1836, log_likelihood 132.98, jacobian 0.00, obj 1.22, max_var 0.0106 min_var 0.0046 time elapsed 196.89 sec
#
# epoch 14, log_likelihood 133.00, jacobian 0.00, obj 0.38
#
#
# *****epoch 14, iter 1845, M1 0.746801, VM 0.682125*****
#
# epoch 15, iter 1848, log_likelihood 132.82, jacobian 0.00, obj 41.39, max_var 0.0106 min_var 0.0046 time elapsed 203.73 sec
# epoch 15, iter 1860, log_likelihood 133.02, jacobian 0.00, obj 10.47, max_var 0.0106 min_var 0.0046 time elapsed 204.53 sec
# epoch 15, iter 1872, log_likelihood 132.92, jacobian 0.00, obj 4.27, max_var 0.0106 min_var 0.0046 time elapsed 205.13 sec
# epoch 15, iter 1884, log_likelihood 132.94, jacobian 0.00, obj 3.77, max_var 0.0106 min_var 0.0046 time elapsed 205.80 sec
# epoch 15, iter 1896, log_likelihood 132.91, jacobian 0.00, obj 2.86, max_var 0.0106 min_var 0.0046 time elapsed 206.46 sec
# epoch 15, iter 1908, log_likelihood 132.99, jacobian 0.00, obj 2.11, max_var 0.0106 min_var 0.0046 time elapsed 207.05 sec
# epoch 15, iter 1920, log_likelihood 133.03, jacobian 0.00, obj 1.64, max_var 0.0106 min_var 0.0046 time elapsed 207.68 sec
# epoch 15, iter 1932, log_likelihood 133.04, jacobian 0.00, obj 1.52, max_var 0.0106 min_var 0.0046 time elapsed 208.30 sec
# epoch 15, iter 1944, log_likelihood 133.07, jacobian 0.00, obj 1.44, max_var 0.0106 min_var 0.0046 time elapsed 208.87 sec
# epoch 15, iter 1956, log_likelihood 133.05, jacobian 0.00, obj 1.10, max_var 0.0106 min_var 0.0046 time elapsed 209.50 sec
# epoch 15, iter 1968, log_likelihood 133.04, jacobian 0.00, obj 0.34, max_var 0.0106 min_var 0.0046 time elapsed 210.11 sec
#
# epoch 15, log_likelihood 133.04, jacobian 0.00, obj 0.34
#
#
# *****epoch 15, iter 1968, M1 0.747672, VM 0.682831*****
#
# epoch 16, iter 1980, log_likelihood 133.05, jacobian 0.00, obj 10.49, max_var 0.0106 min_var 0.0046 time elapsed 217.10 sec
# epoch 16, iter 1992, log_likelihood 133.03, jacobian 0.00, obj 5.56, max_var 0.0106 min_var 0.0046 time elapsed 217.73 sec
# epoch 16, iter 2004, log_likelihood 133.11, jacobian 0.00, obj 3.86, max_var 0.0106 min_var 0.0046 time elapsed 218.30 sec
# epoch 16, iter 2016, log_likelihood 133.05, jacobian 0.00, obj 2.49, max_var 0.0106 min_var 0.0046 time elapsed 218.97 sec
# epoch 16, iter 2028, log_likelihood 133.07, jacobian 0.00, obj 2.37, max_var 0.0106 min_var 0.0046 time elapsed 219.59 sec
# epoch 16, iter 2040, log_likelihood 133.08, jacobian 0.00, obj 1.89, max_var 0.0106 min_var 0.0046 time elapsed 220.17 sec
# epoch 16, iter 2052, log_likelihood 133.11, jacobian 0.00, obj 1.58, max_var 0.0106 min_var 0.0046 time elapsed 220.79 sec
# epoch 16, iter 2064, log_likelihood 133.12, jacobian 0.00, obj 1.45, max_var 0.0106 min_var 0.0046 time elapsed 221.39 sec
# epoch 16, iter 2076, log_likelihood 133.08, jacobian 0.00, obj 1.22, max_var 0.0106 min_var 0.0046 time elapsed 222.04 sec
# epoch 16, iter 2088, log_likelihood 133.08, jacobian 0.00, obj 1.05, max_var 0.0106 min_var 0.0046 time elapsed 222.82 sec
#
# epoch 16, log_likelihood 133.08, jacobian 0.00, obj 0.32
#
#
# *****epoch 16, iter 2091, M1 0.747098, VM 0.682855*****
#
# epoch 17, iter 2100, log_likelihood 133.11, jacobian 0.00, obj 13.91, max_var 0.0106 min_var 0.0046 time elapsed 230.14 sec
# epoch 17, iter 2112, log_likelihood 133.05, jacobian 0.00, obj 5.63, max_var 0.0106 min_var 0.0046 time elapsed 231.07 sec
# epoch 17, iter 2124, log_likelihood 132.92, jacobian 0.00, obj 4.13, max_var 0.0106 min_var 0.0046 time elapsed 231.66 sec
# epoch 17, iter 2136, log_likelihood 133.03, jacobian 0.00, obj 2.38, max_var 0.0106 min_var 0.0046 time elapsed 232.35 sec
# epoch 17, iter 2148, log_likelihood 133.09, jacobian 0.00, obj 2.33, max_var 0.0106 min_var 0.0046 time elapsed 232.99 sec
# epoch 17, iter 2160, log_likelihood 133.09, jacobian 0.00, obj 1.70, max_var 0.0106 min_var 0.0046 time elapsed 233.63 sec
# epoch 17, iter 2172, log_likelihood 133.11, jacobian 0.00, obj 1.67, max_var 0.0106 min_var 0.0046 time elapsed 234.37 sec
# epoch 17, iter 2184, log_likelihood 133.16, jacobian 0.00, obj 1.23, max_var 0.0106 min_var 0.0046 time elapsed 234.99 sec
# epoch 17, iter 2196, log_likelihood 133.12, jacobian 0.00, obj 1.24, max_var 0.0106 min_var 0.0046 time elapsed 235.63 sec
# epoch 17, iter 2208, log_likelihood 133.11, jacobian 0.00, obj 1.17, max_var 0.0106 min_var 0.0046 time elapsed 236.27 sec
#
# epoch 17, log_likelihood 133.08, jacobian 0.00, obj 0.48
#
#
# *****epoch 17, iter 2214, M1 0.746014, VM 0.681076*****
#
# epoch 18, iter 2220, log_likelihood 133.45, jacobian 0.00, obj 22.83, max_var 0.0106 min_var 0.0046 time elapsed 243.61 sec
# epoch 18, iter 2232, log_likelihood 133.16, jacobian 0.00, obj 7.20, max_var 0.0106 min_var 0.0046 time elapsed 244.23 sec
# epoch 18, iter 2244, log_likelihood 133.01, jacobian 0.00, obj 4.52, max_var 0.0106 min_var 0.0046 time elapsed 245.07 sec
# epoch 18, iter 2256, log_likelihood 133.05, jacobian 0.00, obj 3.29, max_var 0.0106 min_var 0.0046 time elapsed 245.76 sec
# epoch 18, iter 2268, log_likelihood 133.14, jacobian 0.00, obj 2.52, max_var 0.0106 min_var 0.0046 time elapsed 246.43 sec
# epoch 18, iter 2280, log_likelihood 133.19, jacobian 0.00, obj 2.13, max_var 0.0106 min_var 0.0046 time elapsed 247.06 sec
# epoch 18, iter 2292, log_likelihood 133.19, jacobian 0.00, obj 1.92, max_var 0.0106 min_var 0.0046 time elapsed 247.77 sec
# epoch 18, iter 2304, log_likelihood 133.15, jacobian 0.00, obj 1.47, max_var 0.0106 min_var 0.0046 time elapsed 248.36 sec
# epoch 18, iter 2316, log_likelihood 133.13, jacobian 0.00, obj 1.46, max_var 0.0106 min_var 0.0046 time elapsed 248.94 sec
# epoch 18, iter 2328, log_likelihood 133.12, jacobian 0.00, obj 1.21, max_var 0.0106 min_var 0.0046 time elapsed 249.56 sec
#
# epoch 18, log_likelihood 133.09, jacobian 0.00, obj 0.38
#
#
# *****epoch 18, iter 2337, M1 0.745376, VM 0.681187*****
#
# epoch 19, iter 2340, log_likelihood 132.71, jacobian 0.00, obj 50.06, max_var 0.0106 min_var 0.0046 time elapsed 256.53 sec
# epoch 19, iter 2352, log_likelihood 132.89, jacobian 0.00, obj 8.82, max_var 0.0106 min_var 0.0046 time elapsed 257.13 sec
# epoch 19, iter 2364, log_likelihood 133.01, jacobian 0.00, obj 4.50, max_var 0.0106 min_var 0.0046 time elapsed 257.77 sec
# epoch 19, iter 2376, log_likelihood 133.05, jacobian 0.00, obj 3.06, max_var 0.0106 min_var 0.0046 time elapsed 258.38 sec
# epoch 19, iter 2388, log_likelihood 133.10, jacobian 0.00, obj 3.24, max_var 0.0106 min_var 0.0046 time elapsed 259.18 sec
# epoch 19, iter 2400, log_likelihood 133.09, jacobian 0.00, obj 1.98, max_var 0.0106 min_var 0.0046 time elapsed 259.82 sec
# epoch 19, iter 2412, log_likelihood 133.06, jacobian 0.00, obj 1.73, max_var 0.0106 min_var 0.0046 time elapsed 260.49 sec
# epoch 19, iter 2424, log_likelihood 133.07, jacobian 0.00, obj 1.36, max_var 0.0106 min_var 0.0046 time elapsed 261.06 sec
# epoch 19, iter 2436, log_likelihood 133.08, jacobian 0.00, obj 1.25, max_var 0.0106 min_var 0.0046 time elapsed 261.64 sec
# epoch 19, iter 2448, log_likelihood 133.08, jacobian 0.00, obj 1.25, max_var 0.0106 min_var 0.0046 time elapsed 262.27 sec
# epoch 19, iter 2460, log_likelihood 133.08, jacobian 0.00, obj 0.38, max_var 0.0106 min_var 0.0046 time elapsed 262.84 sec
#
# epoch 19, log_likelihood 133.08, jacobian 0.00, obj 0.38
#
#
# *****epoch 19, iter 2460, M1 0.746142, VM 0.681049*****
#
# epoch 20, iter 2472, log_likelihood 133.15, jacobian 0.00, obj 9.83, max_var 0.0106 min_var 0.0046 time elapsed 269.86 sec
# epoch 20, iter 2484, log_likelihood 133.26, jacobian 0.00, obj 5.69, max_var 0.0106 min_var 0.0046 time elapsed 270.51 sec
# epoch 20, iter 2496, log_likelihood 133.27, jacobian 0.00, obj 3.74, max_var 0.0106 min_var 0.0046 time elapsed 271.10 sec
# epoch 20, iter 2508, log_likelihood 133.27, jacobian 0.00, obj 3.05, max_var 0.0106 min_var 0.0046 time elapsed 271.69 sec
# epoch 20, iter 2520, log_likelihood 133.17, jacobian 0.00, obj 1.86, max_var 0.0106 min_var 0.0046 time elapsed 272.26 sec
# epoch 20, iter 2532, log_likelihood 133.17, jacobian 0.00, obj 2.01, max_var 0.0106 min_var 0.0046 time elapsed 272.89 sec
# epoch 20, iter 2544, log_likelihood 133.15, jacobian 0.00, obj 1.36, max_var 0.0106 min_var 0.0046 time elapsed 273.57 sec
# epoch 20, iter 2556, log_likelihood 133.10, jacobian 0.00, obj 1.34, max_var 0.0106 min_var 0.0046 time elapsed 274.33 sec
# epoch 20, iter 2568, log_likelihood 133.11, jacobian 0.00, obj 1.07, max_var 0.0106 min_var 0.0046 time elapsed 274.93 sec
# epoch 20, iter 2580, log_likelihood 133.09, jacobian 0.00, obj 0.96, max_var 0.0106 min_var 0.0046 time elapsed 275.49 sec
#
# epoch 20, log_likelihood 133.08, jacobian 0.00, obj 0.41
#
#
# *****epoch 20, iter 2583, M1 0.745175, VM 0.680528*****
#
# epoch 21, iter 2592, log_likelihood 132.88, jacobian 0.00, obj 14.54, max_var 0.0106 min_var 0.0046 time elapsed 282.50 sec
# epoch 21, iter 2604, log_likelihood 133.02, jacobian 0.00, obj 6.59, max_var 0.0106 min_var 0.0046 time elapsed 283.05 sec
# epoch 21, iter 2616, log_likelihood 133.00, jacobian 0.00, obj 3.76, max_var 0.0106 min_var 0.0046 time elapsed 283.79 sec
# epoch 21, iter 2628, log_likelihood 132.99, jacobian 0.00, obj 2.74, max_var 0.0106 min_var 0.0046 time elapsed 284.42 sec
# epoch 21, iter 2640, log_likelihood 132.97, jacobian 0.00, obj 1.99, max_var 0.0106 min_var 0.0046 time elapsed 285.21 sec
# epoch 21, iter 2652, log_likelihood 133.07, jacobian 0.00, obj 2.00, max_var 0.0106 min_var 0.0046 time elapsed 285.74 sec
# epoch 21, iter 2664, log_likelihood 133.05, jacobian 0.00, obj 1.71, max_var 0.0106 min_var 0.0046 time elapsed 286.39 sec
# epoch 21, iter 2676, log_likelihood 133.02, jacobian 0.00, obj 1.35, max_var 0.0106 min_var 0.0046 time elapsed 287.00 sec
# epoch 21, iter 2688, log_likelihood 133.08, jacobian 0.00, obj 1.33, max_var 0.0106 min_var 0.0046 time elapsed 287.62 sec
# epoch 21, iter 2700, log_likelihood 133.09, jacobian 0.00, obj 0.89, max_var 0.0106 min_var 0.0046 time elapsed 288.21 sec
#
# epoch 21, log_likelihood 133.08, jacobian 0.00, obj 0.31
#
#
# *****epoch 21, iter 2706, M1 0.746397, VM 0.682996*****
#
# epoch 22, iter 2712, log_likelihood 133.13, jacobian 0.00, obj 22.72, max_var 0.0106 min_var 0.0046 time elapsed 295.61 sec
# epoch 22, iter 2724, log_likelihood 132.99, jacobian 0.00, obj 7.41, max_var 0.0106 min_var 0.0046 time elapsed 296.27 sec
# epoch 22, iter 2736, log_likelihood 133.13, jacobian 0.00, obj 4.39, max_var 0.0106 min_var 0.0046 time elapsed 296.90 sec
# epoch 22, iter 2748, log_likelihood 133.14, jacobian 0.00, obj 3.19, max_var 0.0106 min_var 0.0046 time elapsed 297.53 sec
# epoch 22, iter 2760, log_likelihood 133.10, jacobian 0.00, obj 2.33, max_var 0.0106 min_var 0.0046 time elapsed 298.16 sec
# epoch 22, iter 2772, log_likelihood 133.13, jacobian 0.00, obj 2.17, max_var 0.0106 min_var 0.0046 time elapsed 298.75 sec
# epoch 22, iter 2784, log_likelihood 133.11, jacobian 0.00, obj 1.94, max_var 0.0106 min_var 0.0046 time elapsed 299.43 sec
# epoch 22, iter 2796, log_likelihood 133.09, jacobian 0.00, obj 1.38, max_var 0.0106 min_var 0.0046 time elapsed 300.04 sec
# epoch 22, iter 2808, log_likelihood 133.08, jacobian 0.00, obj 1.29, max_var 0.0106 min_var 0.0046 time elapsed 300.71 sec
# epoch 22, iter 2820, log_likelihood 133.09, jacobian 0.00, obj 1.15, max_var 0.0106 min_var 0.0046 time elapsed 301.59 sec
#
# epoch 22, log_likelihood 133.08, jacobian 0.00, obj 0.35
#
#
# *****epoch 22, iter 2829, M1 0.744569, VM 0.682128*****
#
# epoch 23, iter 2832, log_likelihood 132.99, jacobian 0.00, obj 46.15, max_var 0.0106 min_var 0.0046 time elapsed 309.05 sec
# epoch 23, iter 2844, log_likelihood 133.26, jacobian 0.00, obj 8.60, max_var 0.0106 min_var 0.0046 time elapsed 309.68 sec
# epoch 23, iter 2856, log_likelihood 133.14, jacobian 0.00, obj 5.35, max_var 0.0106 min_var 0.0046 time elapsed 310.37 sec
# epoch 23, iter 2868, log_likelihood 133.09, jacobian 0.00, obj 3.48, max_var 0.0106 min_var 0.0046 time elapsed 311.01 sec
# epoch 23, iter 2880, log_likelihood 133.09, jacobian 0.00, obj 2.39, max_var 0.0106 min_var 0.0046 time elapsed 311.65 sec
# epoch 23, iter 2892, log_likelihood 133.14, jacobian 0.00, obj 2.23, max_var 0.0106 min_var 0.0046 time elapsed 312.32 sec
# epoch 23, iter 2904, log_likelihood 133.17, jacobian 0.00, obj 1.99, max_var 0.0106 min_var 0.0046 time elapsed 312.94 sec
# epoch 23, iter 2916, log_likelihood 133.12, jacobian 0.00, obj 1.60, max_var 0.0106 min_var 0.0046 time elapsed 313.64 sec
# epoch 23, iter 2928, log_likelihood 133.12, jacobian 0.00, obj 1.19, max_var 0.0106 min_var 0.0046 time elapsed 314.25 sec
# epoch 23, iter 2940, log_likelihood 133.10, jacobian 0.00, obj 1.19, max_var 0.0106 min_var 0.0046 time elapsed 315.13 sec
# epoch 23, iter 2952, log_likelihood 133.09, jacobian 0.00, obj 0.31, max_var 0.0106 min_var 0.0046 time elapsed 315.77 sec
#
# epoch 23, log_likelihood 133.09, jacobian 0.00, obj 0.31
#
#
# *****epoch 23, iter 2952, M1 0.747322, VM 0.681287*****
#
# epoch 24, iter 2964, log_likelihood 132.97, jacobian 0.00, obj 9.65, max_var 0.0106 min_var 0.0046 time elapsed 322.88 sec
# epoch 24, iter 2976, log_likelihood 133.11, jacobian 0.00, obj 5.68, max_var 0.0106 min_var 0.0046 time elapsed 323.50 sec
# epoch 24, iter 2988, log_likelihood 133.17, jacobian 0.00, obj 3.39, max_var 0.0106 min_var 0.0046 time elapsed 324.13 sec
# epoch 24, iter 3000, log_likelihood 133.09, jacobian 0.00, obj 2.35, max_var 0.0106 min_var 0.0046 time elapsed 324.71 sec
# epoch 24, iter 3012, log_likelihood 133.08, jacobian 0.00, obj 2.23, max_var 0.0106 min_var 0.0046 time elapsed 325.34 sec
# epoch 24, iter 3024, log_likelihood 133.10, jacobian 0.00, obj 2.10, max_var 0.0106 min_var 0.0046 time elapsed 325.96 sec
# epoch 24, iter 3036, log_likelihood 133.09, jacobian 0.00, obj 1.53, max_var 0.0106 min_var 0.0046 time elapsed 326.63 sec
# epoch 24, iter 3048, log_likelihood 133.07, jacobian 0.00, obj 1.30, max_var 0.0106 min_var 0.0046 time elapsed 327.21 sec
# epoch 24, iter 3060, log_likelihood 133.09, jacobian 0.00, obj 1.32, max_var 0.0106 min_var 0.0046 time elapsed 327.81 sec
# epoch 24, iter 3072, log_likelihood 133.10, jacobian 0.00, obj 0.96, max_var 0.0106 min_var 0.0046 time elapsed 328.39 sec
#
# epoch 24, log_likelihood 133.08, jacobian 0.00, obj 0.22
#
#
# *****epoch 24, iter 3075, M1 0.742570, VM 0.679050*****
#
# epoch 25, iter 3084, log_likelihood 133.17, jacobian 0.00, obj 13.22, max_var 0.0106 min_var 0.0046 time elapsed 335.31 sec
# epoch 25, iter 3096, log_likelihood 133.17, jacobian 0.00, obj 6.14, max_var 0.0106 min_var 0.0046 time elapsed 335.94 sec
# epoch 25, iter 3108, log_likelihood 133.16, jacobian 0.00, obj 4.01, max_var 0.0106 min_var 0.0046 time elapsed 336.53 sec
# epoch 25, iter 3120, log_likelihood 133.13, jacobian 0.00, obj 2.56, max_var 0.0106 min_var 0.0046 time elapsed 337.13 sec
# epoch 25, iter 3132, log_likelihood 133.11, jacobian 0.00, obj 2.47, max_var 0.0106 min_var 0.0046 time elapsed 337.94 sec
# epoch 25, iter 3144, log_likelihood 133.10, jacobian 0.00, obj 1.73, max_var 0.0106 min_var 0.0046 time elapsed 338.60 sec
# epoch 25, iter 3156, log_likelihood 133.06, jacobian 0.00, obj 1.58, max_var 0.0106 min_var 0.0046 time elapsed 339.20 sec
# epoch 25, iter 3168, log_likelihood 133.08, jacobian 0.00, obj 1.23, max_var 0.0106 min_var 0.0046 time elapsed 339.92 sec
# epoch 25, iter 3180, log_likelihood 133.08, jacobian 0.00, obj 1.23, max_var 0.0106 min_var 0.0046 time elapsed 340.51 sec
# epoch 25, iter 3192, log_likelihood 133.10, jacobian 0.00, obj 0.98, max_var 0.0106 min_var 0.0046 time elapsed 341.10 sec
#
# epoch 25, log_likelihood 133.08, jacobian 0.00, obj 0.40
#
#
# *****epoch 25, iter 3198, M1 0.746482, VM 0.680957*****
#
# epoch 26, iter 3204, log_likelihood 132.98, jacobian 0.00, obj 23.36, max_var 0.0106 min_var 0.0046 time elapsed 348.15 sec
# epoch 26, iter 3216, log_likelihood 133.26, jacobian 0.00, obj 7.24, max_var 0.0106 min_var 0.0046 time elapsed 348.74 sec
# epoch 26, iter 3228, log_likelihood 133.32, jacobian 0.00, obj 3.99, max_var 0.0106 min_var 0.0046 time elapsed 349.39 sec
# epoch 26, iter 3240, log_likelihood 133.27, jacobian 0.00, obj 3.61, max_var 0.0106 min_var 0.0046 time elapsed 349.98 sec
# epoch 26, iter 3252, log_likelihood 133.22, jacobian 0.00, obj 2.53, max_var 0.0106 min_var 0.0046 time elapsed 350.63 sec
# epoch 26, iter 3264, log_likelihood 133.20, jacobian 0.00, obj 2.11, max_var 0.0106 min_var 0.0046 time elapsed 351.28 sec
# epoch 26, iter 3276, log_likelihood 133.18, jacobian 0.00, obj 1.86, max_var 0.0106 min_var 0.0046 time elapsed 351.95 sec
# epoch 26, iter 3288, log_likelihood 133.18, jacobian 0.00, obj 1.48, max_var 0.0106 min_var 0.0046 time elapsed 352.54 sec
# epoch 26, iter 3300, log_likelihood 133.18, jacobian 0.00, obj 1.08, max_var 0.0106 min_var 0.0046 time elapsed 353.14 sec
# epoch 26, iter 3312, log_likelihood 133.12, jacobian 0.00, obj 1.27, max_var 0.0106 min_var 0.0046 time elapsed 353.77 sec
#
# epoch 26, log_likelihood 133.08, jacobian 0.00, obj 0.38
#
#
# *****epoch 26, iter 3321, M1 0.748459, VM 0.682418*****
#
# epoch 27, iter 3324, log_likelihood 133.32, jacobian 0.00, obj 45.02, max_var 0.0106 min_var 0.0046 time elapsed 361.06 sec
# epoch 27, iter 3336, log_likelihood 133.10, jacobian 0.00, obj 8.58, max_var 0.0106 min_var 0.0046 time elapsed 361.68 sec
# epoch 27, iter 3348, log_likelihood 133.16, jacobian 0.00, obj 5.02, max_var 0.0106 min_var 0.0046 time elapsed 362.39 sec
# epoch 27, iter 3360, log_likelihood 133.19, jacobian 0.00, obj 3.31, max_var 0.0106 min_var 0.0046 time elapsed 363.04 sec
# epoch 27, iter 3372, log_likelihood 133.12, jacobian 0.00, obj 2.39, max_var 0.0106 min_var 0.0046 time elapsed 363.70 sec
# epoch 27, iter 3384, log_likelihood 133.15, jacobian 0.00, obj 2.24, max_var 0.0106 min_var 0.0046 time elapsed 364.41 sec
# epoch 27, iter 3396, log_likelihood 133.14, jacobian 0.00, obj 1.89, max_var 0.0106 min_var 0.0046 time elapsed 365.10 sec
# epoch 27, iter 3408, log_likelihood 133.12, jacobian 0.00, obj 1.72, max_var 0.0106 min_var 0.0046 time elapsed 365.74 sec
# epoch 27, iter 3420, log_likelihood 133.09, jacobian 0.00, obj 1.36, max_var 0.0106 min_var 0.0046 time elapsed 366.62 sec
# epoch 27, iter 3432, log_likelihood 133.08, jacobian 0.00, obj 1.29, max_var 0.0106 min_var 0.0046 time elapsed 367.25 sec
# epoch 27, iter 3444, log_likelihood 133.07, jacobian 0.00, obj 0.32, max_var 0.0106 min_var 0.0046 time elapsed 367.85 sec
#
# epoch 27, log_likelihood 133.07, jacobian 0.00, obj 0.32
#
#
# *****epoch 27, iter 3444, M1 0.747077, VM 0.681264*****
#
# epoch 28, iter 3456, log_likelihood 132.97, jacobian 0.00, obj 11.51, max_var 0.0106 min_var 0.0046 time elapsed 375.24 sec
# epoch 28, iter 3468, log_likelihood 132.92, jacobian 0.00, obj 5.80, max_var 0.0106 min_var 0.0046 time elapsed 375.90 sec
# epoch 28, iter 3480, log_likelihood 133.01, jacobian 0.00, obj 3.19, max_var 0.0106 min_var 0.0046 time elapsed 376.73 sec
# epoch 28, iter 3492, log_likelihood 133.02, jacobian 0.00, obj 2.95, max_var 0.0106 min_var 0.0046 time elapsed 377.34 sec
# epoch 28, iter 3504, log_likelihood 133.04, jacobian 0.00, obj 2.15, max_var 0.0106 min_var 0.0046 time elapsed 378.05 sec
# epoch 28, iter 3516, log_likelihood 132.99, jacobian 0.00, obj 1.90, max_var 0.0106 min_var 0.0046 time elapsed 378.75 sec
# epoch 28, iter 3528, log_likelihood 133.02, jacobian 0.00, obj 1.66, max_var 0.0106 min_var 0.0046 time elapsed 379.41 sec
# epoch 28, iter 3540, log_likelihood 133.04, jacobian 0.00, obj 1.38, max_var 0.0106 min_var 0.0046 time elapsed 380.06 sec
# epoch 28, iter 3552, log_likelihood 133.05, jacobian 0.00, obj 1.15, max_var 0.0106 min_var 0.0046 time elapsed 380.69 sec
# epoch 28, iter 3564, log_likelihood 133.07, jacobian 0.00, obj 1.13, max_var 0.0106 min_var 0.0046 time elapsed 381.45 sec
#
# epoch 28, log_likelihood 133.08, jacobian 0.00, obj 0.36
#
#
# *****epoch 28, iter 3567, M1 0.742826, VM 0.680273*****
#
# epoch 29, iter 3576, log_likelihood 133.01, jacobian 0.00, obj 14.27, max_var 0.0106 min_var 0.0046 time elapsed 388.58 sec
# epoch 29, iter 3588, log_likelihood 132.87, jacobian 0.00, obj 6.02, max_var 0.0106 min_var 0.0046 time elapsed 389.26 sec
# epoch 29, iter 3600, log_likelihood 133.01, jacobian 0.00, obj 4.13, max_var 0.0106 min_var 0.0046 time elapsed 389.90 sec
# epoch 29, iter 3612, log_likelihood 133.04, jacobian 0.00, obj 2.61, max_var 0.0106 min_var 0.0046 time elapsed 390.55 sec
# epoch 29, iter 3624, log_likelihood 133.07, jacobian 0.00, obj 2.35, max_var 0.0106 min_var 0.0046 time elapsed 391.17 sec
# epoch 29, iter 3636, log_likelihood 133.13, jacobian 0.00, obj 2.27, max_var 0.0106 min_var 0.0046 time elapsed 391.86 sec
# epoch 29, iter 3648, log_likelihood 133.09, jacobian 0.00, obj 1.69, max_var 0.0106 min_var 0.0046 time elapsed 392.54 sec
# epoch 29, iter 3660, log_likelihood 133.07, jacobian 0.00, obj 1.36, max_var 0.0106 min_var 0.0046 time elapsed 393.44 sec
# epoch 29, iter 3672, log_likelihood 133.05, jacobian 0.00, obj 1.26, max_var 0.0106 min_var 0.0046 time elapsed 394.11 sec
# epoch 29, iter 3684, log_likelihood 133.10, jacobian 0.00, obj 1.09, max_var 0.0106 min_var 0.0046 time elapsed 394.77 sec
#
# epoch 29, log_likelihood 133.09, jacobian 0.00, obj 0.30
#
#
# *****epoch 29, iter 3690, M1 0.745589, VM 0.681531*****
#
# epoch 30, iter 3696, log_likelihood 133.23, jacobian 0.00, obj 22.94, max_var 0.0106 min_var 0.0046 time elapsed 402.12 sec
# epoch 30, iter 3708, log_likelihood 133.35, jacobian 0.00, obj 7.52, max_var 0.0106 min_var 0.0046 time elapsed 402.76 sec
# epoch 30, iter 3720, log_likelihood 133.21, jacobian 0.00, obj 4.18, max_var 0.0106 min_var 0.0046 time elapsed 403.38 sec
# epoch 30, iter 3732, log_likelihood 133.26, jacobian 0.00, obj 2.84, max_var 0.0106 min_var 0.0046 time elapsed 404.03 sec
# epoch 30, iter 3744, log_likelihood 133.20, jacobian 0.00, obj 2.54, max_var 0.0106 min_var 0.0046 time elapsed 404.65 sec
# epoch 30, iter 3756, log_likelihood 133.13, jacobian 0.00, obj 1.90, max_var 0.0106 min_var 0.0046 time elapsed 405.35 sec
# epoch 30, iter 3768, log_likelihood 133.14, jacobian 0.00, obj 1.59, max_var 0.0106 min_var 0.0046 time elapsed 406.01 sec
# epoch 30, iter 3780, log_likelihood 133.11, jacobian 0.00, obj 1.48, max_var 0.0106 min_var 0.0046 time elapsed 406.87 sec
# epoch 30, iter 3792, log_likelihood 133.07, jacobian 0.00, obj 1.31, max_var 0.0106 min_var 0.0046 time elapsed 407.54 sec
# epoch 30, iter 3804, log_likelihood 133.07, jacobian 0.00, obj 1.33, max_var 0.0106 min_var 0.0046 time elapsed 408.21 sec
#
# epoch 30, log_likelihood 133.08, jacobian 0.00, obj 0.29
#
#
# *****epoch 30, iter 3813, M1 0.748066, VM 0.681619*****
#
# epoch 31, iter 3816, log_likelihood 133.82, jacobian 0.00, obj 50.09, max_var 0.0106 min_var 0.0046 time elapsed 415.51 sec
# epoch 31, iter 3828, log_likelihood 133.28, jacobian 0.00, obj 7.64, max_var 0.0106 min_var 0.0046 time elapsed 416.16 sec
# epoch 31, iter 3840, log_likelihood 133.05, jacobian 0.00, obj 5.27, max_var 0.0106 min_var 0.0046 time elapsed 416.79 sec
# epoch 31, iter 3852, log_likelihood 133.14, jacobian 0.00, obj 3.67, max_var 0.0106 min_var 0.0046 time elapsed 417.37 sec
# epoch 31, iter 3864, log_likelihood 133.10, jacobian 0.00, obj 2.39, max_var 0.0106 min_var 0.0046 time elapsed 417.95 sec
# epoch 31, iter 3876, log_likelihood 133.08, jacobian 0.00, obj 2.06, max_var 0.0106 min_var 0.0046 time elapsed 418.60 sec
# epoch 31, iter 3888, log_likelihood 133.09, jacobian 0.00, obj 1.98, max_var 0.0106 min_var 0.0046 time elapsed 419.20 sec
# epoch 31, iter 3900, log_likelihood 133.10, jacobian 0.00, obj 1.70, max_var 0.0106 min_var 0.0046 time elapsed 419.88 sec
# epoch 31, iter 3912, log_likelihood 133.09, jacobian 0.00, obj 1.31, max_var 0.0106 min_var 0.0046 time elapsed 420.43 sec
# epoch 31, iter 3924, log_likelihood 133.06, jacobian 0.00, obj 1.21, max_var 0.0106 min_var 0.0046 time elapsed 421.30 sec
# epoch 31, iter 3936, log_likelihood 133.08, jacobian 0.00, obj 0.32, max_var 0.0106 min_var 0.0046 time elapsed 421.90 sec
#
# epoch 31, log_likelihood 133.08, jacobian 0.00, obj 0.32
#
#
# *****epoch 31, iter 3936, M1 0.747906, VM 0.682364*****
#
# epoch 32, iter 3948, log_likelihood 133.09, jacobian 0.00, obj 10.84, max_var 0.0106 min_var 0.0046 time elapsed 428.95 sec
# epoch 32, iter 3960, log_likelihood 133.08, jacobian 0.00, obj 5.86, max_var 0.0106 min_var 0.0046 time elapsed 429.60 sec
# epoch 32, iter 3972, log_likelihood 133.17, jacobian 0.00, obj 3.29, max_var 0.0106 min_var 0.0046 time elapsed 430.27 sec
# epoch 32, iter 3984, log_likelihood 133.14, jacobian 0.00, obj 2.97, max_var 0.0106 min_var 0.0046 time elapsed 430.82 sec
# epoch 32, iter 3996, log_likelihood 133.11, jacobian 0.00, obj 2.36, max_var 0.0106 min_var 0.0046 time elapsed 431.46 sec
# epoch 32, iter 4008, log_likelihood 133.10, jacobian 0.00, obj 2.01, max_var 0.0106 min_var 0.0046 time elapsed 432.12 sec
# epoch 32, iter 4020, log_likelihood 133.11, jacobian 0.00, obj 1.89, max_var 0.0106 min_var 0.0046 time elapsed 432.82 sec
# epoch 32, iter 4032, log_likelihood 133.09, jacobian 0.00, obj 1.37, max_var 0.0106 min_var 0.0046 time elapsed 433.43 sec
# epoch 32, iter 4044, log_likelihood 133.08, jacobian 0.00, obj 1.45, max_var 0.0106 min_var 0.0046 time elapsed 434.21 sec
# epoch 32, iter 4056, log_likelihood 133.08, jacobian 0.00, obj 1.26, max_var 0.0106 min_var 0.0046 time elapsed 434.88 sec
#
# epoch 32, log_likelihood 133.09, jacobian 0.00, obj 0.33
#
#
# *****epoch 32, iter 4059, M1 0.748980, VM 0.684208*****
#
# epoch 33, iter 4068, log_likelihood 133.24, jacobian 0.00, obj 13.32, max_var 0.0106 min_var 0.0046 time elapsed 441.92 sec
# epoch 33, iter 4080, log_likelihood 133.21, jacobian 0.00, obj 7.75, max_var 0.0106 min_var 0.0046 time elapsed 442.50 sec
# epoch 33, iter 4092, log_likelihood 133.14, jacobian 0.00, obj 3.80, max_var 0.0106 min_var 0.0046 time elapsed 443.15 sec
# epoch 33, iter 4104, log_likelihood 133.17, jacobian 0.00, obj 3.01, max_var 0.0106 min_var 0.0046 time elapsed 443.73 sec
# epoch 33, iter 4116, log_likelihood 133.12, jacobian 0.00, obj 2.18, max_var 0.0106 min_var 0.0046 time elapsed 444.39 sec
# epoch 33, iter 4128, log_likelihood 133.08, jacobian 0.00, obj 1.78, max_var 0.0106 min_var 0.0046 time elapsed 444.95 sec
# epoch 33, iter 4140, log_likelihood 133.07, jacobian 0.00, obj 1.67, max_var 0.0106 min_var 0.0046 time elapsed 445.65 sec
# epoch 33, iter 4152, log_likelihood 133.11, jacobian 0.00, obj 1.46, max_var 0.0106 min_var 0.0046 time elapsed 446.32 sec
# epoch 33, iter 4164, log_likelihood 133.11, jacobian 0.00, obj 1.21, max_var 0.0106 min_var 0.0046 time elapsed 446.97 sec
# epoch 33, iter 4176, log_likelihood 133.10, jacobian 0.00, obj 1.16, max_var 0.0106 min_var 0.0046 time elapsed 447.58 sec
#
# epoch 33, log_likelihood 133.08, jacobian 0.00, obj 0.37
#
#
# *****epoch 33, iter 4182, M1 0.749585, VM 0.684024*****
#
# epoch 34, iter 4188, log_likelihood 133.22, jacobian 0.00, obj 20.94, max_var 0.0106 min_var 0.0046 time elapsed 454.73 sec
# epoch 34, iter 4200, log_likelihood 132.92, jacobian 0.00, obj 7.02, max_var 0.0106 min_var 0.0046 time elapsed 455.57 sec
# epoch 34, iter 4212, log_likelihood 132.96, jacobian 0.00, obj 4.46, max_var 0.0106 min_var 0.0046 time elapsed 456.21 sec
# epoch 34, iter 4224, log_likelihood 133.03, jacobian 0.00, obj 2.83, max_var 0.0106 min_var 0.0046 time elapsed 456.91 sec
# epoch 34, iter 4236, log_likelihood 133.03, jacobian 0.00, obj 2.21, max_var 0.0106 min_var 0.0046 time elapsed 457.52 sec
# epoch 34, iter 4248, log_likelihood 133.09, jacobian 0.00, obj 2.15, max_var 0.0106 min_var 0.0046 time elapsed 458.27 sec
# ...
# epoch 38, iter 4740, log_likelihood 133.08, jacobian 0.00, obj 2.31, max_var 0.0106 min_var 0.0046 time elapsed 511.25 sec
# epoch 38, iter 4752, log_likelihood 133.10, jacobian 0.00, obj 2.02, max_var 0.0106 min_var 0.0046 time elapsed 511.86 sec
# epoch 38, iter 4764, log_likelihood 133.14, jacobian 0.00, obj 1.43, max_var 0.0106 min_var 0.0046 time elapsed 512.44 sec
# epoch 38, iter 4776, log_likelihood 133.15, jacobian 0.00, obj 1.17, max_var 0.0106 min_var 0.0046 time elapsed 513.06 sec
# epoch 38, iter 4788, log_likelihood 133.10, jacobian 0.00, obj 1.05, max_var 0.0106 min_var 0.0046 time elapsed 513.67 sec
#
# epoch 38, log_likelihood 133.12, jacobian 0.00, obj 0.27
#
#
# *****epoch 38, iter 4797, M1 0.742475, VM 0.681194*****
#
# epoch 39, iter 4800, log_likelihood 133.32, jacobian 0.00, obj 48.32, max_var 0.0106 min_var 0.0046 time elapsed 520.61 sec
# epoch 39, iter 4812, log_likelihood 132.94, jacobian 0.00, obj 7.95, max_var 0.0106 min_var 0.0046 time elapsed 521.49 sec
# epoch 39, iter 4824, log_likelihood 133.00, jacobian 0.00, obj 4.50, max_var 0.0106 min_var 0.0046 time elapsed 522.10 sec
# epoch 39, iter 4836, log_likelihood 132.95, jacobian 0.00, obj 3.38, max_var 0.0106 min_var 0.0046 time elapsed 522.70 sec
# epoch 39, iter 4848, log_likelihood 133.03, jacobian 0.00, obj 2.81, max_var 0.0106 min_var 0.0046 time elapsed 523.42 sec
# epoch 39, iter 4860, log_likelihood 133.04, jacobian 0.00, obj 2.13, max_var 0.0106 min_var 0.0046 time elapsed 524.06 sec
# epoch 39, iter 4872, log_likelihood 133.15, jacobian 0.00, obj 1.78, max_var 0.0106 min_var 0.0046 time elapsed 524.69 sec
# epoch 39, iter 4884, log_likelihood 133.11, jacobian 0.00, obj 1.57, max_var 0.0106 min_var 0.0046 time elapsed 525.32 sec
# epoch 39, iter 4896, log_likelihood 133.11, jacobian 0.00, obj 1.18, max_var 0.0106 min_var 0.0046 time elapsed 525.95 sec
# epoch 39, iter 4908, log_likelihood 133.10, jacobian 0.00, obj 1.20, max_var 0.0106 min_var 0.0046 time elapsed 526.63 sec
# epoch 39, iter 4920, log_likelihood 133.12, jacobian 0.00, obj 0.27, max_var 0.0106 min_var 0.0046 time elapsed 527.32 sec
#
# epoch 39, log_likelihood 133.12, jacobian 0.00, obj 0.27
#
#
# *****epoch 39, iter 4920, M1 0.746684, VM 0.683123*****
#
# epoch 40, iter 4932, log_likelihood 133.07, jacobian 0.00, obj 9.24, max_var 0.0106 min_var 0.0046 time elapsed 534.69 sec
# epoch 40, iter 4944, log_likelihood 133.17, jacobian 0.00, obj 5.18, max_var 0.0106 min_var 0.0046 time elapsed 535.32 sec
# epoch 40, iter 4956, log_likelihood 133.22, jacobian 0.00, obj 3.27, max_var 0.0106 min_var 0.0046 time elapsed 536.18 sec
# epoch 40, iter 4968, log_likelihood 133.13, jacobian 0.00, obj 2.85, max_var 0.0106 min_var 0.0046 time elapsed 536.87 sec
# epoch 40, iter 4980, log_likelihood 133.15, jacobian 0.00, obj 2.20, max_var 0.0106 min_var 0.0046 time elapsed 537.50 sec
# epoch 40, iter 4992, log_likelihood 133.19, jacobian 0.00, obj 1.91, max_var 0.0106 min_var 0.0046 time elapsed 538.12 sec
# epoch 40, iter 5004, log_likelihood 133.19, jacobian 0.00, obj 1.67, max_var 0.0106 min_var 0.0046 time elapsed 538.83 sec
# epoch 40, iter 5016, log_likelihood 133.15, jacobian 0.00, obj 1.52, max_var 0.0106 min_var 0.0046 time elapsed 539.47 sec
# epoch 40, iter 5028, log_likelihood 133.13, jacobian 0.00, obj 1.04, max_var 0.0106 min_var 0.0046 time elapsed 540.14 sec
# epoch 40, iter 5040, log_likelihood 133.14, jacobian 0.00, obj 1.19, max_var 0.0106 min_var 0.0046 time elapsed 540.83 sec
#
# epoch 40, log_likelihood 133.12, jacobian 0.00, obj 0.35
#
#
# *****epoch 40, iter 5043, M1 0.745089, VM 0.682685*****
#
# epoch 41, iter 5052, log_likelihood 133.05, jacobian 0.00, obj 13.97, max_var 0.0106 min_var 0.0046 time elapsed 548.04 sec
# epoch 41, iter 5064, log_likelihood 133.14, jacobian 0.00, obj 5.72, max_var 0.0106 min_var 0.0046 time elapsed 548.67 sec
# epoch 41, iter 5076, log_likelihood 133.09, jacobian 0.00, obj 4.06, max_var 0.0106 min_var 0.0046 time elapsed 549.33 sec
# epoch 41, iter 5088, log_likelihood 133.12, jacobian 0.00, obj 3.29, max_var 0.0106 min_var 0.0046 time elapsed 550.06 sec
# epoch 41, iter 5100, log_likelihood 133.16, jacobian 0.00, obj 2.18, max_var 0.0106 min_var 0.0046 time elapsed 550.65 sec
# epoch 41, iter 5112, log_likelihood 133.13, jacobian 0.00, obj 1.85, max_var 0.0106 min_var 0.0046 time elapsed 551.22 sec
# epoch 41, iter 5124, log_likelihood 133.11, jacobian 0.00, obj 1.44, max_var 0.0106 min_var 0.0046 time elapsed 551.98 sec
# epoch 41, iter 5136, log_likelihood 133.11, jacobian 0.00, obj 1.35, max_var 0.0106 min_var 0.0046 time elapsed 552.59 sec
# epoch 41, iter 5148, log_likelihood 133.12, jacobian 0.00, obj 1.35, max_var 0.0106 min_var 0.0046 time elapsed 553.19 sec
# epoch 41, iter 5160, log_likelihood 133.14, jacobian 0.00, obj 1.16, max_var 0.0106 min_var 0.0046 time elapsed 553.87 sec
#
# epoch 41, log_likelihood 133.13, jacobian 0.00, obj 0.21
#
#
# *****epoch 41, iter 5166, M1 0.746960, VM 0.683948*****
#
# epoch 42, iter 5172, log_likelihood 133.21, jacobian 0.00, obj 21.49, max_var 0.0106 min_var 0.0046 time elapsed 560.80 sec
# epoch 42, iter 5184, log_likelihood 133.28, jacobian 0.00, obj 6.90, max_var 0.0106 min_var 0.0046 time elapsed 561.42 sec
# epoch 42, iter 5196, log_likelihood 133.11, jacobian 0.00, obj 4.65, max_var 0.0106 min_var 0.0046 time elapsed 562.03 sec
# epoch 42, iter 5208, log_likelihood 133.16, jacobian 0.00, obj 3.30, max_var 0.0106 min_var 0.0046 time elapsed 562.66 sec
# epoch 42, iter 5220, log_likelihood 133.10, jacobian 0.00, obj 2.45, max_var 0.0106 min_var 0.0046 time elapsed 563.45 sec
# epoch 42, iter 5232, log_likelihood 133.14, jacobian 0.00, obj 1.98, max_var 0.0106 min_var 0.0046 time elapsed 564.09 sec
# epoch 42, iter 5244, log_likelihood 133.16, jacobian 0.00, obj 1.55, max_var 0.0106 min_var 0.0046 time elapsed 564.68 sec
# epoch 42, iter 5256, log_likelihood 133.17, jacobian 0.00, obj 1.21, max_var 0.0106 min_var 0.0046 time elapsed 565.33 sec
# epoch 42, iter 5268, log_likelihood 133.18, jacobian 0.00, obj 1.36, max_var 0.0106 min_var 0.0046 time elapsed 566.00 sec
# epoch 42, iter 5280, log_likelihood 133.13, jacobian 0.00, obj 1.16, max_var 0.0106 min_var 0.0046 time elapsed 566.64 sec
#
# epoch 42, log_likelihood 133.12, jacobian 0.00, obj 0.28
#
#
# *****epoch 42, iter 5289, M1 0.744080, VM 0.681808*****
#
# epoch 43, iter 5292, log_likelihood 132.89, jacobian 0.00, obj 42.69, max_var 0.0106 min_var 0.0046 time elapsed 573.52 sec
# epoch 43, iter 5304, log_likelihood 132.98, jacobian 0.00, obj 8.38, max_var 0.0106 min_var 0.0046 time elapsed 574.33 sec
# epoch 43, iter 5316, log_likelihood 133.03, jacobian 0.00, obj 4.89, max_var 0.0106 min_var 0.0046 time elapsed 574.92 sec
# epoch 43, iter 5328, log_likelihood 133.07, jacobian 0.00, obj 3.58, max_var 0.0106 min_var 0.0046 time elapsed 575.64 sec
# epoch 43, iter 5340, log_likelihood 133.07, jacobian 0.00, obj 2.70, max_var 0.0106 min_var 0.0046 time elapsed 576.21 sec
# epoch 43, iter 5352, log_likelihood 133.11, jacobian 0.00, obj 2.20, max_var 0.0106 min_var 0.0046 time elapsed 576.84 sec
# epoch 43, iter 5364, log_likelihood 133.09, jacobian 0.00, obj 1.74, max_var 0.0106 min_var 0.0046 time elapsed 577.42 sec
# epoch 43, iter 5376, log_likelihood 133.11, jacobian 0.00, obj 1.58, max_var 0.0106 min_var 0.0046 time elapsed 578.06 sec
# epoch 43, iter 5388, log_likelihood 133.11, jacobian 0.00, obj 1.24, max_var 0.0106 min_var 0.0046 time elapsed 578.69 sec
# epoch 43, iter 5400, log_likelihood 133.11, jacobian 0.00, obj 1.34, max_var 0.0106 min_var 0.0046 time elapsed 579.28 sec
# epoch 43, iter 5412, log_likelihood 133.13, jacobian 0.00, obj 0.33, max_var 0.0106 min_var 0.0046 time elapsed 579.82 sec
#
# epoch 43, log_likelihood 133.13, jacobian 0.00, obj 0.33
#
#
# *****epoch 43, iter 5412, M1 0.743251, VM 0.681463*****
#
# epoch 44, iter 5424, log_likelihood 132.94, jacobian 0.00, obj 11.66, max_var 0.0106 min_var 0.0046 time elapsed 586.84 sec
# epoch 44, iter 5436, log_likelihood 132.95, jacobian 0.00, obj 5.65, max_var 0.0106 min_var 0.0046 time elapsed 587.55 sec
# epoch 44, iter 5448, log_likelihood 133.05, jacobian 0.00, obj 4.63, max_var 0.0106 min_var 0.0046 time elapsed 588.39 sec
# epoch 44, iter 5460, log_likelihood 133.08, jacobian 0.00, obj 2.81, max_var 0.0106 min_var 0.0046 time elapsed 589.05 sec
# epoch 44, iter 5472, log_likelihood 133.06, jacobian 0.00, obj 1.87, max_var 0.0106 min_var 0.0046 time elapsed 589.65 sec
# epoch 44, iter 5484, log_likelihood 133.04, jacobian 0.00, obj 1.65, max_var 0.0106 min_var 0.0046 time elapsed 590.35 sec
# epoch 44, iter 5496, log_likelihood 133.07, jacobian 0.00, obj 1.72, max_var 0.0106 min_var 0.0046 time elapsed 591.03 sec
# epoch 44, iter 5508, log_likelihood 133.08, jacobian 0.00, obj 1.24, max_var 0.0106 min_var 0.0046 time elapsed 591.70 sec
# epoch 44, iter 5520, log_likelihood 133.11, jacobian 0.00, obj 1.35, max_var 0.0106 min_var 0.0046 time elapsed 592.36 sec
# epoch 44, iter 5532, log_likelihood 133.12, jacobian 0.00, obj 1.16, max_var 0.0106 min_var 0.0046 time elapsed 592.99 sec
#
# epoch 44, log_likelihood 133.11, jacobian 0.00, obj 0.32
#
#
# *****epoch 44, iter 5535, M1 0.749203, VM 0.684500*****
#
# epoch 45, iter 5544, log_likelihood 132.58, jacobian 0.00, obj 14.73, max_var 0.0106 min_var 0.0046 time elapsed 600.41 sec
# epoch 45, iter 5556, log_likelihood 132.86, jacobian 0.00, obj 6.57, max_var 0.0106 min_var 0.0046 time elapsed 601.11 sec
# epoch 45, iter 5568, log_likelihood 132.99, jacobian 0.00, obj 3.93, max_var 0.0106 min_var 0.0046 time elapsed 601.71 sec
# epoch 45, iter 5580, log_likelihood 132.94, jacobian 0.00, obj 3.11, max_var 0.0106 min_var 0.0046 time elapsed 602.30 sec
# epoch 45, iter 5592, log_likelihood 133.02, jacobian 0.00, obj 2.33, max_var 0.0106 min_var 0.0046 time elapsed 602.99 sec
# epoch 45, iter 5604, log_likelihood 133.02, jacobian 0.00, obj 1.73, max_var 0.0106 min_var 0.0046 time elapsed 603.62 sec
# epoch 45, iter 5616, log_likelihood 133.05, jacobian 0.00, obj 1.61, max_var 0.0106 min_var 0.0046 time elapsed 604.27 sec
# epoch 45, iter 5628, log_likelihood 133.08, jacobian 0.00, obj 1.28, max_var 0.0106 min_var 0.0046 time elapsed 604.97 sec
# epoch 45, iter 5640, log_likelihood 133.09, jacobian 0.00, obj 1.08, max_var 0.0106 min_var 0.0046 time elapsed 605.58 sec
# epoch 45, iter 5652, log_likelihood 133.12, jacobian 0.00, obj 1.17, max_var 0.0106 min_var 0.0046 time elapsed 606.27 sec
#
# epoch 45, log_likelihood 133.12, jacobian 0.00, obj 0.30
#
#
# *****epoch 45, iter 5658, M1 0.746089, VM 0.685005*****
#
# epoch 46, iter 5664, log_likelihood 133.33, jacobian 0.00, obj 24.40, max_var 0.0106 min_var 0.0046 time elapsed 613.69 sec
# epoch 46, iter 5676, log_likelihood 133.15, jacobian 0.00, obj 7.87, max_var 0.0106 min_var 0.0046 time elapsed 614.28 sec
# epoch 46, iter 5688, log_likelihood 133.22, jacobian 0.00, obj 4.47, max_var 0.0106 min_var 0.0046 time elapsed 614.84 sec
# epoch 46, iter 5700, log_likelihood 133.24, jacobian 0.00, obj 3.08, max_var 0.0106 min_var 0.0046 time elapsed 615.42 sec
# epoch 46, iter 5712, log_likelihood 133.18, jacobian 0.00, obj 2.19, max_var 0.0106 min_var 0.0046 time elapsed 616.06 sec
# epoch 46, iter 5724, log_likelihood 133.16, jacobian 0.00, obj 1.73, max_var 0.0106 min_var 0.0046 time elapsed 616.70 sec
# epoch 46, iter 5736, log_likelihood 133.21, jacobian 0.00, obj 1.93, max_var 0.0106 min_var 0.0046 time elapsed 617.35 sec
# epoch 46, iter 5748, log_likelihood 133.20, jacobian 0.00, obj 1.56, max_var 0.0106 min_var 0.0046 time elapsed 618.02 sec
# epoch 46, iter 5760, log_likelihood 133.15, jacobian 0.00, obj 1.44, max_var 0.0106 min_var 0.0046 time elapsed 618.66 sec
# epoch 46, iter 5772, log_likelihood 133.13, jacobian 0.00, obj 1.08, max_var 0.0106 min_var 0.0046 time elapsed 619.42 sec
#
# epoch 46, log_likelihood 133.11, jacobian 0.00, obj 0.28
#
#
# *****epoch 46, iter 5781, M1 0.745685, VM 0.684549*****
#
# epoch 47, iter 5784, log_likelihood 133.26, jacobian 0.00, obj 45.78, max_var 0.0106 min_var 0.0046 time elapsed 626.46 sec
# epoch 47, iter 5796, log_likelihood 133.05, jacobian 0.00, obj 8.14, max_var 0.0106 min_var 0.0046 time elapsed 627.06 sec
# epoch 47, iter 5808, log_likelihood 133.05, jacobian 0.00, obj 4.62, max_var 0.0106 min_var 0.0046 time elapsed 627.67 sec
# epoch 47, iter 5820, log_likelihood 133.10, jacobian 0.00, obj 3.93, max_var 0.0106 min_var 0.0046 time elapsed 628.29 sec
# epoch 47, iter 5832, log_likelihood 133.10, jacobian 0.00, obj 2.90, max_var 0.0106 min_var 0.0046 time elapsed 629.21 sec
# epoch 47, iter 5844, log_likelihood 133.07, jacobian 0.00, obj 1.95, max_var 0.0106 min_var 0.0046 time elapsed 629.90 sec
# epoch 47, iter 5856, log_likelihood 133.02, jacobian 0.00, obj 1.81, max_var 0.0106 min_var 0.0046 time elapsed 630.47 sec
# epoch 47, iter 5868, log_likelihood 133.03, jacobian 0.00, obj 1.69, max_var 0.0106 min_var 0.0046 time elapsed 631.10 sec
# epoch 47, iter 5880, log_likelihood 133.06, jacobian 0.00, obj 1.33, max_var 0.0106 min_var 0.0046 time elapsed 631.69 sec
# epoch 47, iter 5892, log_likelihood 133.10, jacobian 0.00, obj 1.13, max_var 0.0106 min_var 0.0046 time elapsed 632.27 sec
# epoch 47, iter 5904, log_likelihood 133.13, jacobian 0.00, obj 0.44, max_var 0.0106 min_var 0.0046 time elapsed 632.85 sec
#
# epoch 47, log_likelihood 133.13, jacobian 0.00, obj 0.44
#
#
# *****epoch 47, iter 5904, M1 0.747151, VM 0.683782*****
#
# epoch 48, iter 5916, log_likelihood 132.64, jacobian 0.00, obj 11.00, max_var 0.0106 min_var 0.0046 time elapsed 639.83 sec
# epoch 48, iter 5928, log_likelihood 132.73, jacobian 0.00, obj 5.71, max_var 0.0106 min_var 0.0046 time elapsed 640.40 sec
# epoch 48, iter 5940, log_likelihood 132.81, jacobian 0.00, obj 4.05, max_var 0.0106 min_var 0.0046 time elapsed 641.08 sec
# epoch 48, iter 5952, log_likelihood 133.03, jacobian 0.00, obj 2.71, max_var 0.0106 min_var 0.0046 time elapsed 641.65 sec
# epoch 48, iter 5964, log_likelihood 133.03, jacobian 0.00, obj 1.82, max_var 0.0106 min_var 0.0046 time elapsed 642.20 sec
# epoch 48, iter 5976, log_likelihood 133.09, jacobian 0.00, obj 1.84, max_var 0.0106 min_var 0.0046 time elapsed 642.80 sec
# epoch 48, iter 5988, log_likelihood 133.08, jacobian 0.00, obj 1.67, max_var 0.0106 min_var 0.0046 time elapsed 643.61 sec
# epoch 48, iter 6000, log_likelihood 133.07, jacobian 0.00, obj 1.52, max_var 0.0106 min_var 0.0046 time elapsed 644.23 sec
# epoch 48, iter 6012, log_likelihood 133.09, jacobian 0.00, obj 1.17, max_var 0.0106 min_var 0.0046 time elapsed 644.92 sec
# epoch 48, iter 6024, log_likelihood 133.11, jacobian 0.00, obj 1.08, max_var 0.0106 min_var 0.0046 time elapsed 645.54 sec
#
# epoch 48, log_likelihood 133.12, jacobian 0.00, obj 0.39
#
#
# *****epoch 48, iter 6027, M1 0.744441, VM 0.683050*****
#
# epoch 49, iter 6036, log_likelihood 133.36, jacobian 0.00, obj 13.78, max_var 0.0106 min_var 0.0046 time elapsed 652.54 sec
# epoch 49, iter 6048, log_likelihood 133.40, jacobian 0.00, obj 6.47, max_var 0.0106 min_var 0.0046 time elapsed 653.17 sec
# epoch 49, iter 6060, log_likelihood 133.30, jacobian 0.00, obj 4.55, max_var 0.0106 min_var 0.0046 time elapsed 653.91 sec
# epoch 49, iter 6072, log_likelihood 133.32, jacobian 0.00, obj 3.19, max_var 0.0106 min_var 0.0046 time elapsed 654.74 sec
# epoch 49, iter 6084, log_likelihood 133.27, jacobian 0.00, obj 2.33, max_var 0.0106 min_var 0.0046 time elapsed 655.50 sec
# epoch 49, iter 6096, log_likelihood 133.23, jacobian 0.00, obj 2.22, max_var 0.0106 min_var 0.0046 time elapsed 656.10 sec
# epoch 49, iter 6108, log_likelihood 133.16, jacobian 0.00, obj 1.58, max_var 0.0106 min_var 0.0046 time elapsed 656.82 sec
# epoch 49, iter 6120, log_likelihood 133.09, jacobian 0.00, obj 1.56, max_var 0.0106 min_var 0.0046 time elapsed 657.53 sec
# epoch 49, iter 6132, log_likelihood 133.10, jacobian 0.00, obj 1.31, max_var 0.0106 min_var 0.0046 time elapsed 658.14 sec
# epoch 49, iter 6144, log_likelihood 133.11, jacobian 0.00, obj 1.16, max_var 0.0106 min_var 0.0046 time elapsed 658.76 sec
#
# epoch 49, log_likelihood 133.12, jacobian 0.00, obj 0.31
#
#
# *****epoch 49, iter 6150, M1 0.743272, VM 0.681809*****
#
#
#  complete training, accuracy 0.743272, vm 0.681809

# %% [markdown]
# ## Training Normalising Flows

# %% [markdown]
# Following cells are used for the training of a projection model with Markov prior instead of
#
# ```
# python markov_flow_train.py \
#         --model nice \
#         --lr 0.01 \
#         --train_file /path/to/train \
#         --word_vec /path/to/word_vec_file \
#         --load_gaussian /path/to/gaussian_model
# ```

# %%
load_gaussian = f"/content/struct_learning_with_flow/dump_models/markov/pos_gaussian_{couple_layers}layers_0_0.pt"
model = "nice"
lr = 0.01

# %%
args = init_config(train_file, word_vec, lr=lr, model=model, couple_layers=couple_layers, load_gaussian=load_gaussian)
main(args)

# %% [markdown]
# ## Evaluation on Test Data

# %% [markdown]
# We evaluate on the training data, you can test on different dataset which can be specified via passing the path to `init_config` function as `test_file` argument

# %%
tag_from = f"/content/struct_learning_with_flow/dump_models/markov/pos_nice_{couple_layers}layers_0_0.pt"

# %%
args = init_config(train_file, word_vec, model=model, lr=lr, tag_from=tag_from, couple_layers=couple_layers)
main(args)
# Out:
# model save path:  dump_models/markov/pos_nice_4layers_0_0.pt
# Namespace(batch_size=32, cell_layers=1, couple_layers=4, cuda=True, epochs=50, hidden_units=50, jobid=0, load_gaussian='', load_nice='/content/struct_learning_with_flow/dump_models/markov/pos_nice_4layers_0_0.pt', lr=0.01, model='nice', num_state=45, save_path='dump_models/markov/pos_nice_4layers_0_0.pt', seed=5783287, set_seed=False, tag_from='/content/struct_learning_with_flow/dump_models/markov/pos_nice_4layers_0_0.pt', tag_path='pos_nice_4layers_tagging0_0.txt', taskid=0, test_file='', train_file='/content/struct_learning_with_flow/sample_data/ptb_tag_train_sub.txt', valid_nepoch=1, word_vec='/content/struct_learning_with_flow/sample_data/wsj_word_vec.pkl')
# complete loading word vectors
# complete reading data
# #training sentences: 3914
# #testing sentences: 3914
#
# ***** M1 0.778347, VM 0.717845, max_var 0.0128, min_var 0.0036*****

# %% [markdown]
# ## Ordinal Encoding of POS Tags

# %%
from sklearn.preprocessing import OrdinalEncoder

# define data
# define ordinal encoding
data = pd.read_csv(
    "/content/struct_learning_with_flow/sample_data/ptb_tag_train_sub.txt", delim_whitespace=True, header=None
)
data = data.drop(columns=[0, 3, 4])
data = data[data[2] != "-NONE-"]

encoder = OrdinalEncoder()
# transform data
data["idx"] = encoder.fit_transform(data[2].to_numpy().reshape((-1, 1))).astype(int)

# %% [markdown]
# ## Colors Assocaited with POS Tags

# %% [markdown]
# We create our own color map for the better visualization of word embeddingss

# %%
discrete_colors = np.vstack(
    (
        plt.cm.tab20b(np.linspace(0, 1, 25))[:5],
        plt.cm.tab20c(np.linspace(0, 1, 25))[:5],
        plt.cm.tab20b(np.linspace(0, 1, 25))[-10:],
        plt.cm.tab20c(np.linspace(0, 1, 25))[5:10],
        plt.cm.Set2(np.linspace(0, 1, 8)),
        plt.cm.Set3(np.linspace(0, 1, 12)),
    )
)
color_map = matplotlib.colors.LinearSegmentedColormap.from_list("spec_cmap", discrete_colors)

# %%
tags = [data[data["idx"] == i][2].unique()[0] for i in range(45)]

# %%
plt.figure(figsize=(11, 18))
discrete_colors_matrix = np.arange(0, 45).reshape(5, 9)
plt.imshow(discrete_colors_matrix, cmap=color_map)
patches1 = [
    mpatches.Patch(color=discrete_colors[i], label=data[data["idx"] == i][2].unique()[0]) for i in range(23, 45)
]
legend1 = plt.legend(handles=patches1, bbox_to_anchor=(1.2, 1), loc=2, borderaxespad=0.0)
patches2 = [mpatches.Patch(color=discrete_colors[i], label=data[data["idx"] == i][2].unique()[0]) for i in range(23)]
plt.legend(handles=patches2, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.0)
plt.gca().add_artist(legend1)
plt.show()

# %% [markdown]
# ## Word Embeddings

# %%
embeddings = pd.read_pickle("/content/struct_learning_with_flow/sample_data/wsj_word_vec.pkl")
data["embeddings"] = data[1].apply(lambda x: embeddings[x])

x = np.vstack(data.embeddings.to_numpy())
y = data["idx"].to_numpy()

tsne = TSNE.TSNE(perplexity=40, random_seed=0, n_iter=500, learning_rate=175)
tsne_result = tsne.fit_transform(x)

# %%
embeddings = pd.read_pickle("/content/word_embeddings.pkl")
data["embeddings"] = data[1].apply(lambda x: embeddings[x] if x in embeddings else embeddings["0"])

x = np.vstack(data.embeddings.to_numpy())
new_tsne_result = tsne.fit_transform(x)

# %%
plt.figure(figsize=(20, 10))
plt.subplot(1, 2, 1)
plt.scatter(tsne_result[:, 0], tsne_result[:, 1], cmap=color_map, c=list(map(int, y)), alpha=0.2, marker=".")
plt.subplot(1, 2, 2)
plt.scatter(new_tsne_result[:, 0], new_tsne_result[:, 1], cmap=color_map, c=list(map(int, y)), alpha=0.2, marker=".")
plt.show()
